# %%
import os
import torch
import torch.nn as nn
from datetime import datetime
from obd1.models import yolo_base,ann_new_model_2
from lava.lib.dl import slayer
from torch.utils.data import DataLoader
from obd1.dataset import evCIVIL,visualize_data
from obd1.boundingbox import metrics,utils
from torch.ao.quantization import QuantStub, DeQuantStub

# %%
def load_model_only_with_necessary_keys_from_state_dict(model,pretained_ckpt_path,is_full_checkpoint = True):

    # Load the state dictionary from a pre-trained checkpoint
    pretrained_full_checkpoint = torch.load(pretained_ckpt_path)
    if is_full_checkpoint:
        pretrained_checkpoint = pretrained_full_checkpoint["model_state_dict"]
    else:
        pretrained_checkpoint = pretrained_full_checkpoint

    # Get the current state dictionary of the model
    model_state_dict = model.state_dict()

    # Create a new state dictionary to load the weights
    updated_state_dict = {}

    # Iterate over the keys in the pre-trained state dictionary
    for key in pretrained_checkpoint.keys():
        if key in model_state_dict and pretrained_checkpoint[key].size() == model_state_dict[key].size():
     
            #if torch.any(pretrained_checkpoint[key] > 4):
            #    print(key) #"     ",pretrained_checkpoint[key])

            updated_state_dict[key] = pretrained_checkpoint[key]
        else:
            print(f"Skipping {key} due to mismatch in size or missing key.")

    all_tensors = torch.cat([v.view(-1) for v in updated_state_dict.values()])

    # Find the maximum value
    max_value = torch.max(all_tensors)

    # Find the minimum value
    min_value = torch.min(all_tensors)
    
    # Update the state dictionary of the model
    model_state_dict.update(updated_state_dict)

    print("max value of the state_dict ",max_value)
    print("min value of the state dict ",min_value)
    print("average value of state dict ",torch.mean(all_tensors))

    # Load the updated state dictionary into the model
    model.load_state_dict(model_state_dict)


    # Verify if the model weights have been loaded correctly
    for key in updated_state_dict.keys():
        assert torch.equal(model.state_dict()[key], updated_state_dict[key]), f"Weights not loaded correctly for {key}"

    print("Model loaded with available pre-trained weights.")

# %%
def validate_gradients(model) -> None:
        """Validate gradients of the network and circumvent if any.
        """
        valid_gradients = True
        for name, param in model.named_parameters():
            if param.grad is not None:
                valid_gradients = not (torch.isnan(param.grad).any()
                                       or torch.isinf(param.grad).any())
                if not valid_gradients:
                    break
        if not valid_gradients:
            model.zero_grad()

# %%
def _yolo(x: torch.tensor,
          anchors: torch.tensor,
          clamp_max: float = 5.0) -> torch.tensor:
    # converts raw predictions to bounding box predictions.
    _, _, H, W, _, _ = x.shape
    range_y, range_x = torch.meshgrid(
        torch.arange(H, dtype=x.dtype, device=x.device),
        torch.arange(W, dtype=x.dtype, device=x.device),
        indexing='ij',
    )
    anchor_x, anchor_y = anchors[:, 0], anchors[:, 1]

    x_center = (torch.sigmoid(x[:, :, :, :, 0:1, :])
                + range_x[None, None, :, :, None, None]) / W
    y_center = (torch.sigmoid(x[:, :, :, :, 1:2, :])
                + range_y[None, None, :, :, None, None]) / H
    width = (torch.exp(
        x[:, :, :, :, 2:3, :].clamp(
            max=clamp_max)) * anchor_x[None, :, None, None, None, None]) / W
    height = (torch.exp(
        x[:, :, :, :, 3:4, :].clamp(
            max=clamp_max)) * anchor_y[None, :, None, None, None, None]) / H
    confidence = torch.sigmoid(x[:, :, :, :, 4:5, :])
    classes = torch.softmax(x[:, :, :, :, 5:, :], dim=-2)

    x = torch.concat([x_center, y_center, width, height,
                      confidence, classes], dim=-2)

    if torch.isnan(x).any() or torch.isinf(x).any():
        print(f'{torch.isnan(x_center).any()=}')
        print(f'{torch.isinf(x_center).any()=}')
        print(f'{torch.isnan(y_center).any()=}')
        print(f'{torch.isinf(y_center).any()=}')
        print(f'{torch.isnan(width).any()=}')
        print(f'{torch.isinf(width).any()=}')
        print(f'{torch.isnan(height).any()=}')
        print(f'{torch.isinf(height).any()=}')
        raise RuntimeError('Ecountered NaN and Inf!')

    return x  # batch, anchor, height, width, predictions, time 



def yolo(x: torch.tensor, anchors: torch.tensor) -> torch.tensor:
        """Evaluates YOLO bounding box prediction from raw network output.

        Parameters
        ----------
        x : torch.tensor
            Raw prediciton tensor.
        anchors : torch.tensor
            Anchors associated with the prediction head.

        Returns
        -------
        torch.tensor
            Output bounding boxes.
        """
        clamp_max = 5.0
        N, _, _, _, P, T = x.shape
        return _yolo(x, anchors, clamp_max).reshape([N, -1, P, T])

def yolo_raw(x: torch.tensor) -> torch.tensor:
        """Transforms raw YOLO prediction to eventual output order i.e.
        NCHWT order to (batch, num_anchors, num_outputs, height, width, time).

        Parameters
        ----------
        x : torch.tensor
            Raw prediction output of the network.

        Returns
        -------
        torch.tensor
            Transformed raw prediction output for a head.
        """
        num_anchors = 3

        N, _, H, W = x.shape
        return x.reshape(N,
                         num_anchors,
                         -1, H, W).permute(0, 1, 3, 4, 2)
        #return x.reshape(N,num_anchors,-1, H, W, T).permute(0, 1, 3, 4, 2, 5)

        """T, N, _, H, W = x.shape
        return x.reshape(T,N,
                         num_anchors,
                         -1, H, W).permute(1, 2, 4, 5, 3, 0) # now (batch,anchors,h,w,-1,T)"""

# %%
dataset_path = '/home/udayanga/latest_dataset/'
train_csv_file = "night_outdoor_and_daytime_train_files_image_based.txt"
test_csv_file = "test_files_image_based.txt" #"test_files_image_based.txt" #night_outdoor_test_files_event_based
param_dict = {"TSteps" : 7, "tbins" : 1 ,"quantized_h" : 260 ,"quantized_w" : 346}

# %%
in_channels = 1
num_anchors = 3
num_classes = 2
num_output = num_anchors * (5 + num_classes)
tgt_iou_thr = 0.5
conf_thres = 0.1

# %%
net_dummy = ann_new_model_2.Network(in_channels=in_channels,num_classes=2,clamp_max=5.)
net_dummy.to(torch.device("cuda:0"))
net_dummy.init_model((320,320),1)
pretrained_ckpt_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/epoch_262_0.3226383599284339.pt"  #"/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_model_images/selected_checkpoints/epoch_570_0.3243951648790068.pt"
full_ckpt = torch.load(pretrained_ckpt_path,map_location=torch.device("cuda:0"))
net_dummy.load_state_dict(full_ckpt["model_state_dict"])
load_model_only_with_necessary_keys_from_state_dict(net_dummy,pretrained_ckpt_path,is_full_checkpoint = True)
# Out:
# max value of the state_dict  tensor(177263., device='cuda:0')
# min value of the state dict  tensor(-13.3185, device='cuda:0')
# average value of state dict  tensor(3.6925, device='cuda:0')
# Model loaded with available pre-trained weights.
# /tmp/ipykernel_68322/2396264443.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   full_ckpt = torch.load(pretrained_ckpt_path,map_location=torch.device("cuda:0"))
# /tmp/ipykernel_68322/3181773012.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_full_checkpoint = torch.load(pretained_ckpt_path)

# %%
#net = ann_new_model.Network(in_channels=in_channels,num_classes=2,clamp_max=5.)
#N,C,H,W = 8,2,320,320
#input = torch.rand(N,C, H, W)
#net(input)

# %%
yolo_target = yolo_base.YOLOtarget(anchors= net_dummy.anchors,
                                 scales= net_dummy.scale,
                                 num_classes=net_dummy.num_classes,
                                 ignore_iou_thres=tgt_iou_thr)

# %%
train_set = evCIVIL.evCIVIL(root = dataset_path ,csv_file_name = train_csv_file , param_dict = param_dict, train = True,augment = False)
test_set = evCIVIL.evCIVIL(root = dataset_path, csv_file_name= test_csv_file, param_dict = param_dict, train = False, augment = False)

train_loader = DataLoader(train_set,
                                batch_size=8,
                                shuffle=True,
                                collate_fn=yolo_target.collate_fn,
                                num_workers=1,
                                pin_memory=True)
    
test_loader = DataLoader(test_set,
                                batch_size=1,
                                shuffle=False,
                                collate_fn=yolo_target.collate_fn,    
                                num_workers=1,
                                pin_memory=True)

# %%
print(net_dummy)
# Out:
# Network(
#   (backend_blocks): ModuleList(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#   )
#   (head1_backend): ModuleList(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (head1_blocks): ModuleList(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(128, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (7): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#   )
# )

# %%
#visualize_save_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/visualize_image_save_day"
conf_thres = 0.5
stats = slayer.utils.LearningStats(accuracy_str='AP@0.5')
ap_stats = metrics.APstats(iou_threshold=0.5)
stats.update()

epoch = 0
t_st = datetime.now()
net_dummy.eval()

with torch.no_grad():
        
        for i, (inputs, targets, bboxes) in enumerate(test_loader):

                #start
                inputs = inputs.permute(4,0,1,2,3)
          
                inputs = inputs.squeeze(0)

                inputs = inputs.to(torch.device('cuda:0'))
                predictions,_ = net_dummy(inputs)

      
                predictions = [prediction.unsqueeze(-1) for prediction in predictions]
                
                #predictions = [torch.sum(prediction,dim=-1).unsqueeze(-1) for prediction in predictions]

                # MAP calculations
                T = 1 #inputs.shape[-1]
                try:
                    predictions = torch.concat([net_dummy.yolo(p, a) for (p, a)
                        in zip(predictions, net_dummy.anchors)],dim=1)
                except RuntimeError:
                    print('Runtime error on MAP predictions calculation.'
                            'continuing')
                    continue

                predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)
                                for t in range(T)]
                
                print("predictions shape ",predictions[0][0].shape)
                print("bboxes shape ",bboxes[0][0].shape)
                print("inputs shape ",inputs.shape)

                #visualize_data.dump_image_with_labels(inputs.squeeze(0).permute(1,2,0).cpu(),predictions[0][0].cpu().numpy(),(320,320),visualize_save_path,i,create_histo_frames=False)
                for t in range(T):
                    ap_stats.update(predictions[t], bboxes[t])
                    #end

                stats.testing.num_samples += inputs.shape[0]
                stats.testing.correct_samples = ap_stats[:] * stats.testing.num_samples

                processed = i * test_loader.batch_size
                total = len(test_loader.dataset)
                time_elapsed = (datetime.now() - t_st).total_seconds()
                samples_sec = time_elapsed / (i + 1) / test_loader.batch_size
                header_list = [f'Test: [{processed}/{total} '
                                    f'({100.0 * processed / total:.0f}%)]']
                stats.print(epoch, i, samples_sec, header=header_list)
                #functional.reset_net(net)

        print("Loss/train", stats.training.loss,epoch)
        print('mAP@50/train',stats.training.accuracy,epoch)
        print('mAP@50/test', stats.testing.accuracy, epoch)
# Out:
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [0/1556 (0%)]
# Epoch    0: i =     0 ,     118.8080 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.99625
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1/1556 (0%)]
# Epoch    0: i =     1 ,      62.3825 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.50562
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [2/1556 (0%)]
# Epoch    0: i =     2 ,      43.4330 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34208
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [3/1556 (0%)]
# Epoch    0: i =     3 ,      33.9780 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26031
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [4/1556 (0%)]
# Epoch    0: i =     4 ,      28.3286 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.40758
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [5/1556 (0%)]
# Epoch    0: i =     5 ,      24.4357 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34215
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [6/1556 (0%)]
# Epoch    0: i =     6 ,      21.7806 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29542
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [7/1556 (0%)]
# Epoch    0: i =     7 ,      19.6589 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26036
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [8/1556 (1%)]
# Epoch    0: i =     8 ,      17.8684 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.23310
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [9/1556 (1%)]
# Epoch    0: i =     9 ,      16.5036 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21129
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [10/1556 (1%)]
# Epoch    0: i =    10 ,      15.3676 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28277
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [11/1556 (1%)]
# Epoch    0: i =    11 ,      14.4817 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34233
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [12/1556 (1%)]
# Epoch    0: i =    12 ,      13.7051 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31715
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [13/1556 (1%)]
# Epoch    0: i =    13 ,      13.0299 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29557
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [14/1556 (1%)]
# Epoch    0: i =    14 ,      12.4769 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.27686
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [15/1556 (1%)]
# Epoch    0: i =    15 ,      11.9867 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26049
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [16/1556 (1%)]
# Epoch    0: i =    16 ,      11.5340 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.24605
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [17/1556 (1%)]
# Epoch    0: i =    17 ,      11.1598 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.23322
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [18/1556 (1%)]
# Epoch    0: i =    18 ,      10.8198 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.22173
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [19/1556 (1%)]
# Epoch    0: i =    19 ,      10.5156 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21140
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [20/1556 (1%)]
# Epoch    0: i =    20 ,      10.1704 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20204
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [21/1556 (1%)]
# Epoch    0: i =    21 ,       9.8882 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19354
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [22/1556 (1%)]
# Epoch    0: i =    22 ,       9.6823 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18578
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [23/1556 (1%)]
# Epoch    0: i =    23 ,       9.4780 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17866
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [24/1556 (2%)]
# Epoch    0: i =    24 ,       9.2715 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17212
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [25/1556 (2%)]
# Epoch    0: i =    25 ,       9.1025 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16607
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [26/1556 (2%)]
# Epoch    0: i =    26 ,       8.9015 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16048
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [27/1556 (2%)]
# Epoch    0: i =    27 ,       8.7550 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15528
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [28/1556 (2%)]
# Epoch    0: i =    28 ,       8.6056 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16389
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [29/1556 (2%)]
# Epoch    0: i =    29 ,       8.4553 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17193
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [30/1556 (2%)]
# Epoch    0: i =    30 ,       8.3444 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17945
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [31/1556 (2%)]
# Epoch    0: i =    31 ,       8.2203 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17431
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [32/1556 (2%)]
# Epoch    0: i =    32 ,       8.1184 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16948
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [33/1556 (2%)]
# Epoch    0: i =    33 ,       8.0139 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17641
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [34/1556 (2%)]
# Epoch    0: i =    34 ,       7.9065 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17723
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [35/1556 (2%)]
# Epoch    0: i =    35 ,       7.8129 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17800
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [36/1556 (2%)]
# Epoch    0: i =    36 ,       7.7269 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17359
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [37/1556 (2%)]
# Epoch    0: i =    37 ,       7.6779 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16942
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([5, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [38/1556 (2%)]
# Epoch    0: i =    38 ,       7.5940 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17033
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [39/1556 (3%)]
# Epoch    0: i =    39 ,       7.5021 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16645
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [40/1556 (3%)]
# Epoch    0: i =    40 ,       7.4893 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16275
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [41/1556 (3%)]
# Epoch    0: i =    41 ,       7.4037 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18269
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [42/1556 (3%)]
# Epoch    0: i =    42 ,       7.3349 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17879
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [43/1556 (3%)]
# Epoch    0: i =    43 ,       7.2935 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17507
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [44/1556 (3%)]
# Epoch    0: i =    44 ,       7.2858 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19340
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [45/1556 (3%)]
# Epoch    0: i =    45 ,       7.2417 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18952
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [46/1556 (3%)]
# Epoch    0: i =    46 ,       7.2293 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18581
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [47/1556 (3%)]
# Epoch    0: i =    47 ,       7.1576 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18225
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [48/1556 (3%)]
# Epoch    0: i =    48 ,       7.1105 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17853
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [49/1556 (3%)]
# Epoch    0: i =    49 ,       7.0585 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19489
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [50/1556 (3%)]
# Epoch    0: i =    50 ,       7.0361 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19136
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [51/1556 (3%)]
# Epoch    0: i =    51 ,       6.9849 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18797
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [52/1556 (3%)]
# Epoch    0: i =    52 ,       6.9410 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18471
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [53/1556 (3%)]
# Epoch    0: i =    53 ,       6.9002 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19974
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [54/1556 (3%)]
# Epoch    0: i =    54 ,       6.8526 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19314
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [55/1556 (4%)]
# Epoch    0: i =    55 ,       6.8033 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19001
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [56/1556 (4%)]
# Epoch    0: i =    56 ,       6.7548 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18700
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [57/1556 (4%)]
# Epoch    0: i =    57 ,       6.7210 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18408
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [58/1556 (4%)]
# Epoch    0: i =    58 ,       6.6486 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18101
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [59/1556 (4%)]
# Epoch    0: i =    59 ,       6.6119 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17566
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [60/1556 (4%)]
# Epoch    0: i =    60 ,       6.5815 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17311
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [61/1556 (4%)]
# Epoch    0: i =    61 ,       6.5501 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17064
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [62/1556 (4%)]
# Epoch    0: i =    62 ,       6.5186 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16824
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [63/1556 (4%)]
# Epoch    0: i =    63 ,       6.4853 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16592
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [64/1556 (4%)]
# Epoch    0: i =    64 ,       6.4608 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16367
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [65/1556 (4%)]
# Epoch    0: i =    65 ,       6.4191 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16148
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [66/1556 (4%)]
# Epoch    0: i =    66 ,       6.3771 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15708
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [67/1556 (4%)]
# Epoch    0: i =    67 ,       6.3448 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15508
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [68/1556 (4%)]
# Epoch    0: i =    68 ,       6.3114 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15314
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [69/1556 (4%)]
# Epoch    0: i =    69 ,       6.2909 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15124
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [70/1556 (4%)]
# Epoch    0: i =    70 ,       6.2536 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14920
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [71/1556 (5%)]
# Epoch    0: i =    71 ,       6.2169 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14741
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [72/1556 (5%)]
# Epoch    0: i =    72 ,       6.1902 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15863
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [73/1556 (5%)]
# Epoch    0: i =    73 ,       6.1655 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16951
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [74/1556 (5%)]
# Epoch    0: i =    74 ,       6.1384 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18012
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [75/1556 (5%)]
# Epoch    0: i =    75 ,       6.1105 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18423
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [76/1556 (5%)]
# Epoch    0: i =    76 ,       6.0869 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19439
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [77/1556 (5%)]
# Epoch    0: i =    77 ,       6.0643 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19217
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [78/1556 (5%)]
# Epoch    0: i =    78 ,       6.0405 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19001
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [79/1556 (5%)]
# Epoch    0: i =    79 ,       6.0158 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18791
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [80/1556 (5%)]
# Epoch    0: i =    80 ,       5.9939 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18585
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [81/1556 (5%)]
# Epoch    0: i =    81 ,       5.9519 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18366
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [82/1556 (5%)]
# Epoch    0: i =    82 ,       5.9374 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19311
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [83/1556 (5%)]
# Epoch    0: i =    83 ,       5.9159 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20238
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [84/1556 (5%)]
# Epoch    0: i =    84 ,       5.8820 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20025
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [85/1556 (5%)]
# Epoch    0: i =    85 ,       5.8683 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19817
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [86/1556 (6%)]
# Epoch    0: i =    86 ,       5.8485 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19614
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [87/1556 (6%)]
# Epoch    0: i =    87 ,       5.8224 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19203
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [88/1556 (6%)]
# Epoch    0: i =    88 ,       5.7974 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19540
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [89/1556 (6%)]
# Epoch    0: i =    89 ,       5.7790 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19348
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [90/1556 (6%)]
# Epoch    0: i =    90 ,       5.7643 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19160
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [91/1556 (6%)]
# Epoch    0: i =    91 ,       5.7372 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18976
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [92/1556 (6%)]
# Epoch    0: i =    92 ,       5.7208 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18796
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [93/1556 (6%)]
# Epoch    0: i =    93 ,       5.7067 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18447
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [94/1556 (6%)]
# Epoch    0: i =    94 ,       5.7004 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18581
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [95/1556 (6%)]
# Epoch    0: i =    95 ,       5.6771 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18235
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [96/1556 (6%)]
# Epoch    0: i =    96 ,       5.6689 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17902
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [97/1556 (6%)]
# Epoch    0: i =    97 ,       5.6526 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17747
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [98/1556 (6%)]
# Epoch    0: i =    98 ,       5.6369 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17595
# predictions shape  torch.Size([6, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [99/1556 (6%)]
# Epoch    0: i =    99 ,       5.6122 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17446
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [100/1556 (6%)]
# Epoch    0: i =   100 ,       5.6037 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17300
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [101/1556 (6%)]
# Epoch    0: i =   101 ,       5.5981 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17157
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [102/1556 (7%)]
# Epoch    0: i =   102 ,       5.5793 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17232
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [103/1556 (7%)]
# Epoch    0: i =   103 ,       5.5495 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17091
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [104/1556 (7%)]
# Epoch    0: i =   104 ,       5.5375 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17387
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [105/1556 (7%)]
# Epoch    0: i =   105 ,       5.5240 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17537
# predictions shape  torch.Size([7, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [106/1556 (7%)]
# Epoch    0: i =   106 ,       5.5046 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17824
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [107/1556 (7%)]
# Epoch    0: i =   107 ,       5.5023 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17683
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [108/1556 (7%)]
# Epoch    0: i =   108 ,       5.4851 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17545
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [109/1556 (7%)]
# Epoch    0: i =   109 ,       5.4832 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17674
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [110/1556 (7%)]
# Epoch    0: i =   110 ,       5.4689 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17667
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [111/1556 (7%)]
# Epoch    0: i =   111 ,       5.4617 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17392
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [112/1556 (7%)]
# Epoch    0: i =   112 ,       5.4506 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17138
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [113/1556 (7%)]
# Epoch    0: i =   113 ,       5.4422 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17014
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [114/1556 (7%)]
# Epoch    0: i =   114 ,       5.4403 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16891
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [115/1556 (7%)]
# Epoch    0: i =   115 ,       5.4306 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17029
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [116/1556 (7%)]
# Epoch    0: i =   116 ,       5.4254 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16779
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [117/1556 (8%)]
# Epoch    0: i =   117 ,       5.4234 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16907
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [118/1556 (8%)]
# Epoch    0: i =   118 ,       5.4135 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17410
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [119/1556 (8%)]
# Epoch    0: i =   119 ,       5.4006 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17292
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([7, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [120/1556 (8%)]
# Epoch    0: i =   120 ,       5.4016 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17279
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([9, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [121/1556 (8%)]
# Epoch    0: i =   121 ,       5.3978 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17164
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [122/1556 (8%)]
# Epoch    0: i =   122 ,       5.3813 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17050
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [123/1556 (8%)]
# Epoch    0: i =   123 ,       5.3711 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16939
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [124/1556 (8%)]
# Epoch    0: i =   124 ,       5.3696 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16828
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [125/1556 (8%)]
# Epoch    0: i =   125 ,       5.3637 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16720
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [126/1556 (8%)]
# Epoch    0: i =   126 ,       5.3540 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16612
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [127/1556 (8%)]
# Epoch    0: i =   127 ,       5.3465 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16507
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [128/1556 (8%)]
# Epoch    0: i =   128 ,       5.3297 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16392
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [129/1556 (8%)]
# Epoch    0: i =   129 ,       5.3128 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16289
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([11, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [130/1556 (8%)]
# Epoch    0: i =   130 ,       5.3143 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16188
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([9, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [131/1556 (8%)]
# Epoch    0: i =   131 ,       5.3014 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16088
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [132/1556 (8%)]
# Epoch    0: i =   132 ,       5.2968 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15990
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [133/1556 (9%)]
# Epoch    0: i =   133 ,       5.2871 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15892
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [134/1556 (9%)]
# Epoch    0: i =   134 ,       5.2793 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15796
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [135/1556 (9%)]
# Epoch    0: i =   135 ,       5.2621 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15702
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [136/1556 (9%)]
# Epoch    0: i =   136 ,       5.2587 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15608
# predictions shape  torch.Size([6, 6])
# bboxes shape  torch.Size([4, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [137/1556 (9%)]
# Epoch    0: i =   137 ,       5.2527 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15516
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [138/1556 (9%)]
# Epoch    0: i =   138 ,       5.2483 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15425
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [139/1556 (9%)]
# Epoch    0: i =   139 ,       5.2412 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15335
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [140/1556 (9%)]
# Epoch    0: i =   140 ,       5.2344 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15247
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [141/1556 (9%)]
# Epoch    0: i =   141 ,       5.2267 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15159
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [142/1556 (9%)]
# Epoch    0: i =   142 ,       5.2232 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15073
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [143/1556 (9%)]
# Epoch    0: i =   143 ,       5.2188 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14987
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [144/1556 (9%)]
# Epoch    0: i =   144 ,       5.2164 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14903
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [145/1556 (9%)]
# Epoch    0: i =   145 ,       5.2032 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14820
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [146/1556 (9%)]
# Epoch    0: i =   146 ,       5.1986 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14737
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [147/1556 (9%)]
# Epoch    0: i =   147 ,       5.1945 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14859
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [148/1556 (10%)]
# Epoch    0: i =   148 ,       5.1900 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14978
# predictions shape  torch.Size([5, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [149/1556 (10%)]
# Epoch    0: i =   149 ,       5.1902 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14897
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([3, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [150/1556 (10%)]
# Epoch    0: i =   150 ,       5.2289 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14816
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [151/1556 (10%)]
# Epoch    0: i =   151 ,       5.2341 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15325
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [152/1556 (10%)]
# Epoch    0: i =   152 ,       5.2158 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15829
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [153/1556 (10%)]
# Epoch    0: i =   153 ,       5.2126 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15744
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [154/1556 (10%)]
# Epoch    0: i =   154 ,       5.1966 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16240
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [155/1556 (10%)]
# Epoch    0: i =   155 ,       5.1919 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16728
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [156/1556 (10%)]
# Epoch    0: i =   156 ,       5.1837 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17210
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [157/1556 (10%)]
# Epoch    0: i =   157 ,       5.1818 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17119
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [158/1556 (10%)]
# Epoch    0: i =   158 ,       5.1753 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17030
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [159/1556 (10%)]
# Epoch    0: i =   159 ,       5.1611 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17504
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [160/1556 (10%)]
# Epoch    0: i =   160 ,       5.1547 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17971
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [161/1556 (10%)]
# Epoch    0: i =   161 ,       5.1452 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17878
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [162/1556 (10%)]
# Epoch    0: i =   162 ,       5.1413 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17786
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [163/1556 (10%)]
# Epoch    0: i =   163 ,       5.1340 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18243
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [164/1556 (11%)]
# Epoch    0: i =   164 ,       5.1181 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18697
# predictions shape  torch.Size([0, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [165/1556 (11%)]
# Epoch    0: i =   165 ,       5.1038 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18594
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [166/1556 (11%)]
# Epoch    0: i =   166 ,       5.0906 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19041
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [167/1556 (11%)]
# Epoch    0: i =   167 ,       5.0923 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19484
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [168/1556 (11%)]
# Epoch    0: i =   168 ,       5.0841 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19386
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [169/1556 (11%)]
# Epoch    0: i =   169 ,       5.0787 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19820
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [170/1556 (11%)]
# Epoch    0: i =   170 ,       5.0742 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19985
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [171/1556 (11%)]
# Epoch    0: i =   171 ,       5.0721 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19886
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [172/1556 (11%)]
# Epoch    0: i =   172 ,       5.0644 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19788
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [173/1556 (11%)]
# Epoch    0: i =   173 ,       5.0588 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19951
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [174/1556 (11%)]
# Epoch    0: i =   174 ,       5.0546 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20111
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [175/1556 (11%)]
# Epoch    0: i =   175 ,       5.0524 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20271
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [176/1556 (11%)]
# Epoch    0: i =   176 ,       5.0475 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20684
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [177/1556 (11%)]
# Epoch    0: i =   177 ,       5.0429 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21093
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [178/1556 (11%)]
# Epoch    0: i =   178 ,       5.0404 ms elapsed
# ...
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1497/1556 (96%)]
# Epoch    0: i =  1497 ,       4.5709 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31294
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1498/1556 (96%)]
# Epoch    0: i =  1498 ,       4.5705 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31338
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1499/1556 (96%)]
# Epoch    0: i =  1499 ,       4.5700 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31383
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1500/1556 (96%)]
# Epoch    0: i =  1500 ,       4.5702 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31364
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1501/1556 (96%)]
# Epoch    0: i =  1501 ,       4.5709 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31344
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1502/1556 (97%)]
# Epoch    0: i =  1502 ,       4.5704 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31325
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1503/1556 (97%)]
# Epoch    0: i =  1503 ,       4.5703 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31337
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1504/1556 (97%)]
# Epoch    0: i =  1504 ,       4.5701 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31382
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1505/1556 (97%)]
# Epoch    0: i =  1505 ,       4.5697 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31426
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1506/1556 (97%)]
# Epoch    0: i =  1506 ,       4.5693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31471
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1507/1556 (97%)]
# Epoch    0: i =  1507 ,       4.5693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31515
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1508/1556 (97%)]
# Epoch    0: i =  1508 ,       4.5693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31527
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([2, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1509/1556 (97%)]
# Epoch    0: i =  1509 ,       4.5689 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31540
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1510/1556 (97%)]
# Epoch    0: i =  1510 ,       4.5686 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31520
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1511/1556 (97%)]
# Epoch    0: i =  1511 ,       4.5685 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31564
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1512/1556 (97%)]
# Epoch    0: i =  1512 ,       4.5684 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31608
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1513/1556 (97%)]
# Epoch    0: i =  1513 ,       4.5680 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31653
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1514/1556 (97%)]
# Epoch    0: i =  1514 ,       4.5675 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31633
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1515/1556 (97%)]
# Epoch    0: i =  1515 ,       4.5674 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31677
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1516/1556 (97%)]
# Epoch    0: i =  1516 ,       4.5672 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31721
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1517/1556 (97%)]
# Epoch    0: i =  1517 ,       4.5668 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31766
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1518/1556 (98%)]
# Epoch    0: i =  1518 ,       4.5664 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31809
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1519/1556 (98%)]
# Epoch    0: i =  1519 ,       4.5663 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31853
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1520/1556 (98%)]
# Epoch    0: i =  1520 ,       4.5662 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31897
# predictions shape  torch.Size([4, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1521/1556 (98%)]
# Epoch    0: i =  1521 ,       4.5659 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31941
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1522/1556 (98%)]
# Epoch    0: i =  1522 ,       4.5655 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31921
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1523/1556 (98%)]
# Epoch    0: i =  1523 ,       4.5665 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31902
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1524/1556 (98%)]
# Epoch    0: i =  1524 ,       4.5676 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31945
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1525/1556 (98%)]
# Epoch    0: i =  1525 ,       4.5679 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31989
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1526/1556 (98%)]
# Epoch    0: i =  1526 ,       4.5682 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32033
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1527/1556 (98%)]
# Epoch    0: i =  1527 ,       4.5682 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32076
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1528/1556 (98%)]
# Epoch    0: i =  1528 ,       4.5679 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32120
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1529/1556 (98%)]
# Epoch    0: i =  1529 ,       4.5677 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32163
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1530/1556 (98%)]
# Epoch    0: i =  1530 ,       4.5681 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32207
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1531/1556 (98%)]
# Epoch    0: i =  1531 ,       4.5679 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32250
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1532/1556 (98%)]
# Epoch    0: i =  1532 ,       4.5677 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32293
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1533/1556 (99%)]
# Epoch    0: i =  1533 ,       4.5675 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32336
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1534/1556 (99%)]
# Epoch    0: i =  1534 ,       4.5682 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32380
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1535/1556 (99%)]
# Epoch    0: i =  1535 ,       4.5680 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32423
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1536/1556 (99%)]
# Epoch    0: i =  1536 ,       4.5677 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32466
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1537/1556 (99%)]
# Epoch    0: i =  1537 ,       4.5684 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32509
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1538/1556 (99%)]
# Epoch    0: i =  1538 ,       4.5693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32552
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1539/1556 (99%)]
# Epoch    0: i =  1539 ,       4.5691 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32595
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1540/1556 (99%)]
# Epoch    0: i =  1540 ,       4.5692 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32637
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1541/1556 (99%)]
# Epoch    0: i =  1541 ,       4.5694 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32680
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1542/1556 (99%)]
# Epoch    0: i =  1542 ,       4.5693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32723
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1543/1556 (99%)]
# Epoch    0: i =  1543 ,       4.5690 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32766
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1544/1556 (99%)]
# Epoch    0: i =  1544 ,       4.5694 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32808
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1545/1556 (99%)]
# Epoch    0: i =  1545 ,       4.5693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32851
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1546/1556 (99%)]
# Epoch    0: i =  1546 ,       4.5692 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32893
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1547/1556 (99%)]
# Epoch    0: i =  1547 ,       4.5712 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32936
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1548/1556 (99%)]
# Epoch    0: i =  1548 ,       4.5710 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.32978
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1549/1556 (100%)]
# Epoch    0: i =  1549 ,       4.5708 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.33020
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1550/1556 (100%)]
# Epoch    0: i =  1550 ,       4.5704 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.33063
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1551/1556 (100%)]
# Epoch    0: i =  1551 ,       4.5707 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.33105
# predictions shape  torch.Size([1, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1552/1556 (100%)]
# Epoch    0: i =  1552 ,       4.5704 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.33147
# predictions shape  torch.Size([3, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1553/1556 (100%)]
# Epoch    0: i =  1553 ,       4.5701 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.33189
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1554/1556 (100%)]
# Epoch    0: i =  1554 ,       4.5693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.33231
# predictions shape  torch.Size([2, 6])
# bboxes shape  torch.Size([1, 6])
# inputs shape  torch.Size([1, 1, 320, 320])
#
# Test: [1555/1556 (100%)]
# Epoch    0: i =  1555 ,       4.5689 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.33273
# Loss/train None 0
# mAP@50/train None 0
# mAP@50/test 0.33272637038812636 0

# %%
#### The following is the net that will be quantized.... ####

# %%
class QuantNetwork(torch.nn.Module):

    def __init__(self,
                    in_channels = 4,
                    num_output = num_output):
        
        super().__init__()
        
        self.num_output = num_output
        
        self.backend_blocks = torch.nn.ModuleList([
            
            nn.Conv2d(in_channels, 16, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            
            nn.Conv2d(16, 32, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2,stride = 2),
            #nn.Dropout(0.2),

            nn.Conv2d(32, 32, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            
            nn.Conv2d(32, 64, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2,stride = 2),
            #nn.Dropout(0.2),

            nn.Conv2d(64, 64, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        
        ])

        self.head1_backend = torch.nn.ModuleList([

            nn.Conv2d(64,64, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            #nn.Dropout(0.2),

            nn.Conv2d(64,128, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            #nn.Dropout(0.2),
            
        ])

        self.head1_blocks = torch.nn.ModuleList([

            nn.Conv2d(128,128, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            #nn.Dropout(0.2),

            nn.Conv2d(128,128, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),

            nn.Conv2d(128,self.num_output, kernel_size=1, padding=0, stride=1, bias=False),
            nn.BatchNorm2d(self.num_output),
            nn.ReLU(),

        ])

        self.quant = QuantStub()
        self.dequant = DeQuantStub()

        """self.backend_blocks[1].synapse.weight.requires_grad = False #pool
        self.backend_blocks[6].synapse.weight.requires_grad = False #pool
        self.head2_backend[2].synapse.weight.requires_grad = False #unpool
        self.head2_backend[3].synapse.weight.requires_grad = False"""
    
    def forward(self,
        input
    ):

        count = []
        """for block in self.input_blocks:
            input = block(input)
            count.append(slayer.utils.event_rate(input))
            
        backend = input"""
        input = self.quant(input)
        backend = input
        for block in self.backend_blocks:
            backend = block(backend)
        
        h1_backend = backend
        for block in self.head1_backend:
            h1_backend = block(h1_backend)
        
        head1 = h1_backend
        for block in self.head1_blocks:
            head1 = block(head1)
            """if has_sparisty_loss and isinstance(block,
                                                slayer.block.sigma_delta.Conv):
                sparsity_monitor.append(head1)"""

            """if has_sparisty_loss and isinstance(block,
                                                slayer.block.sigma_delta.Conv):
                sparsity_monitor.append(head2)"""

        ## Get the summation or averaging over all the time steps, and preserve the last dimension of head1 tensor as time but Time = 1

        head1 = self.dequant(head1)

        return head1
    
    def fuse_model(self,quant_aware_train = False):
        # Specify which layers to fuse
        if quant_aware_train:
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU
            # Pooling layers do not need to be fused
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['7', '8', '9'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['10', '11', '12'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['14', '15', '16'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules_qat(self.head1_backend, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.head1_backend, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules_qat(self.head1_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.head1_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU
        
        else:
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU
            # Pooling layers do not need to be fused
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['7', '8', '9'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['10', '11', '12'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['14', '15', '16'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules(self.head1_backend, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.head1_backend, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules(self.head1_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.head1_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU

# %%
net = QuantNetwork(in_channels=in_channels,num_output=num_output)
net.to(torch.device("cuda:0"))
pretrained_ckpt_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/epoch_262_0.3226383599284339.pt"
load_model_only_with_necessary_keys_from_state_dict(net,pretrained_ckpt_path,is_full_checkpoint = True)
net.qconfig = torch.ao.quantization.get_default_qconfig('qnnpack')
net.to(torch.device("cpu"))
net.eval()
net.fuse_model()
net = torch.ao.quantization.prepare(net)
#N,C,H,W = 1,2,320,320
#input = torch.rand(N,C, H, W)
#net(input)
# Out:
# Skipping anchors due to mismatch in size or missing key.
# max value of the state_dict  tensor(177263., device='cuda:0')
# min value of the state dict  tensor(-13.3185, device='cuda:0')
# average value of state dict  tensor(3.6925, device='cuda:0')
# Model loaded with available pre-trained weights.
# /tmp/ipykernel_68322/3181773012.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_full_checkpoint = torch.load(pretained_ckpt_path)

# %%
#to identify the limits for activation quantization.
max = 0
min = 0
with torch.no_grad():
    for i, (inputs, targets, bboxes) in enumerate(train_loader):
        # Pass a batch of images through the model
        inputs = inputs.permute(4,0,1,2,3)
        inputs = inputs.squeeze(0)
        inputs = inputs.to('cpu')
        if inputs.max() > max:
            max = inputs.max()
        elif inputs.min() < min:
            min = inputs.min()  
        predictions = net(inputs)

# %%
print(min)
# Out:
# tensor(-1.)

# %%
for key in net.state_dict().keys():
    print(key)

# %%
model_int8 = torch.ao.quantization.convert(net)
model_int8.eval()
# Out:
# QuantNetwork(
#   (backend_blocks): ModuleList(
#     (0): QuantizedConvReLU2d(1, 16, kernel_size=(3, 3), stride=(2, 2), scale=0.04696192592382431, zero_point=0, padding=(1, 1))
#     (1-2): 2 x Identity()
#     (3): QuantizedConvReLU2d(16, 32, kernel_size=(3, 3), stride=(1, 1), scale=0.06214122101664543, zero_point=0, padding=(1, 1))
#     (4-5): 2 x Identity()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): QuantizedConvReLU2d(32, 32, kernel_size=(3, 3), stride=(2, 2), scale=0.034173861145973206, zero_point=0, padding=(1, 1))
#     (8-9): 2 x Identity()
#     (10): QuantizedConvReLU2d(32, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.0248524509370327, zero_point=0, padding=(1, 1))
#     (11-12): 2 x Identity()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(2, 2), scale=0.061386145651340485, zero_point=0, padding=(1, 1))
#     (15-16): 2 x Identity()
#   )
#   (head1_backend): ModuleList(
#     (0): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.04559260234236717, zero_point=0, padding=(1, 1))
#     (1-2): 2 x Identity()
#     (3): QuantizedConvReLU2d(64, 128, kernel_size=(3, 3), stride=(2, 2), scale=0.03279571235179901, zero_point=0, padding=(1, 1))
#     (4-5): 2 x Identity()
#   )
#   (head1_blocks): ModuleList(
#     (0): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.025142045691609383, zero_point=0, padding=(1, 1))
#     (1-2): 2 x Identity()
#     (3): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.02426918037235737, zero_point=0, padding=(1, 1))
#     (4-5): 2 x Identity()
#     (6): QuantizedConv2d(128, 21, kernel_size=(1, 1), stride=(1, 1), scale=0.2102385014295578, zero_point=181, bias=False)
#     (7): QuantizedBatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#   )
#   (quant): Quantize(scale=tensor([0.0078]), zero_point=tensor([128]), dtype=torch.quint8)
#   (dequant): DeQuantize()
# )

# %%
"""with torch.no_grad():
    for i, (inputs, targets, bboxes) in enumerate(train_loader):
        # Pass a batch of images through the model
        inputs = inputs.permute(4,0,1,2,3)
        inputs = inputs.squeeze(0)
        inputs = inputs.to('cpu')
        predictions = net(inputs)"""

# %%
#pretrained_model_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/epoch_386_0.31518240416279664.pt"
#pretrained_model_info = torch.load(pretrained_model_path,map_location='cpu')
#model_state_dict = pretrained_model_info["model_state_dict"]
#net.load_state_dict(model_state_dict)
#net.to(torch.device("cuda:0"))
#load_model_only_with_necessary_keys_from_state_dict(net,pretrained_model_path,is_full_checkpoint = True)

# %%
"""epoch = 0
t_st = datetime.now()

with torch.no_grad():
        
        for i, (inputs, targets, bboxes) in enumerate(test_loader):

                #start
                inputs = inputs.permute(4,0,1,2,3)
          
                inputs = inputs.squeeze(0)

                inputs = inputs.to('cpu')
                predictions, counts = net(inputs, None)
      

                predictions = [prediction.unsqueeze(-1) for prediction in predictions]
                
                #predictions = [torch.sum(prediction,dim=-1).unsqueeze(-1) for prediction in predictions]

                loss, loss_distr = yolo_loss(predictions, targets)

                # MAP calculations
                T = 1 #inputs.shape[-1]
                try:
                    predictions = torch.concat([net.yolo(p, a) for (p, a)
                        in zip(predictions, net.anchors)],dim=1)
                except RuntimeError:
                    print('Runtime error on MAP predictions calculation.'
                            'continuing')
                    continue

                predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)
                                for t in range(T)]
                for t in range(T):
                    ap_stats.update(predictions[t], bboxes[t])
                    #end

                stats.testing.loss_sum += loss.item() * inputs.shape[0]
                stats.testing.num_samples += inputs.shape[0]
                stats.testing.correct_samples = ap_stats[:] * stats.testing.num_samples

                processed = i * test_loader.batch_size
                total = len(test_loader.dataset)
                time_elapsed = (datetime.now() - t_st).total_seconds()
                samples_sec = time_elapsed / (i + 1) / test_loader.batch_size
                header_list = [f'Test: [{processed}/{total} '
                                    f'({100.0 * processed / total:.0f}%)]']
                header_list += ['Event Rate: ['
                                        + ', '.join([f'{c.item():.2f}'
                                                    for c in counts[0]]) + ']']
                header_list += [f'Coord loss: {loss_distr[0].item()}']
                header_list += [f'Obj   loss: {loss_distr[1].item()}']
                header_list += [f'NoObj loss: {loss_distr[2].item()}']
                header_list += [f'Class loss: {loss_distr[3].item()}']
                header_list += [f'IOU   loss: {loss_distr[4].item()}']
                stats.print(epoch, i, samples_sec, header=header_list)
                #functional.reset_net(net)

        print("Loss/train", stats.training.loss,epoch)
        print('mAP@50/train',stats.training.accuracy,epoch)
        print('mAP@50/test', stats.testing.accuracy, epoch)"""
# Out:
# 'epoch = 0\nt_st = datetime.now()\n\nwith torch.no_grad():\n        \n        for i, (inputs, targets, bboxes) in enumerate(test_loader):\n\n                #start\n                inputs = inputs.permute(4,0,1,2,3)\n          \n                inputs = inputs.squeeze(0)\n\n                inputs = inputs.to(\'cpu\')\n                predictions, counts = net(inputs, None)\n      \n\n                predictions = [prediction.unsqueeze(-1) for prediction in predictions]\n                \n                #predictions = [torch.sum(prediction,dim=-1).unsqueeze(-1) for prediction in predictions]\n\n                loss, loss_distr = yolo_loss(predictions, targets)\n\n                # MAP calculations\n                T = 1 #inputs.shape[-1]\n                try:\n                    predictions = torch.concat([net.yolo(p, a) for (p, a)\n                        in zip(predictions, net.anchors)],dim=1)\n                except RuntimeError:\n                    print(\'Runtime error on MAP predictions calculation.\'\n                            \'continuing\')\n                    continue\n\n                predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)\n                                for t in range(T)]\n                for t in range(T):\n                    ap_stats.update(predictions[t], bboxes[t])\n                    #end\n\n                stats.testing.loss_sum += loss.item() * inputs.shape[0]\n                stats.testing.num_samples += inputs.shape[0]\n                stats.testing.correct_samples = ap_stats[:] * stats.testing.num_samples\n\n                processed = i * test_loader.batch_size\n                total = len(test_loader.dataset)\n                time_elapsed = (datetime.now() - t_st).total_seconds()\n                samples_sec = time_elapsed / (i + 1) / test_loader.batch_size\n                header_list = [f\'Test: [{processed}/{total} \'\n                                    f\'({100.0 * processed / total:.0f}%)]\']\n                header_list += [\'Event Rate: [\'\n                                        + \', \'.join([f\'{c.item():.2f}\'\n                                                    for c in counts[0]]) + \']\']\n                header_list += [f\'Coord loss: {loss_distr[0].item()}\']\n                header_list += [f\'Obj   loss: {loss_distr[1].item()}\']\n                header_list += [f\'NoObj loss: {loss_distr[2].item()}\']\n                header_list += [f\'Class loss: {loss_distr[3].item()}\']\n                header_list += [f\'IOU   loss: {loss_distr[4].item()}\']\n                stats.print(epoch, i, samples_sec, header=header_list)\n                #functional.reset_net(net)\n\n        print("Loss/train", stats.training.loss,epoch)\n        print(\'mAP@50/train\',stats.training.accuracy,epoch)\n        print(\'mAP@50/test\', stats.testing.accuracy, epoch)'

# %%
"""net.qconfig = torch.ao.quantization.get_default_qconfig('qnnpack')
net.fuse_model()
net_prepared = torch.ao.quantization.prepare(net)
with torch.no_grad():
    for i, (inputs, targets, bboxes) in enumerate(train_loader):
        # Pass a batch of images through the model
        inputs = inputs.permute(4,0,1,2,3)
        inputs = inputs.squeeze(0)
        inputs = inputs.to('cpu')
        predictions = net_prepared(inputs)
temp = torch.load("/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/qat_checkpoints/epoch_145_0.3345367681206545.pt")
net_prepared.load_state_dict(temp["model_state_dict"])
model_int8 = torch.ao.quantization.convert(net_prepared)
model_int8.eval()"""
# Out:
# 'net.qconfig = torch.ao.quantization.get_default_qconfig(\'qnnpack\')\nnet.fuse_model()\nnet_prepared = torch.ao.quantization.prepare(net)\nwith torch.no_grad():\n    for i, (inputs, targets, bboxes) in enumerate(train_loader):\n        # Pass a batch of images through the model\n        inputs = inputs.permute(4,0,1,2,3)\n        inputs = inputs.squeeze(0)\n        inputs = inputs.to(\'cpu\')\n        predictions = net_prepared(inputs)\ntemp = torch.load("/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/qat_checkpoints/epoch_145_0.3345367681206545.pt")\nnet_prepared.load_state_dict(temp["model_state_dict"])\nmodel_int8 = torch.ao.quantization.convert(net_prepared)\nmodel_int8.eval()'

# %%
model_int8.backend_blocks[0].weight
# Out:
# <bound method Conv2d.weight of QuantizedConvReLU2d(1, 16, kernel_size=(3, 3), stride=(2, 2), scale=0.042458146810531616, zero_point=0, padding=(1, 1))>

# %%
print(model_int8.backend_blocks[0].weight())
# Out:
# tensor([[[[-0.0236, -0.0117,  0.0025],
#           [-0.0205,  0.0151,  0.0079],
#           [ 0.0082,  0.0176,  0.0095]]],
#
#
#         [[[ 0.0060, -0.0192,  0.0255],
#           [ 0.0117, -0.0088, -0.0173],
#           [ 0.0299, -0.0221, -0.0044]]],
#
#
#         [[[ 0.0003, -0.0123, -0.0044],
#           [ 0.0236,  0.0085, -0.0054],
#           [ 0.0013,  0.0060, -0.0123]]],
#
#
#         [[[-0.0025,  0.0038,  0.0028],
#           [-0.0003, -0.0022, -0.0013],
#           [-0.0079,  0.0003, -0.0016]]],
#
#
#         [[[ 0.0334,  0.0095, -0.0050],
#           [ 0.0123, -0.0076, -0.0095],
#           [-0.0047, -0.0044, -0.0284]]],
#
#
#         [[[-0.0063, -0.0066,  0.0082],
#           [-0.0066,  0.0032,  0.0129],
#           [-0.0217,  0.0107,  0.0019]]],
#
#
#         [[[-0.0003, -0.0035, -0.0025],
#           [ 0.0006, -0.0057, -0.0019],
#           [ 0.0003, -0.0016,  0.0013]]],
#
#
#         [[[-0.0006, -0.0003,  0.0028],
#           [-0.0013,  0.0003,  0.0013],
#           [-0.0032, -0.0113,  0.0013]]],
#
#
#         [[[-0.0047,  0.0199, -0.0032],
#           [ 0.0120,  0.0035, -0.0113],
#           [-0.0041, -0.0258,  0.0032]]],
#
#
#         [[[ 0.0009,  0.0233, -0.0013],
#           [-0.0085,  0.0186,  0.0113],
#           [-0.0391, -0.0063, -0.0032]]],
#
#
#         [[[ 0.0136, -0.0148,  0.0208],
#           [-0.0227, -0.0400,  0.0113],
#           [ 0.0192,  0.0142, -0.0113]]],
#
#
#         [[[-0.0025, -0.0006, -0.0003],
#           [ 0.0022,  0.0022, -0.0003],
#           [ 0.0013,  0.0013,  0.0028]]],
#
#
#         [[[-0.0035, -0.0120, -0.0287],
#           [ 0.0195, -0.0032, -0.0158],
#           [-0.0006,  0.0315,  0.0082]]],
#
#
#         [[[-0.0009,  0.0000,  0.0009],
#           [-0.0079, -0.0025,  0.0003],
#           [-0.0019,  0.0025,  0.0000]]],
#
#
#         [[[-0.0060, -0.0262,  0.0186],
#           [-0.0167,  0.0016,  0.0233],
#           [-0.0028,  0.0003,  0.0101]]],
#
#
#         [[[ 0.0028,  0.0101,  0.0076],
#           [ 0.0022,  0.0079, -0.0095],
#           [ 0.0013, -0.0145, -0.0013]]]], size=(16, 1, 3, 3),
#        dtype=torch.qint8, quantization_scheme=torch.per_tensor_affine,
#        scale=0.00031511872657574713, zero_point=0)

# %%
stats = slayer.utils.LearningStats(accuracy_str='AP@0.5')
ap_stats = metrics.APstats(iou_threshold=0.5)
stats.update()
epoch = 0
conf_thres = 0.5
t_st = datetime.now()
with torch.no_grad():
        
        for i, (inputs, targets, bboxes) in enumerate(test_loader):
                
                """"inputs = inputs.permute(4,0,1,2,3)
                inputs = inputs.to(device)
                predictions, counts = net(inputs)

                T = 1
                predictions = [utils.nms(predictions[..., t],conf_threshold = args.conf_thres)
                    for t in range(T)]
                for t in range(T):
                    ap_stats.update(predictions[t], bboxes[t])"""

                #start
                inputs = inputs.permute(4,0,1,2,3)
          
                inputs = inputs.squeeze(0)

                inputs = inputs.to('cpu')

                predictions = model_int8(inputs)

                print("shapeeeeeeeeeeeeeee ",predictions.shape)
                

                predictions = yolo_raw(predictions)
                predictions = [predictions]

                print("predictionss .... ",predictions[0].shape)
      
                predictions = [prediction.unsqueeze(-1) for prediction in predictions]
                
                #predictions = [torch.sum(prediction,dim=-1).unsqueeze(-1) for prediction in predictions]
                
                #loss, loss_distr = yolo_loss(predictions, targets)

                # MAP calculations
                T = 1 #inputs.shape[-1]
                try:
                    predictions = torch.concat([yolo(p, a) for (p, a)
                        in zip(predictions, net_dummy.anchors.to(torch.device("cpu")))],dim=1)
                except RuntimeError:
                    print('Runtime error on MAP predictions calculation.'
                            'continuing')
                    continue

                predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)
                                for t in range(T)]
                for t in range(T):
                    ap_stats.update(predictions[t], bboxes[t])
                    #end

                stats.testing.num_samples += inputs.shape[0]
                stats.testing.correct_samples = ap_stats[:] * stats.testing.num_samples

                processed = i * test_loader.batch_size
                total = len(test_loader.dataset)
                time_elapsed = (datetime.now() - t_st).total_seconds()
                samples_sec = time_elapsed / (i + 1) / test_loader.batch_size
                header_list = [f'Test: [{processed}/{total} '
                                    f'({100.0 * processed / total:.0f}%)]']
  
                stats.print(epoch, i, samples_sec, header=header_list)
                #functional.reset_net(net)

        print('mAP@50/train',stats.training.accuracy,epoch)
        print('mAP@50/test', stats.testing.accuracy, epoch)
# Out:
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [0/1556 (0%)]
# Epoch    0: i =     0 ,      48.1880 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.99667
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1/1556 (0%)]
# Epoch    0: i =     1 ,      27.9260 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.50583
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [2/1556 (0%)]
# Epoch    0: i =     2 ,      21.1600 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34222
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [3/1556 (0%)]
# Epoch    0: i =     3 ,      17.6345 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26042
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [4/1556 (0%)]
# Epoch    0: i =     4 ,      15.6294 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.40783
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [5/1556 (0%)]
# Epoch    0: i =     5 ,      14.1457 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34236
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [6/1556 (0%)]
# Epoch    0: i =     6 ,      13.0900 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29560
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [7/1556 (0%)]
# Epoch    0: i =     7 ,      12.3169 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26052
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [8/1556 (1%)]
# Epoch    0: i =     8 ,      11.6826 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.23324
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [9/1556 (1%)]
# Epoch    0: i =     9 ,      11.2259 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21142
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [10/1556 (1%)]
# Epoch    0: i =    10 ,      10.7806 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28288
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [11/1556 (1%)]
# Epoch    0: i =    11 ,      10.4233 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26056
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [12/1556 (1%)]
# Epoch    0: i =    12 ,      10.1889 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.24167
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [13/1556 (1%)]
# Epoch    0: i =    13 ,       9.9285 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.22548
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [14/1556 (1%)]
# Epoch    0: i =    14 ,       9.7677 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21144
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [15/1556 (1%)]
# Epoch    0: i =    15 ,       9.5742 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19917
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [16/1556 (1%)]
# Epoch    0: i =    16 ,       9.4334 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18833
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [17/1556 (1%)]
# Epoch    0: i =    17 ,       9.2723 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17787
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [18/1556 (1%)]
# Epoch    0: i =    18 ,       9.1162 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16930
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [19/1556 (1%)]
# Epoch    0: i =    19 ,       9.0295 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16158
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [20/1556 (1%)]
# Epoch    0: i =    20 ,       8.9289 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15460
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [21/1556 (1%)]
# Epoch    0: i =    21 ,       8.8230 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14826
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [22/1556 (1%)]
# Epoch    0: i =    22 ,       8.7082 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14181
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [23/1556 (1%)]
# Epoch    0: i =    23 ,       8.6109 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13653
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [24/1556 (2%)]
# Epoch    0: i =    24 ,       8.5377 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13107
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [25/1556 (2%)]
# Epoch    0: i =    25 ,       8.5318 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12660
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [26/1556 (2%)]
# Epoch    0: i =    26 ,       8.5083 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12247
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [27/1556 (2%)]
# Epoch    0: i =    27 ,       8.4316 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11810
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [28/1556 (2%)]
# Epoch    0: i =    28 ,       8.3966 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12109
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [29/1556 (2%)]
# Epoch    0: i =    29 ,       8.3430 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12389
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [30/1556 (2%)]
# Epoch    0: i =    30 ,       8.2876 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13296
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [31/1556 (2%)]
# Epoch    0: i =    31 ,       8.2634 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12927
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [32/1556 (2%)]
# Epoch    0: i =    32 ,       8.2270 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13157
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [33/1556 (2%)]
# Epoch    0: i =    33 ,       8.1984 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13373
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [34/1556 (2%)]
# Epoch    0: i =    34 ,       8.1631 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13576
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [35/1556 (2%)]
# Epoch    0: i =    35 ,       8.1210 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14324
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [36/1556 (2%)]
# Epoch    0: i =    36 ,       8.1066 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13977
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [37/1556 (2%)]
# Epoch    0: i =    37 ,       8.0659 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13649
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [38/1556 (2%)]
# Epoch    0: i =    38 ,       8.0415 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13338
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [39/1556 (3%)]
# Epoch    0: i =    39 ,       8.0060 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13042
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [40/1556 (3%)]
# Epoch    0: i =    40 ,       7.9670 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12724
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [41/1556 (3%)]
# Epoch    0: i =    41 ,       7.9357 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12456
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [42/1556 (3%)]
# Epoch    0: i =    42 ,       7.8997 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12202
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [43/1556 (3%)]
# Epoch    0: i =    43 ,       7.8693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11924
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [44/1556 (3%)]
# Epoch    0: i =    44 ,       7.8313 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11659
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [45/1556 (3%)]
# Epoch    0: i =    45 ,       7.8019 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11438
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [46/1556 (3%)]
# Epoch    0: i =    46 ,       7.7893 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11227
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [47/1556 (3%)]
# Epoch    0: i =    47 ,       7.7622 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11024
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [48/1556 (3%)]
# Epoch    0: i =    48 ,       7.7331 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.10799
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [49/1556 (3%)]
# Epoch    0: i =    49 ,       7.7133 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12576
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [50/1556 (3%)]
# Epoch    0: i =    50 ,       7.6856 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12359
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [51/1556 (3%)]
# Epoch    0: i =    51 ,       7.6655 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12150
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [52/1556 (3%)]
# Epoch    0: i =    52 ,       7.6406 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11949
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [53/1556 (3%)]
# Epoch    0: i =    53 ,       7.6224 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13573
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [54/1556 (3%)]
# Epoch    0: i =    54 ,       7.6027 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13115
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [55/1556 (4%)]
# Epoch    0: i =    55 ,       7.5812 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12911
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [56/1556 (4%)]
# Epoch    0: i =    56 ,       7.5586 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12714
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [57/1556 (4%)]
# Epoch    0: i =    57 ,       7.5317 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12524
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [58/1556 (4%)]
# Epoch    0: i =    58 ,       7.5170 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12315
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [59/1556 (4%)]
# Epoch    0: i =    59 ,       7.5047 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11966
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [60/1556 (4%)]
# Epoch    0: i =    60 ,       7.4953 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11776
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [61/1556 (4%)]
# Epoch    0: i =    61 ,       7.4996 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11616
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [62/1556 (4%)]
# Epoch    0: i =    62 ,       7.4808 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11460
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [63/1556 (4%)]
# Epoch    0: i =    63 ,       7.4700 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11309
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [64/1556 (4%)]
# Epoch    0: i =    64 ,       7.4555 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11163
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [65/1556 (4%)]
# Epoch    0: i =    65 ,       7.4401 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11021
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [66/1556 (4%)]
# Epoch    0: i =    66 ,       7.4309 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.10727
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [67/1556 (4%)]
# Epoch    0: i =    67 ,       7.4190 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.10597
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [68/1556 (4%)]
# Epoch    0: i =    68 ,       7.4135 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.10471
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [69/1556 (4%)]
# Epoch    0: i =    69 ,       7.4059 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.10348
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [70/1556 (4%)]
# Epoch    0: i =    70 ,       7.3893 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.10208
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [71/1556 (5%)]
# Epoch    0: i =    71 ,       7.3770 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.10072
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [72/1556 (5%)]
# Epoch    0: i =    72 ,       7.3664 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11255
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [73/1556 (5%)]
# Epoch    0: i =    73 ,       7.3604 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12405
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [74/1556 (5%)]
# Epoch    0: i =    74 ,       7.3608 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13525
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [75/1556 (5%)]
# Epoch    0: i =    75 ,       7.3649 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13993
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [76/1556 (5%)]
# Epoch    0: i =    76 ,       7.3606 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13836
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [77/1556 (5%)]
# Epoch    0: i =    77 ,       7.3512 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13684
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [78/1556 (5%)]
# Epoch    0: i =    78 ,       7.3549 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13536
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [79/1556 (5%)]
# Epoch    0: i =    79 ,       7.3502 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13391
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [80/1556 (5%)]
# Epoch    0: i =    80 ,       7.3533 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13249
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [81/1556 (5%)]
# Epoch    0: i =    81 ,       7.3462 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13093
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [82/1556 (5%)]
# Epoch    0: i =    82 ,       7.3345 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12958
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [83/1556 (5%)]
# Epoch    0: i =    83 ,       7.3380 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13955
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [84/1556 (5%)]
# Epoch    0: i =    84 ,       7.3200 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13796
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [85/1556 (5%)]
# Epoch    0: i =    85 ,       7.3140 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13658
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [86/1556 (6%)]
# Epoch    0: i =    86 ,       7.3076 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13523
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [87/1556 (6%)]
# Epoch    0: i =    87 ,       7.2971 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13245
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [88/1556 (6%)]
# Epoch    0: i =    88 ,       7.2958 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13646
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [89/1556 (6%)]
# Epoch    0: i =    89 ,       7.2943 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13517
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [90/1556 (6%)]
# Epoch    0: i =    90 ,       7.2970 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13390
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [91/1556 (6%)]
# Epoch    0: i =    91 ,       7.2871 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13266
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [92/1556 (6%)]
# Epoch    0: i =    92 ,       7.2822 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13145
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [93/1556 (6%)]
# Epoch    0: i =    93 ,       7.2754 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13405
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [94/1556 (6%)]
# Epoch    0: i =    94 ,       7.2635 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13639
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [95/1556 (6%)]
# Epoch    0: i =    95 ,       7.2593 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13389
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [96/1556 (6%)]
# Epoch    0: i =    96 ,       7.2472 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13148
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [97/1556 (6%)]
# Epoch    0: i =    97 ,       7.2365 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13039
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [98/1556 (6%)]
# Epoch    0: i =    98 ,       7.2360 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12931
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [99/1556 (6%)]
# Epoch    0: i =    99 ,       7.2259 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12825
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [100/1556 (6%)]
# Epoch    0: i =   100 ,       7.2181 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12721
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [101/1556 (6%)]
# Epoch    0: i =   101 ,       7.2114 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12619
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [102/1556 (7%)]
# Epoch    0: i =   102 ,       7.2003 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12735
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [103/1556 (7%)]
# Epoch    0: i =   103 ,       7.1968 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12635
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [104/1556 (7%)]
# Epoch    0: i =   104 ,       7.1874 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12536
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [105/1556 (7%)]
# Epoch    0: i =   105 ,       7.1829 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12729
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [106/1556 (7%)]
# Epoch    0: i =   106 ,       7.1779 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12631
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [107/1556 (7%)]
# Epoch    0: i =   107 ,       7.1682 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12535
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [108/1556 (7%)]
# Epoch    0: i =   108 ,       7.1656 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12441
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [109/1556 (7%)]
# Epoch    0: i =   109 ,       7.1604 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13085
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [110/1556 (7%)]
# Epoch    0: i =   110 ,       7.1595 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13707
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [111/1556 (7%)]
# Epoch    0: i =   111 ,       7.1567 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13895
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [112/1556 (7%)]
# Epoch    0: i =   112 ,       7.1507 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13697
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [113/1556 (7%)]
# Epoch    0: i =   113 ,       7.1471 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13600
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [114/1556 (7%)]
# Epoch    0: i =   114 ,       7.1417 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13505
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [115/1556 (7%)]
# Epoch    0: i =   115 ,       7.1399 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13411
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [116/1556 (7%)]
# Epoch    0: i =   116 ,       7.1422 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13593
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [117/1556 (8%)]
# Epoch    0: i =   117 ,       7.1375 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13410
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [118/1556 (8%)]
# Epoch    0: i =   118 ,       7.1459 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13221
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [119/1556 (8%)]
# Epoch    0: i =   119 ,       7.1449 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13134
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [120/1556 (8%)]
# Epoch    0: i =   120 ,       7.1481 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13151
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [121/1556 (8%)]
# Epoch    0: i =   121 ,       7.1527 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13147
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [122/1556 (8%)]
# Epoch    0: i =   122 ,       7.1569 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13062
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [123/1556 (8%)]
# Epoch    0: i =   123 ,       7.1767 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12979
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [124/1556 (8%)]
# Epoch    0: i =   124 ,       7.1748 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12897
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [125/1556 (8%)]
# Epoch    0: i =   125 ,       7.1711 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12816
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [126/1556 (8%)]
# Epoch    0: i =   126 ,       7.1664 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12737
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [127/1556 (8%)]
# Epoch    0: i =   127 ,       7.1657 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12658
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [128/1556 (8%)]
# Epoch    0: i =   128 ,       7.1576 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12570
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [129/1556 (8%)]
# Epoch    0: i =   129 ,       7.1545 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12483
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [130/1556 (8%)]
# Epoch    0: i =   130 ,       7.1492 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12408
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [131/1556 (8%)]
# Epoch    0: i =   131 ,       7.1398 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12334
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [132/1556 (8%)]
# Epoch    0: i =   132 ,       7.1350 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12261
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [133/1556 (9%)]
# Epoch    0: i =   133 ,       7.1278 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12188
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [134/1556 (9%)]
# Epoch    0: i =   134 ,       7.1274 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12117
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [135/1556 (9%)]
# Epoch    0: i =   135 ,       7.1206 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12037
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [136/1556 (9%)]
# Epoch    0: i =   136 ,       7.1146 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11968
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [137/1556 (9%)]
# Epoch    0: i =   137 ,       7.1129 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12056
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [138/1556 (9%)]
# Epoch    0: i =   138 ,       7.1082 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11988
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [139/1556 (9%)]
# Epoch    0: i =   139 ,       7.1065 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11920
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [140/1556 (9%)]
# Epoch    0: i =   140 ,       7.0988 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11843
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [141/1556 (9%)]
# Epoch    0: i =   141 ,       7.0921 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11778
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [142/1556 (9%)]
# Epoch    0: i =   142 ,       7.0920 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11713
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [143/1556 (9%)]
# Epoch    0: i =   143 ,       7.0878 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11648
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [144/1556 (9%)]
# Epoch    0: i =   144 ,       7.0861 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11585
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [145/1556 (9%)]
# Epoch    0: i =   145 ,       7.0819 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11522
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [146/1556 (9%)]
# Epoch    0: i =   146 ,       7.0759 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11460
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [147/1556 (9%)]
# Epoch    0: i =   147 ,       7.0775 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11602
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [148/1556 (10%)]
# Epoch    0: i =   148 ,       7.0764 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11540
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [149/1556 (10%)]
# Epoch    0: i =   149 ,       7.0758 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11479
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [150/1556 (10%)]
# Epoch    0: i =   150 ,       7.0758 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11419
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [151/1556 (10%)]
# Epoch    0: i =   151 ,       7.0713 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.11950
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [152/1556 (10%)]
# Epoch    0: i =   152 ,       7.0693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12474
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [153/1556 (10%)]
# Epoch    0: i =   153 ,       7.0755 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12409
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [154/1556 (10%)]
# Epoch    0: i =   154 ,       7.1038 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.12924
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [155/1556 (10%)]
# Epoch    0: i =   155 ,       7.1091 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13432
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [156/1556 (10%)]
# Epoch    0: i =   156 ,       7.1113 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13934
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [157/1556 (10%)]
# Epoch    0: i =   157 ,       7.1069 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13862
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [158/1556 (10%)]
# Epoch    0: i =   158 ,       7.1049 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.13791
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [159/1556 (10%)]
# Epoch    0: i =   159 ,       7.0980 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14283
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [160/1556 (10%)]
# Epoch    0: i =   160 ,       7.0913 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14769
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [161/1556 (10%)]
# Epoch    0: i =   161 ,       7.0902 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14694
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [162/1556 (10%)]
# Epoch    0: i =   162 ,       7.0858 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14620
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [163/1556 (10%)]
# Epoch    0: i =   163 ,       7.0838 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15095
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [164/1556 (11%)]
# Epoch    0: i =   164 ,       7.0808 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15567
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [165/1556 (11%)]
# Epoch    0: i =   165 ,       7.0737 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15481
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [166/1556 (11%)]
# Epoch    0: i =   166 ,       7.0724 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15945
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [167/1556 (11%)]
# Epoch    0: i =   167 ,       7.0693 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16404
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [168/1556 (11%)]
# Epoch    0: i =   168 ,       7.0666 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16323
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [169/1556 (11%)]
# Epoch    0: i =   169 ,       7.0674 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16774
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [170/1556 (11%)]
# Epoch    0: i =   170 ,       7.0675 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16955
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [171/1556 (11%)]
# Epoch    0: i =   171 ,       7.0699 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16873
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [172/1556 (11%)]
# Epoch    0: i =   172 ,       7.0654 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16791
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [173/1556 (11%)]
# Epoch    0: i =   173 ,       7.0655 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16969
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [174/1556 (11%)]
# Epoch    0: i =   174 ,       7.0821 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17146
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [175/1556 (11%)]
# Epoch    0: i =   175 ,       7.0818 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17320
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [176/1556 (11%)]
# Epoch    0: i =   176 ,       7.0793 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17749
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [177/1556 (11%)]
# Epoch    0: i =   177 ,       7.0804 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18173
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [178/1556 (11%)]
# Epoch    0: i =   178 ,       7.0830 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18594
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [179/1556 (12%)]
# Epoch    0: i =   179 ,       7.0803 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19010
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [180/1556 (12%)]
# Epoch    0: i =   180 ,       7.0822 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19421
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [181/1556 (12%)]
# Epoch    0: i =   181 ,       7.0777 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19828
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [182/1556 (12%)]
# Epoch    0: i =   182 ,       7.0775 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20232
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [183/1556 (12%)]
# Epoch    0: i =   183 ,       7.0774 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20631
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [184/1556 (12%)]
# Epoch    0: i =   184 ,       7.1068 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20535
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [185/1556 (12%)]
# Epoch    0: i =   185 ,       7.1026 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20441
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [186/1556 (12%)]
# Epoch    0: i =   186 ,       7.0987 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20347
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [187/1556 (12%)]
# Epoch    0: i =   187 ,       7.0983 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20254
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [188/1556 (12%)]
# Epoch    0: i =   188 ,       7.0949 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20643
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [189/1556 (12%)]
# Epoch    0: i =   189 ,       7.0963 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20550
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [190/1556 (12%)]
# Epoch    0: i =   190 ,       7.0926 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20934
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [191/1556 (12%)]
# Epoch    0: i =   191 ,       7.0913 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21315
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [192/1556 (12%)]
# Epoch    0: i =   192 ,       7.0906 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21219
# ...
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28730
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1493/1556 (96%)]
# Epoch    0: i =  1493 ,       6.7863 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28777
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1494/1556 (96%)]
# Epoch    0: i =  1494 ,       6.7860 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28823
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1495/1556 (96%)]
# Epoch    0: i =  1495 ,       6.7860 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28805
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1496/1556 (96%)]
# Epoch    0: i =  1496 ,       6.7859 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28787
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1497/1556 (96%)]
# Epoch    0: i =  1497 ,       6.7856 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28833
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1498/1556 (96%)]
# Epoch    0: i =  1498 ,       6.7856 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28879
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1499/1556 (96%)]
# Epoch    0: i =  1499 ,       6.7854 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28926
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1500/1556 (96%)]
# Epoch    0: i =  1500 ,       6.7854 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28972
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1501/1556 (96%)]
# Epoch    0: i =  1501 ,       6.7854 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28954
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1502/1556 (97%)]
# Epoch    0: i =  1502 ,       6.7856 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28936
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1503/1556 (97%)]
# Epoch    0: i =  1503 ,       6.7857 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28950
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1504/1556 (97%)]
# Epoch    0: i =  1504 ,       6.7858 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28996
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1505/1556 (97%)]
# Epoch    0: i =  1505 ,       6.7861 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29042
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1506/1556 (97%)]
# Epoch    0: i =  1506 ,       6.7862 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29088
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1507/1556 (97%)]
# Epoch    0: i =  1507 ,       6.7859 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29134
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1508/1556 (97%)]
# Epoch    0: i =  1508 ,       6.7859 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29148
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1509/1556 (97%)]
# Epoch    0: i =  1509 ,       6.7856 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29162
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1510/1556 (97%)]
# Epoch    0: i =  1510 ,       6.7856 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29144
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1511/1556 (97%)]
# Epoch    0: i =  1511 ,       6.7856 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29189
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1512/1556 (97%)]
# Epoch    0: i =  1512 ,       6.7853 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29235
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1513/1556 (97%)]
# Epoch    0: i =  1513 ,       6.7872 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29281
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1514/1556 (97%)]
# Epoch    0: i =  1514 ,       6.7870 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29263
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1515/1556 (97%)]
# Epoch    0: i =  1515 ,       6.7873 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29309
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1516/1556 (97%)]
# Epoch    0: i =  1516 ,       6.7871 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29354
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1517/1556 (97%)]
# Epoch    0: i =  1517 ,       6.7872 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29400
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1518/1556 (98%)]
# Epoch    0: i =  1518 ,       6.7871 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29445
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1519/1556 (98%)]
# Epoch    0: i =  1519 ,       6.7892 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29491
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1520/1556 (98%)]
# Epoch    0: i =  1520 ,       6.7891 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29473
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1521/1556 (98%)]
# Epoch    0: i =  1521 ,       6.7888 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29518
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1522/1556 (98%)]
# Epoch    0: i =  1522 ,       6.7890 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29500
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1523/1556 (98%)]
# Epoch    0: i =  1523 ,       6.7887 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29482
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1524/1556 (98%)]
# Epoch    0: i =  1524 ,       6.7888 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29527
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1525/1556 (98%)]
# Epoch    0: i =  1525 ,       6.7887 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29509
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1526/1556 (98%)]
# Epoch    0: i =  1526 ,       6.7884 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29554
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1527/1556 (98%)]
# Epoch    0: i =  1527 ,       6.7886 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29599
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1528/1556 (98%)]
# Epoch    0: i =  1528 ,       6.7884 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29644
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1529/1556 (98%)]
# Epoch    0: i =  1529 ,       6.7886 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29689
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1530/1556 (98%)]
# Epoch    0: i =  1530 ,       6.7887 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29734
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1531/1556 (98%)]
# Epoch    0: i =  1531 ,       6.7890 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29779
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1532/1556 (98%)]
# Epoch    0: i =  1532 ,       6.7893 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29824
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1533/1556 (99%)]
# Epoch    0: i =  1533 ,       6.7892 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29869
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1534/1556 (99%)]
# Epoch    0: i =  1534 ,       6.7896 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29913
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1535/1556 (99%)]
# Epoch    0: i =  1535 ,       6.7894 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29958
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1536/1556 (99%)]
# Epoch    0: i =  1536 ,       6.7894 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30003
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1537/1556 (99%)]
# Epoch    0: i =  1537 ,       6.7894 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30047
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1538/1556 (99%)]
# Epoch    0: i =  1538 ,       6.7912 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30092
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1539/1556 (99%)]
# Epoch    0: i =  1539 ,       6.7912 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30136
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1540/1556 (99%)]
# Epoch    0: i =  1540 ,       6.7911 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30181
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1541/1556 (99%)]
# Epoch    0: i =  1541 ,       6.7913 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30225
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1542/1556 (99%)]
# Epoch    0: i =  1542 ,       6.7910 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30269
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1543/1556 (99%)]
# Epoch    0: i =  1543 ,       6.7910 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30314
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1544/1556 (99%)]
# Epoch    0: i =  1544 ,       6.7911 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30358
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1545/1556 (99%)]
# Epoch    0: i =  1545 ,       6.7908 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30402
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1546/1556 (99%)]
# Epoch    0: i =  1546 ,       6.7908 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30445
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1547/1556 (99%)]
# Epoch    0: i =  1547 ,       6.7906 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30489
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1548/1556 (99%)]
# Epoch    0: i =  1548 ,       6.7905 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30471
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1549/1556 (100%)]
# Epoch    0: i =  1549 ,       6.7904 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30515
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1550/1556 (100%)]
# Epoch    0: i =  1550 ,       6.7901 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30559
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1551/1556 (100%)]
# Epoch    0: i =  1551 ,       6.7902 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30602
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1552/1556 (100%)]
# Epoch    0: i =  1552 ,       6.7899 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30646
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1553/1556 (100%)]
# Epoch    0: i =  1553 ,       6.7898 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30689
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1554/1556 (100%)]
# Epoch    0: i =  1554 ,       6.7896 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30733
# shapeeeeeeeeeeeeeee  torch.Size([1, 21, 5, 5])
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
#
# Test: [1555/1556 (100%)]
# Epoch    0: i =  1555 ,       6.7892 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.30776
# mAP@50/train None 0
# mAP@50/test 0.30776409379043695 0

# %%
model_filepath = "./torch_quantized_jit.pth"
torch.jit.save(torch.jit.script(model_int8), model_filepath)

# %%
loaded_jit_model = torch.load(model_filepath)
loaded_jit_model.to(torch.device('cpu'))

# %%
stats.update()

# %%
epoch = 0
t_st = datetime.now()
stats = slayer.utils.LearningStats(accuracy_str='AP@0.5')
ap_stats = metrics.APstats(iou_threshold=0.5)
stats.update()
with torch.no_grad():
        
        for i, (inputs, targets, bboxes) in enumerate(test_loader):
                
                """"inputs = inputs.permute(4,0,1,2,3)
                inputs = inputs.to(device)
                predictions, counts = net(inputs)

                T = 1
                predictions = [utils.nms(predictions[..., t],conf_threshold = args.conf_thres)
                    for t in range(T)]
                for t in range(T):
                    ap_stats.update(predictions[t], bboxes[t])"""

                #start
                inputs = inputs.permute(4,0,1,2,3)
          
                inputs = inputs.squeeze(0)

                inputs = inputs.to('cpu')

                print("input shape ",inputs.shape)

                predictions = loaded_jit_model(inputs)

                print("shapeeeeeeeeeeeeeee ",predictions.shape)
                

                predictions = yolo_raw(predictions)
                predictions = [predictions]

                print("predictionss .... ",predictions[0].shape)
      
                predictions = [prediction.unsqueeze(-1) for prediction in predictions]
                
                #predictions = [torch.sum(prediction,dim=-1).unsqueeze(-1) for prediction in predictions]
                
                #loss, loss_distr = yolo_loss(predictions, targets)

                # MAP calculations
                T = 1 #inputs.shape[-1]
                try:
                    predictions = torch.concat([yolo(p, a) for (p, a)
                        in zip(predictions, net_dummy.anchors)],dim=1)
                except RuntimeError:
                    print('Runtime error on MAP predictions calculation.'
                            'continuing')
                    continue

                predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)
                                for t in range(T)]
                for t in range(T):
                    ap_stats.update(predictions[t], bboxes[t])
                    #end

                stats.testing.num_samples += inputs.shape[0]
                stats.testing.correct_samples = ap_stats[:] * stats.testing.num_samples

                processed = i * test_loader.batch_size
                total = len(test_loader.dataset)
                time_elapsed = (datetime.now() - t_st).total_seconds()
                samples_sec = time_elapsed / (i + 1) / test_loader.batch_size
                header_list = [f'Test: [{processed}/{total} '
                                    f'({100.0 * processed / total:.0f}%)]']
  
                stats.print(epoch, i, samples_sec, header=header_list)
                #functional.reset_net(net)

        print('mAP@50/train',stats.training.accuracy,epoch)
        print('mAP@50/test', stats.testing.accuracy, epoch)

# %%
import onnx
from onnx_tf.backend import prepare
import tensorflow as tf
# Out:
# 2024-10-10 13:25:09.688218: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-10 13:25:09.688251: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-10 13:25:09.689284: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-10 13:25:09.693783: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-10 13:25:10.404825: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/udayanga/miniconda3/envs/udaya_tf/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/udayanga/miniconda3/envs/udaya_tf/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
print(net_dummy)
# Out:
# Network(
#   (backend_blocks): ModuleList(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (15): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#   )
#   (head1_backend): ModuleList(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#   )
#   (head1_blocks): ModuleList(
#     (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv2d(128, 21, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (7): BatchNorm2d(21, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#   )
# )

# %%
dummy_input = torch.randn(1,320,320)

# %%
input_namess = [ "input_1" ]
#here the net should be the 'net' after the prepare
torch.onnx.export(net,dummy_input.unsqueeze(0),'/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.onnx',input_names=input_namess,export_params=True)

# %%
qqq = onnx.load('/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.onnx')

# %%
tf_rep = prepare(qqq)
# Out:
# 2024-10-10 13:25:20.058807: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-10 13:25:20.059435: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
print(tf_rep)
# Out:
# <onnx_tf.backend_rep.TensorflowRep object at 0x7f23e9cf4370>

# %%
tf_rep.export_graph("/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb")
# Out:
# INFO:absl:Function `__call__` contains input name(s) x with unsupported characters which will be renamed to transpose_31_x in the SavedModel.
# INFO:absl:Found untraced functions such as gen_tensor_dict while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb/assets
# INFO:tensorflow:Assets written to: /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb/assets
# INFO:absl:Writing fingerprint to /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb/fingerprint.pb

# %%
loaded_tf_model = tf.saved_model.load("/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb")

# %%
print(loaded_tf_model.signatures.keys())
# Out:
# KeysView(_SignatureMap({'serving_default': <ConcreteFunction (*, input_1: TensorSpec(shape=(1, 1, 320, 320), dtype=tf.float32, name='input_1')) -> Dict[['95', TensorSpec(shape=(1, 21, 5, 5), dtype=tf.float32, name='tensor_95')]] at 0x7FB098725100>}))

# %%
infer = loaded_tf_model.signatures["serving_default"]

# %%
print(infer.structured_outputs)
# Out:
# {'95': TensorSpec(shape=(1, 21, 5, 5), dtype=tf.float32, name='tensor_95')}

# %%
train_set = evCIVIL.evCIVIL(root = dataset_path ,csv_file_name = train_csv_file , param_dict = param_dict, train = True,augment = False)
test_set = evCIVIL.evCIVIL(root = dataset_path, csv_file_name= test_csv_file, param_dict = param_dict, train = False, augment = False)

prepare_loader = DataLoader(train_set,
                                batch_size=1,
                                shuffle=True,
                                collate_fn=yolo_target.collate_fn,
                                num_workers=1,
                                pin_memory=True)
prepare_test_loader = DataLoader(test_set,
                                batch_size=1,
                                shuffle=False,
                                collate_fn=yolo_target.collate_fn,    
                                num_workers=1,
                                pin_memory=True)

# %%
from tqdm import tqdm
import numpy as np
#base_path = "/home/udayanga/Udaya_Research_stuff/GAP8_previous_laptop/GAP_stuff/GAP_Tutorial/"
#CALIBRATION_IMGS = [os.path.join(base_path,"img_8.jpg"),os.path.join(base_path,"img_25.jpg"),os.path.join(base_path,"img_32.jpg")]

def representative_dataset():
    for i, (inputs, targets, bboxes) in enumerate(prepare_loader):
        # Pass a batch of images through the model
        inputs = inputs.permute(4,0,1,2,3)
        inputs = inputs.squeeze(0)
        inputs = inputs.to('cpu')
        yield [inputs.numpy().astype(np.float32)]

        #predictions = net_prepared(inputs)
    """for i
    for image in tqdm(CALIBRATION_IMGS):
        temp = np.array(Image.open(image))
        print("temp shape ",temp.shape)
        yield [np.array(temp[np.newaxis,np.newaxis,:,:],dtype=np.float32)]"""

# %%
path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb"
converter = tf.lite.TFLiteConverter.from_saved_model(path)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  #[tf.lite.Optimize.OPTIMIZE_FOR_SIZE] #If we directly convert to tflite without quantizations we can ignore this line.
converter.representative_dataset = representative_dataset
tflite_model = converter.convert()
# Out:
# 2024-10-10 13:25:54.031182: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-10-10 13:25:54.031219: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-10-10 13:25:54.031933: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb
# 2024-10-10 13:25:54.033116: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-10-10 13:25:54.033135: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb
# 2024-10-10 13:25:54.035332: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-10-10 13:25:54.035837: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-10-10 13:25:54.068171: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.pb
# 2024-10-10 13:25:54.074967: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 43036 microseconds.
# 2024-10-10 13:25:54.086289: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 24, Total Ops 66, % non-converted = 36.36 %
#  * 24 ARITH ops
#
# - arith.constant:   24 occurrences  (f32: 20, i32: 4)
#
#
#
#   (f32: 10)
#   (f32: 2)
#   (f32: 9)
#   (f32: 1)
#   (f32: 17)
# 2024-10-10 13:25:54.135895: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2989] Estimated count of arithmetic ops: 367.415 M  ops, equivalently 183.707 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: FLOAT32, output_inference_type: FLOAT32
# 2024-10-10 13:27:58.144278: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2989] Estimated count of arithmetic ops: 367.415 M  ops, equivalently 183.707 M  MACs

# %%
with open('/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.tflite','wb') as f:
    f.write(tflite_model)

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        return print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        return print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    else:
        return print('File size: ' + str(size) + ' bytes')

# %%
#tf_model_path = os.path.join(base_path,"model.pb/saved_model.pb")
tflite_model_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.tflite"
convert_bytes(get_file_size(tflite_model_path),"MB")
# Out:
# File size: 0.484 Megabytes

# %%
interpreter = tf.lite.Interpreter(model_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/image_checkpoints/simple_PTQ_model.tflite")
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
interpreter.allocate_tensors()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
input_details
# Out:
# [{'name': 'serving_default_input_1:0',
#   'index': 0,
#   'shape': array([  1,   1, 320, 320], dtype=int32),
#   'shape_signature': array([  1,   1, 320, 320], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]

# %%
output_details
# Out:
# [{'name': 'PartitionedCall:0',
#   'index': 65,
#   'shape': array([ 1, 21,  5,  5], dtype=int32),
#   'shape_signature': array([ 1, 21,  5,  5], dtype=int32),
#   'dtype': numpy.float32,
#   'quantization': (0.0, 0),
#   'quantization_parameters': {'scales': array([], dtype=float32),
#    'zero_points': array([], dtype=int32),
#    'quantized_dimension': 0},
#   'sparsity_parameters': {}}]

# %%
print("Input Shape:", input_details[0]['shape'])
print("Input Type:", input_details[0]['dtype'])
print("Output Shape:", output_details[0]['shape'])
print("Output Type:", output_details[0]['dtype'])
# Out:
# Input Shape: [  1   1 320 320]
# Input Type: <class 'numpy.float32'>
# Output Shape: [ 1 21  5  5]
# Output Type: <class 'numpy.float32'>

# %%
conf_thres
# Out:
# 0.6

# %%
visualize_save_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day"
stats = slayer.utils.LearningStats(accuracy_str='AP@0.5')
ap_stats = metrics.APstats(iou_threshold=0.5)
stats.update()
t_st = datetime.now()
epoch = 0
conf_thres = 0.5
with torch.no_grad():
    for i,(inputs,targets,bboxes) in enumerate(prepare_test_loader):
        
        inputs = inputs.permute(4,0,1,2,3)      
        inputs = inputs.squeeze(0)
        inputs = inputs.to('cpu')
        print("input shape ",inputs.shape)
        interpreter.set_tensor(input_details[0]['index'],inputs.numpy())
        interpreter.invoke()

        tflite_model_predictions = interpreter.get_tensor(output_details[0]['index'])
        print(tflite_model_predictions.shape)

        predictions = yolo_raw(torch.from_numpy(tflite_model_predictions))
        predictions = [predictions]

        print("predictionss .... ",predictions[0].shape)
        
        predictions = [prediction.unsqueeze(-1) for prediction in predictions]

        T = 1 #inputs.shape[-1]
        try:
            predictions = torch.concat([yolo(p, a) for (p, a)
                            in zip(predictions, net_dummy.anchors.to(torch.device("cpu")))],dim=1)
        except RuntimeError:
            print('Runtime error on MAP predictions calculation.'
                                'continuing')
            continue

        predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)
                                    for t in range(T)]
        
        visualize_data.dump_image_with_labels(inputs.squeeze(0).permute(1,2,0).cpu(),predictions[0][0].cpu().numpy(),(320,320),visualize_save_path,i,create_histo_frames=False)
        
        for t in range(T):
            ap_stats.update(predictions[t], bboxes[t])
            #end

        stats.testing.num_samples += inputs.shape[0]
        stats.testing.correct_samples = ap_stats[:] * stats.testing.num_samples

        processed = i * test_loader.batch_size
        total = len(test_loader.dataset)
        time_elapsed = (datetime.now() - t_st).total_seconds()
        samples_sec = time_elapsed / (i + 1) / test_loader.batch_size
        header_list = [f'Test: [{processed}/{total} '
                                        f'({100.0 * processed / total:.0f}%)]']
    
        stats.print(epoch, i, samples_sec, header=header_list)
        #functional.reset_net(net)

    print('mAP@50/test', stats.testing.accuracy, epoch)
# Out:
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  0_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/0_evframe.png
#
# Test: [0/1556 (0%)]
# Epoch    0: i =     0 ,     168.3950 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.99625
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  1_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/1_evframe.png
#
# Test: [1/1556 (0%)]
# Epoch    0: i =     1 ,     115.8735 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.50562
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  2_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/2_evframe.png
#
# Test: [2/1556 (0%)]
# Epoch    0: i =     2 ,      98.7877 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34208
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  3_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/3_evframe.png
#
# Test: [3/1556 (0%)]
# Epoch    0: i =     3 ,      90.1590 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26031
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  4_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/4_evframe.png
#
# Test: [4/1556 (0%)]
# Epoch    0: i =     4 ,      85.1510 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.40758
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  5_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/5_evframe.png
#
# Test: [5/1556 (0%)]
# Epoch    0: i =     5 ,      80.8908 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34215
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  6_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/6_evframe.png
#
# Test: [6/1556 (0%)]
# Epoch    0: i =     6 ,      77.8723 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29542
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  7_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/7_evframe.png
#
# Test: [7/1556 (0%)]
# Epoch    0: i =     7 ,      75.5907 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26036
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  8_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/8_evframe.png
#
# Test: [8/1556 (1%)]
# Epoch    0: i =     8 ,      74.1183 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.23310
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  9_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/9_evframe.png
#
# Test: [9/1556 (1%)]
# Epoch    0: i =     9 ,      72.6401 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21129
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  10_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/10_evframe.png
#
# Test: [10/1556 (1%)]
# Epoch    0: i =    10 ,      71.3961 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.28277
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  11_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/11_evframe.png
#
# Test: [11/1556 (1%)]
# Epoch    0: i =    11 ,      70.5727 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.34253
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  12_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/12_evframe.png
#
# Test: [12/1556 (1%)]
# Epoch    0: i =    12 ,      69.6327 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.31734
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  13_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/13_evframe.png
#
# Test: [13/1556 (1%)]
# Epoch    0: i =    13 ,      69.0333 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.29574
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  14_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/14_evframe.png
#
# Test: [14/1556 (1%)]
# Epoch    0: i =    14 ,      68.4297 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.27703
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  15_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/15_evframe.png
#
# Test: [15/1556 (1%)]
# Epoch    0: i =    15 ,      67.7674 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.26065
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  16_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/16_evframe.png
#
# Test: [16/1556 (1%)]
# Epoch    0: i =    16 ,      67.3949 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.24620
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  17_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/17_evframe.png
#
# Test: [17/1556 (1%)]
# Epoch    0: i =    17 ,      67.2718 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.23336
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  18_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/18_evframe.png
#
# Test: [18/1556 (1%)]
# Epoch    0: i =    18 ,      67.1271 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.22186
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  19_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/19_evframe.png
#
# Test: [19/1556 (1%)]
# Epoch    0: i =    19 ,      66.6986 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.21152
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  20_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/20_evframe.png
#
# Test: [20/1556 (1%)]
# Epoch    0: i =    20 ,      66.2939 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.20216
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  21_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/21_evframe.png
#
# Test: [21/1556 (1%)]
# Epoch    0: i =    21 ,      65.9740 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19366
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  22_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/22_evframe.png
#
# Test: [22/1556 (1%)]
# Epoch    0: i =    22 ,      65.6394 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18589
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  23_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/23_evframe.png
#
# Test: [23/1556 (1%)]
# Epoch    0: i =    23 ,      65.5446 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17877
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  24_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/24_evframe.png
#
# Test: [24/1556 (2%)]
# Epoch    0: i =    24 ,      65.3264 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17222
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  25_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/25_evframe.png
#
# Test: [25/1556 (2%)]
# Epoch    0: i =    25 ,      65.1767 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16617
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  26_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/26_evframe.png
#
# Test: [26/1556 (2%)]
# Epoch    0: i =    26 ,      65.1627 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16057
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  27_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/27_evframe.png
#
# Test: [27/1556 (2%)]
# Epoch    0: i =    27 ,      65.0283 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15537
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  28_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/28_evframe.png
#
# Test: [28/1556 (2%)]
# Epoch    0: i =    28 ,      64.8352 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16398
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  29_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/29_evframe.png
#
# Test: [29/1556 (2%)]
# Epoch    0: i =    29 ,      64.6625 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17201
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  30_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/30_evframe.png
#
# Test: [30/1556 (2%)]
# Epoch    0: i =    30 ,      64.5589 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17953
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  31_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/31_evframe.png
#
# Test: [31/1556 (2%)]
# Epoch    0: i =    31 ,      64.3945 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17439
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  32_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/32_evframe.png
#
# Test: [32/1556 (2%)]
# Epoch    0: i =    32 ,      64.2038 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16956
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  33_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/33_evframe.png
#
# Test: [33/1556 (2%)]
# Epoch    0: i =    33 ,      75.1830 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17648
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  34_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/34_evframe.png
#
# Test: [34/1556 (2%)]
# Epoch    0: i =    34 ,      74.7335 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17730
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  35_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/35_evframe.png
#
# Test: [35/1556 (2%)]
# Epoch    0: i =    35 ,      74.3594 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17807
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  36_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/36_evframe.png
#
# Test: [36/1556 (2%)]
# Epoch    0: i =    36 ,      73.9458 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17366
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  37_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/37_evframe.png
#
# Test: [37/1556 (2%)]
# Epoch    0: i =    37 ,      73.6919 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16948
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  38_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/38_evframe.png
#
# Test: [38/1556 (2%)]
# Epoch    0: i =    38 ,      73.3223 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16552
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  39_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/39_evframe.png
#
# Test: [39/1556 (3%)]
# Epoch    0: i =    39 ,      72.9271 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16176
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  40_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/40_evframe.png
#
# Test: [40/1556 (3%)]
# Epoch    0: i =    40 ,      72.6477 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15818
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  41_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/41_evframe.png
#
# Test: [41/1556 (3%)]
# Epoch    0: i =    41 ,      72.3585 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17822
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  42_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/42_evframe.png
#
# Test: [42/1556 (3%)]
# Epoch    0: i =    42 ,      72.0985 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17443
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  43_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/43_evframe.png
#
# Test: [43/1556 (3%)]
# Epoch    0: i =    43 ,      71.8210 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17080
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  44_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/44_evframe.png
#
# Test: [44/1556 (3%)]
# Epoch    0: i =    44 ,      71.7590 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18923
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  45_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/45_evframe.png
#
# Test: [45/1556 (3%)]
# Epoch    0: i =    45 ,      71.6020 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18544
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  46_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/46_evframe.png
#
# Test: [46/1556 (3%)]
# Epoch    0: i =    46 ,      71.3162 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18182
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  47_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/47_evframe.png
#
# Test: [47/1556 (3%)]
# Epoch    0: i =    47 ,      71.1084 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17834
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  48_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/48_evframe.png
#
# Test: [48/1556 (3%)]
# Epoch    0: i =    48 ,      70.8905 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17470
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  49_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/49_evframe.png
#
# Test: [49/1556 (3%)]
# Epoch    0: i =    49 ,      70.6257 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19113
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  50_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/50_evframe.png
#
# Test: [50/1556 (3%)]
# Epoch    0: i =    50 ,      70.3728 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18768
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  51_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/51_evframe.png
#
# Test: [51/1556 (3%)]
# Epoch    0: i =    51 ,      70.1449 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18436
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  52_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/52_evframe.png
#
# Test: [52/1556 (3%)]
# Epoch    0: i =    52 ,      69.9524 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18116
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  53_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/53_evframe.png
#
# Test: [53/1556 (3%)]
# Epoch    0: i =    53 ,      69.7959 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.19626
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  54_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/54_evframe.png
#
# Test: [54/1556 (3%)]
# Epoch    0: i =    54 ,      69.6630 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18978
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  55_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/55_evframe.png
#
# Test: [55/1556 (4%)]
# Epoch    0: i =    55 ,      69.5379 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18672
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  56_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/56_evframe.png
#
# Test: [56/1556 (4%)]
# Epoch    0: i =    56 ,      69.4030 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18376
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  57_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/57_evframe.png
#
# Test: [57/1556 (4%)]
# Epoch    0: i =    57 ,      69.2291 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.18090
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  58_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/58_evframe.png
#
# Test: [58/1556 (4%)]
# Epoch    0: i =    58 ,      69.1134 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17788
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  59_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/59_evframe.png
#
# Test: [59/1556 (4%)]
# Epoch    0: i =    59 ,      69.0237 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17263
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  60_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/60_evframe.png
#
# Test: [60/1556 (4%)]
# Epoch    0: i =    60 ,      68.8726 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.17013
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  61_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/61_evframe.png
#
# Test: [61/1556 (4%)]
# Epoch    0: i =    61 ,      68.7276 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16770
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  62_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/62_evframe.png
#
# Test: [62/1556 (4%)]
# Epoch    0: i =    62 ,      68.6290 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16535
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  63_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/63_evframe.png
#
# Test: [63/1556 (4%)]
# Epoch    0: i =    63 ,      68.5593 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16307
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  64_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/64_evframe.png
#
# Test: [64/1556 (4%)]
# Epoch    0: i =    64 ,      68.4270 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.16086
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  65_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/65_evframe.png
#
# Test: [65/1556 (4%)]
# Epoch    0: i =    65 ,      68.3382 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15872
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  66_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/66_evframe.png
#
# Test: [66/1556 (4%)]
# Epoch    0: i =    66 ,      68.3169 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15440
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  67_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/67_evframe.png
#
# Test: [67/1556 (4%)]
# Epoch    0: i =    67 ,      68.1863 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15244
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  68_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/68_evframe.png
#
# Test: [68/1556 (4%)]
# Epoch    0: i =    68 ,      68.1390 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.15053
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])
# path_to_save  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day
# initial shape  (320, 320, 1)
# relative_out_fname  69_evframe.png
# width and height  (640, 480)
# initial shape 2222  (480, 640)
# output full path  /home/udayanga/Udaya_Research_stuff/2024_GAP8_work/gap8_special_course/visualization/events_day/69_evframe.png
#
# Test: [69/1556 (4%)]
# Epoch    0: i =    69 ,      67.9951 ms elapsed
# Train
# Test  loss =     0.00000                          AP@0.5 = 0.14867
# input shape  torch.Size([1, 1, 320, 320])
# (1, 21, 5, 5)
# predictionss ....  torch.Size([1, 3, 5, 5, 7])

# %% [markdown]
# #### QAT - Quantization aware training

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
class QuantNetwork(torch.nn.Module):

    def __init__(self,
                    in_channels = 4,
                    num_output = num_output):
        
        super().__init__()
        
        self.num_output = num_output
        
        self.backend_blocks = torch.nn.ModuleList([
            
            nn.Conv2d(in_channels, 16, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            
            nn.Conv2d(16, 32, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2,stride = 2),
            #nn.Dropout(0.2),

            nn.Conv2d(32, 32, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            
            nn.Conv2d(32, 64, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 2,stride = 2),
            #nn.Dropout(0.2),

            nn.Conv2d(64, 64, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        
        ])

        self.head1_backend = torch.nn.ModuleList([

            nn.Conv2d(64,64, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            #nn.Dropout(0.2),

            nn.Conv2d(64,128, kernel_size=3, padding=1, stride=2, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            #nn.Dropout(0.2),
            
        ])

        self.head1_blocks = torch.nn.ModuleList([

            nn.Conv2d(128,128, kernel_size=3, padding=1, stride=1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            #nn.Dropout(0.2),

            nn.Conv2d(128,self.num_output, kernel_size=1, padding=0, stride=1, bias=False),
            nn.BatchNorm2d(self.num_output),
            nn.ReLU(),

        ])

        self.quant = QuantStub()
        self.dequant = DeQuantStub()

        """self.backend_blocks[1].synapse.weight.requires_grad = False #pool
        self.backend_blocks[6].synapse.weight.requires_grad = False #pool
        self.head2_backend[2].synapse.weight.requires_grad = False #unpool
        self.head2_backend[3].synapse.weight.requires_grad = False"""
    
    def forward(self,
        input
    ):

        count = []
        """for block in self.input_blocks:
            input = block(input)
            count.append(slayer.utils.event_rate(input))
            
        backend = input"""
        input = self.quant(input)
        backend = input
        for block in self.backend_blocks:
            backend = block(backend)
        
        h1_backend = backend
        for block in self.head1_backend:
            h1_backend = block(h1_backend)
        
        head1 = h1_backend
        for block in self.head1_blocks:
            head1 = block(head1)
            """if has_sparisty_loss and isinstance(block,
                                                slayer.block.sigma_delta.Conv):
                sparsity_monitor.append(head1)"""

            """if has_sparisty_loss and isinstance(block,
                                                slayer.block.sigma_delta.Conv):
                sparsity_monitor.append(head2)"""

        ## Get the summation or averaging over all the time steps, and preserve the last dimension of head1 tensor as time but Time = 1

        head1 = self.dequant(head1)

        return head1
    
    def fuse_model(self,quant_aware_train = False):
        # Specify which layers to fuse
        if quant_aware_train:
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU
            # Pooling layers do not need to be fused
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['7', '8', '9'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['10', '11', '12'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.backend_blocks, ['14', '15', '16'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules_qat(self.head1_backend, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.head1_backend, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules_qat(self.head1_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules_qat(self.head1_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU
        
        else:
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU
            # Pooling layers do not need to be fused
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['7', '8', '9'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['10', '11', '12'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.backend_blocks, ['14', '15', '16'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules(self.head1_backend, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.head1_backend, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU

            torch.ao.quantization.fuse_modules(self.head1_blocks, ['0', '1', '2'], inplace=True)  # Conv + BN + ReLU
            torch.ao.quantization.fuse_modules(self.head1_blocks, ['3', '4', '5'], inplace=True)  # Conv + BN + ReLU

# %%
train_set = evCIVIL.evCIVIL(root = dataset_path ,csv_file_name = train_csv_file , param_dict = param_dict, train = True,augment = True)
test_set = evCIVIL.evCIVIL(root = dataset_path, csv_file_name= test_csv_file, param_dict = param_dict, train = False, augment = False)

prepare_loader = DataLoader(train_set,
                                batch_size=8,
                                shuffle=True,
                                collate_fn=yolo_target.collate_fn,
                                num_workers=1,
                                pin_memory=True)
prepare_test_loader = DataLoader(test_set,
                                batch_size=8,
                                shuffle=False,
                                collate_fn=yolo_target.collate_fn,    
                                num_workers=1,
                                pin_memory=True)

# %%
yolo_loss = yolo_base.YOLOLoss(anchors=net_dummy.anchors,
                             lambda_coord=1.0,
                             lambda_noobj=2.0,
                             lambda_obj=2.0,
                             lambda_cls=4.0,
                             lambda_iou=2.0,
                             alpha_iou=0.8,
                             label_smoothing=0.1).to(torch.device("cuda:0"))

# %%
loss_tracker = dict(coord=[], obj=[], noobj=[], cls=[], iou=[])
loss_order = ['coord', 'obj', 'noobj', 'cls', 'iou']
track_iter = 1000
ckpt_folder = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/qat_checkpoints/"
epochs = 300

# %%
in_channels = 2
num_output = 21
qat_model = QuantNetwork(in_channels=in_channels,num_output=num_output)
#qat_model.load_state_dict(torch.load("nmnist_bnorm_model.pth"))
#qat_model.eval()
qat_model.qconfig = torch.ao.quantization.get_default_qat_qconfig('qnnpack') #x86 or 'qnnpack'
#qat_model.fuse_model(is_qat=True) #is_qat=True only for quantization aware training.
qat_model.fuse_model(quant_aware_train=True)
#qat_model = torch.ao.quantization.fuse_modules_qat(qat_model.nnn, [['0','1','2'],['4','5','6'],['8','9']])
#optimizer = optim.SGD(qat_model.parameters(),lr=0.01,momentum=0.5)
qat_model = torch.ao.quantization.prepare_qat(qat_model)

# %%
writer = SummaryWriter("." + '/runs/' + "qat")
optimizer = torch.optim.AdamW(qat_model.parameters(), lr=0.001,weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer,
            epochs,        # * len(train_loader),
    )
current_epoch = 0

# %%
print([key for key in qat_model.state_dict().keys()])
# Out:
# ['backend_blocks.0.weight', 'backend_blocks.0.bn.weight', 'backend_blocks.0.bn.bias', 'backend_blocks.0.bn.running_mean', 'backend_blocks.0.bn.running_var', 'backend_blocks.0.bn.num_batches_tracked', 'backend_blocks.0.weight_fake_quant.fake_quant_enabled', 'backend_blocks.0.weight_fake_quant.observer_enabled', 'backend_blocks.0.weight_fake_quant.scale', 'backend_blocks.0.weight_fake_quant.zero_point', 'backend_blocks.0.weight_fake_quant.activation_post_process.eps', 'backend_blocks.0.weight_fake_quant.activation_post_process.min_val', 'backend_blocks.0.weight_fake_quant.activation_post_process.max_val', 'backend_blocks.0.activation_post_process.fake_quant_enabled', 'backend_blocks.0.activation_post_process.observer_enabled', 'backend_blocks.0.activation_post_process.scale', 'backend_blocks.0.activation_post_process.zero_point', 'backend_blocks.0.activation_post_process.activation_post_process.eps', 'backend_blocks.0.activation_post_process.activation_post_process.min_val', 'backend_blocks.0.activation_post_process.activation_post_process.max_val', 'backend_blocks.3.weight', 'backend_blocks.3.bn.weight', 'backend_blocks.3.bn.bias', 'backend_blocks.3.bn.running_mean', 'backend_blocks.3.bn.running_var', 'backend_blocks.3.bn.num_batches_tracked', 'backend_blocks.3.weight_fake_quant.fake_quant_enabled', 'backend_blocks.3.weight_fake_quant.observer_enabled', 'backend_blocks.3.weight_fake_quant.scale', 'backend_blocks.3.weight_fake_quant.zero_point', 'backend_blocks.3.weight_fake_quant.activation_post_process.eps', 'backend_blocks.3.weight_fake_quant.activation_post_process.min_val', 'backend_blocks.3.weight_fake_quant.activation_post_process.max_val', 'backend_blocks.3.activation_post_process.fake_quant_enabled', 'backend_blocks.3.activation_post_process.observer_enabled', 'backend_blocks.3.activation_post_process.scale', 'backend_blocks.3.activation_post_process.zero_point', 'backend_blocks.3.activation_post_process.activation_post_process.eps', 'backend_blocks.3.activation_post_process.activation_post_process.min_val', 'backend_blocks.3.activation_post_process.activation_post_process.max_val', 'backend_blocks.7.weight', 'backend_blocks.7.bn.weight', 'backend_blocks.7.bn.bias', 'backend_blocks.7.bn.running_mean', 'backend_blocks.7.bn.running_var', 'backend_blocks.7.bn.num_batches_tracked', 'backend_blocks.7.weight_fake_quant.fake_quant_enabled', 'backend_blocks.7.weight_fake_quant.observer_enabled', 'backend_blocks.7.weight_fake_quant.scale', 'backend_blocks.7.weight_fake_quant.zero_point', 'backend_blocks.7.weight_fake_quant.activation_post_process.eps', 'backend_blocks.7.weight_fake_quant.activation_post_process.min_val', 'backend_blocks.7.weight_fake_quant.activation_post_process.max_val', 'backend_blocks.7.activation_post_process.fake_quant_enabled', 'backend_blocks.7.activation_post_process.observer_enabled', 'backend_blocks.7.activation_post_process.scale', 'backend_blocks.7.activation_post_process.zero_point', 'backend_blocks.7.activation_post_process.activation_post_process.eps', 'backend_blocks.7.activation_post_process.activation_post_process.min_val', 'backend_blocks.7.activation_post_process.activation_post_process.max_val', 'backend_blocks.10.weight', 'backend_blocks.10.bn.weight', 'backend_blocks.10.bn.bias', 'backend_blocks.10.bn.running_mean', 'backend_blocks.10.bn.running_var', 'backend_blocks.10.bn.num_batches_tracked', 'backend_blocks.10.weight_fake_quant.fake_quant_enabled', 'backend_blocks.10.weight_fake_quant.observer_enabled', 'backend_blocks.10.weight_fake_quant.scale', 'backend_blocks.10.weight_fake_quant.zero_point', 'backend_blocks.10.weight_fake_quant.activation_post_process.eps', 'backend_blocks.10.weight_fake_quant.activation_post_process.min_val', 'backend_blocks.10.weight_fake_quant.activation_post_process.max_val', 'backend_blocks.10.activation_post_process.fake_quant_enabled', 'backend_blocks.10.activation_post_process.observer_enabled', 'backend_blocks.10.activation_post_process.scale', 'backend_b ...

# %%
#Load only if it really requires.

pretrained_model_path = "/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/qat_checkpoints/epoch_145_0.3345367681206545.pt"
pretrained_model_info = torch.load(pretrained_model_path,map_location="cuda:0")
model_state_dict = pretrained_model_info["model_state_dict"]
qat_model.load_state_dict(model_state_dict)
"""optimizer_dict = pretrained_model_info["optimizer"]
optimizer.load_state_dict(optimizer_dict)
scheduler_dict = pretrained_model_info["scheduler"]
scheduler.load_state_dict(scheduler_dict)
current_epoch = pretrained_model_info["epoch"]
print("loading state dictionary ")"""
# Out:
# /tmp/ipykernel_437188/154281353.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_model_info = torch.load(pretrained_model_path,map_location="cuda:0")
# 'optimizer_dict = pretrained_model_info["optimizer"]\noptimizer.load_state_dict(optimizer_dict)\nscheduler_dict = pretrained_model_info["scheduler"]\nscheduler.load_state_dict(scheduler_dict)\ncurrent_epoch = pretrained_model_info["epoch"]\nprint("loading state dictionary ")'

# %%
current_epoch
# Out:
# 98

# %%
conf_thres = 0.02
stats = slayer.utils.LearningStats(accuracy_str='AP@0.5')

# %%
anchors = torch.tensor([[0.2800, 0.2200],
        [0.3800, 0.4800],
        [0.9000, 0.7800]])
    
anchors = anchors.unsqueeze(0)

# %%
t_st = datetime.now()

for epoch in range(current_epoch,epochs):


    qat_model.to(torch.device('cuda:0'))
    qat_model.train()
    ap_stats = metrics.APstats(iou_threshold=0.5)

    for i, (inputs, targets, bboxes) in enumerate(train_loader):            

        #start
        inputs = inputs.permute(4,0,1,2,3)
            
        inputs = inputs.squeeze(0)

        inputs = inputs.to(torch.device('cuda:0'))

        #print("input shape ",inputs.shape)

        predictions = qat_model(inputs)

        predictions = yolo_raw(predictions)
        predictions = [predictions]
        #print("predictionss .... ",predictions[0].shape)
        predictions = [prediction.unsqueeze(-1) for prediction in predictions]

        #print("predictions .... ",predictions)

        loss, loss_distr = yolo_loss(predictions, targets)

        if torch.isnan(loss):
            print("loss is nan, continuing")
            continue
        
        clip_val = 1.0
        optimizer.zero_grad()
        loss.backward()
        validate_gradients(qat_model) #net.validate_gradients()
        torch.nn.utils.clip_grad_norm_(qat_model.parameters(), clip_val)
        optimizer.step()

        # MAP calculations
        T = 1 #inputs.shape[-1]
        try:
            predictions = torch.concat([yolo(p, a) for (p, a)
                                                    in zip(predictions, net_dummy.anchors.to(torch.device('cuda:0')))],dim=1)
        except RuntimeError:
            print('Runtime error on MAP predictions calculation.'
                            'continuing')
            continue

        predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)
                                for t in range(T)]
        
                    
        for t in range(T):
            ap_stats.update(predictions[t], bboxes[t])

        if not torch.isnan(loss):
            stats.training.loss_sum += loss.item() * inputs.shape[0]

        stats.training.num_samples += inputs.shape[0]
        stats.training.correct_samples = ap_stats[:] * \
                        stats.training.num_samples

        processed = i * train_loader.batch_size
        total = len(train_loader.dataset)
        time_elapsed = (datetime.now() - t_st).total_seconds()
        samples_sec = time_elapsed / (i + 1) / train_loader.batch_size
        header_list = [f'Train: [{processed}/{total} '
                                f'({100.0 * processed / total:.0f}%)]']

        header_list += [f'Coord loss: {loss_distr[0].item()}']
        header_list += [f'Obj   loss: {loss_distr[1].item()}']
        header_list += [f'NoObj loss: {loss_distr[2].item()}']
        header_list += [f'Class loss: {loss_distr[3].item()}']
        header_list += [f'IOU   loss: {loss_distr[4].item()}']

        if i % track_iter == 0:
            #plt.figure()
            for loss_idx, loss_key in enumerate(loss_order):
                loss_tracker[loss_key].append(loss_distr[loss_idx].item())
                            #plt.semilogy(loss_tracker[loss_key], label=loss_key)

        writer.add_scalar(f'Loss Tracker/{loss_key}',
                                                loss_distr[loss_idx].item(),
                                                len(loss_tracker[loss_key]) - 1)
                            
        stats.print(epoch, i, samples_sec, header=header_list)

    current_val_acc = 0
    qat_model.to(torch.device('cpu'))
    quantized_model = torch.quantization.convert(qat_model)
    quantized_model.eval()

    with torch.no_grad():
            ap_stats = metrics.APstats(iou_threshold=0.5)
            
            for i, (inputs, targets, bboxes) in enumerate(test_loader):

                    #start
                    inputs = inputs.permute(4,0,1,2,3)
            
                    inputs = inputs.squeeze(0)

                    inputs = inputs.to('cpu')

                    #print("input shape ",inputs.shape)

                    predictions = quantized_model(inputs)

                    #print("shapeeeeeeeeeeeeeee ",predictions.shape)
                    
                
                    predictions = yolo_raw(predictions)
                    predictions = [predictions]

                    #print("predictionss .... ",predictions[0].shape)
        
                    predictions = [prediction.unsqueeze(-1) for prediction in predictions]
                    
                    #predictions = [torch.sum(prediction,dim=-1).unsqueeze(-1) for prediction in predictions]
                    
                    #loss, loss_distr = yolo_loss(predictions, targets)

                    # MAP calculations
                    T = 1 #inputs.shape[-1]
                    try:
                        predictions = torch.concat([yolo(p, a) for (p, a)
                            in zip(predictions, net_dummy.anchors)],dim=1)
                    except RuntimeError:
                        print('Runtime error on MAP predictions calculation.'
                                'continuing')
                        continue

                    predictions = [utils.nms(predictions[..., t],conf_threshold = conf_thres)
                                    for t in range(T)]
                    for t in range(T):
                        ap_stats.update(predictions[t], bboxes[t])
                        #end

                    stats.testing.num_samples += inputs.shape[0]
                    stats.testing.correct_samples = ap_stats[:] * stats.testing.num_samples

                    processed = i * test_loader.batch_size
                    total = len(test_loader.dataset)
                    time_elapsed = (datetime.now() - t_st).total_seconds()
                    samples_sec = time_elapsed / (i + 1) / test_loader.batch_size
                    header_list = [f'Test: [{processed}/{total} '
                                        f'({100.0 * processed / total:.0f}%)]']
    
                    stats.print(epoch, i, samples_sec, header=header_list)
                    #functional.reset_net(net)"""
                    

    writer.add_scalar('Loss/train', stats.training.loss, epoch)
    writer.add_scalar('mAP@50/train', stats.training.accuracy, epoch)
    writer.add_scalar('mAP@50/test', stats.testing.accuracy, epoch)

    if stats.testing.accuracy > current_val_acc:
        checkpoint = {"epoch": epoch,
                                "model_state_dict": qat_model.state_dict(),   #module.state_dict(),
                                "optimizer": optimizer.state_dict(),
                                "scheduler": scheduler.state_dict()}
        full_ckpt_path = ckpt_folder + "/epoch_" + str(epoch) + "_" + str(stats.testing.accuracy) + ".pt"
        print("saving net_prepared model ... ")
        torch.save(checkpoint,full_ckpt_path)
        current_val_acc = stats.testing.accuracy
        jit_quant_model_path = ckpt_folder + "/jit_epoch_" + str(epoch) + "_" + str(stats.testing.accuracy) + ".pt"
        print("saving jit quant model ..... ")
        torch.jit.save(torch.jit.script(quantized_model), jit_quant_model_path)
    else:
        if epoch % 2 == 0:
            checkpoint = {"epoch": epoch,
                                    "model_state_dict": qat_model.state_dict(),   #module.state_dict(),
                                    "optimizer": optimizer.state_dict(),
                                    "scheduler": scheduler.state_dict()}
        full_ckpt_path = ckpt_folder + "/epoch_" + str(epoch) + "_" + str(stats.testing.accuracy) + ".pt"
        print("saving ")
        torch.save(checkpoint,full_ckpt_path)
            
    stats.update()
    stats.save(ckpt_folder)
    scheduler.step()
# Out:
# Train: [0/5441 (0%)]
# Coord loss: 0.132863849401474
# Obj   loss: 1.3561460971832275
# NoObj loss: 1.3964393138885498
# Class loss: 1.627793312072754
# IOU   loss: 0.7723892331123352
# Epoch    0: i =     0 ,      26.5916 ms elapsed
# Train loss =     4.91580 (min =     4.81175)     AP@0.5 = 0.26003 (max = 0.34722)
#
# Train: [8/5441 (0%)]
# Coord loss: 0.2360049933195114
# Obj   loss: 1.3248523473739624
# NoObj loss: 1.4047110080718994
# Class loss: 1.1733357906341553
# IOU   loss: 0.7880774736404419
# Epoch    0: i =     1 ,      16.2332 ms elapsed
# Train loss =     4.91587 (min =     4.81175)     AP@0.5 = 0.19879 (max = 0.34722)
#
# Train: [16/5441 (0%)]
# Coord loss: 0.17342327535152435
# Obj   loss: 1.3226360082626343
# NoObj loss: 1.4039744138717651
# Class loss: 1.1190481185913086
# IOU   loss: 0.8769333362579346
# Epoch    0: i =     2 ,      12.5592 ms elapsed
# Train loss =     4.91575 (min =     4.81175)     AP@0.5 = 0.19881 (max = 0.34722)
#
# Train: [24/5441 (0%)]
# Coord loss: 0.06240746006369591
# Obj   loss: 1.2645692825317383
# NoObj loss: 1.402179479598999
# Class loss: 1.6214977502822876
# IOU   loss: 0.48144686222076416
# Epoch    0: i =     3 ,      11.4614 ms elapsed
# Train loss =     4.91524 (min =     4.81175)     AP@0.5 = 0.21413 (max = 0.34722)
#
# Train: [32/5441 (1%)]
# Coord loss: 0.09468811005353928
# Obj   loss: 1.3751509189605713
# NoObj loss: 1.4070591926574707
# Class loss: 1.1425449848175049
# IOU   loss: 0.7278597950935364
# Epoch    0: i =     4 ,      10.7465 ms elapsed
# Train loss =     4.91424 (min =     4.81175)     AP@0.5 = 0.19882 (max = 0.34722)
#
# Train: [40/5441 (1%)]
# Coord loss: 0.1356152892112732
# Obj   loss: 1.2654346227645874
# NoObj loss: 1.4018508195877075
# Class loss: 1.7610619068145752
# IOU   loss: 0.6521968841552734
# Epoch    0: i =     5 ,      10.3215 ms elapsed
# Train loss =     4.91603 (min =     4.81175)     AP@0.5 = 0.21506 (max = 0.34722)
#
# Train: [48/5441 (1%)]
# Coord loss: 0.1764509081840515
# Obj   loss: 1.2914432287216187
# NoObj loss: 1.4003627300262451
# Class loss: 1.030876874923706
# IOU   loss: 0.682469367980957
# Epoch    0: i =     6 ,      10.0511 ms elapsed
# Train loss =     4.91405 (min =     4.81175)     AP@0.5 = 0.22559 (max = 0.34722)
#
# Train: [56/5441 (1%)]
# Coord loss: 0.10006788372993469
# Obj   loss: 1.3676241636276245
# NoObj loss: 1.4034301042556763
# Class loss: 1.8130484819412231
# IOU   loss: 0.5824195742607117
# Epoch    0: i =     7 ,       9.6630 ms elapsed
# Train loss =     4.91613 (min =     4.81175)     AP@0.5 = 0.20430 (max = 0.34722)
#
# Train: [64/5441 (1%)]
# Coord loss: 0.20096318423748016
# Obj   loss: 1.344491720199585
# NoObj loss: 1.400593638420105
# Class loss: 1.129309892654419
# IOU   loss: 0.7309203147888184
# Epoch    0: i =     8 ,       9.6877 ms elapsed
# Train loss =     4.91549 (min =     4.81175)     AP@0.5 = 0.21358 (max = 0.34722)
#
# Train: [72/5441 (1%)]
# Coord loss: 0.12691277265548706
# Obj   loss: 1.3160467147827148
# NoObj loss: 1.397554874420166
# Class loss: 0.9538587927818298
# IOU   loss: 0.49679118394851685
# Epoch    0: i =     9 ,       9.7392 ms elapsed
# Train loss =     4.91186 (min =     4.81175)     AP@0.5 = 0.24203 (max = 0.34722)
#
# Train: [80/5441 (1%)]
# Coord loss: 0.18020521104335785
# Obj   loss: 1.299376368522644
# NoObj loss: 1.408677577972412
# Class loss: 0.8208950757980347
# IOU   loss: 0.7351240515708923
# Epoch    0: i =    10 ,       9.7706 ms elapsed
# Train loss =     4.90915 (min =     4.81175)     AP@0.5 = 0.23274 (max = 0.34722)
#
# Train: [88/5441 (2%)]
# Coord loss: 0.11597040295600891
# Obj   loss: 1.3225927352905273
# NoObj loss: 1.4066591262817383
# Class loss: 2.213229179382324
# IOU   loss: 0.7055036425590515
# Epoch    0: i =    11 ,       9.7722 ms elapsed
# Train loss =     4.91407 (min =     4.81175)     AP@0.5 = 0.24499 (max = 0.34722)
#
# Train: [96/5441 (2%)]
# Coord loss: 0.24141286313533783
# Obj   loss: 1.2444581985473633
# NoObj loss: 1.401029348373413
# Class loss: 1.2081384658813477
# IOU   loss: 0.7573604583740234
# Epoch    0: i =    12 ,       9.5971 ms elapsed
# Train loss =     4.91371 (min =     4.81175)     AP@0.5 = 0.25537 (max = 0.34722)
#
# Train: [104/5441 (2%)]
# Coord loss: 0.10770729929208755
# Obj   loss: 1.3356131315231323
# NoObj loss: 1.4037855863571167
# Class loss: 1.4343478679656982
# IOU   loss: 0.6029170155525208
# Epoch    0: i =    13 ,       9.4943 ms elapsed
# Train loss =     4.91355 (min =     4.81175)     AP@0.5 = 0.24711 (max = 0.34722)
#
# Train: [112/5441 (2%)]
# Coord loss: 0.06500373035669327
# Obj   loss: 1.2056783437728882
# NoObj loss: 1.4037799835205078
# Class loss: 1.043689250946045
# IOU   loss: 0.5598512291908264
# Epoch    0: i =    14 ,       9.5376 ms elapsed
# Train loss =     4.90996 (min =     4.81175)     AP@0.5 = 0.26405 (max = 0.34722)
#
# Train: [120/5441 (2%)]
# Coord loss: 0.05519299581646919
# Obj   loss: 1.1753909587860107
# NoObj loss: 1.4039217233657837
# Class loss: 1.0565096139907837
# IOU   loss: 0.276311993598938
# Epoch    0: i =    15 ,       9.3569 ms elapsed
# Train loss =     4.90466 (min =     4.81175)     AP@0.5 = 0.27889 (max = 0.34722)
#
# Train: [128/5441 (2%)]
# Coord loss: 0.12337049841880798
# Obj   loss: 1.3243772983551025
# NoObj loss: 1.4011423587799072
# Class loss: 0.8666422367095947
# IOU   loss: 0.7161291241645813
# Epoch    0: i =    16 ,       9.2267 ms elapsed
# Train loss =     4.90202 (min =     4.81175)     AP@0.5 = 0.28296 (max = 0.34722)
#
# Train: [136/5441 (2%)]
# Coord loss: 0.041573282331228256
# Obj   loss: 1.2146698236465454
# NoObj loss: 1.402929663658142
# Class loss: 0.8338481783866882
# IOU   loss: 0.23362769186496735
# Epoch    0: i =    17 ,       9.2455 ms elapsed
# Train loss =     4.89549 (min =     4.81175)     AP@0.5 = 0.30172 (max = 0.34722)
#
# Train: [144/5441 (3%)]
# Coord loss: 0.09525725990533829
# Obj   loss: 1.347136378288269
# NoObj loss: 1.4027576446533203
# Class loss: 1.0286073684692383
# IOU   loss: 0.5641970038414001
# Epoch    0: i =    18 ,       9.3237 ms elapsed
# Train loss =     4.89296 (min =     4.81175)     AP@0.5 = 0.29325 (max = 0.34722)
#
# Train: [152/5441 (3%)]
# Coord loss: 0.10319219529628754
# Obj   loss: 1.2964907884597778
# NoObj loss: 1.4018175601959229
# Class loss: 1.2091206312179565
# IOU   loss: 0.6553743481636047
# Epoch    0: i =    19 ,       9.2525 ms elapsed
# Train loss =     4.89171 (min =     4.81175)     AP@0.5 = 0.29763 (max = 0.34722)
#
# Train: [160/5441 (3%)]
# Coord loss: 0.04990384727716446
# Obj   loss: 1.220790147781372
# NoObj loss: 1.4045519828796387
# Class loss: 1.0650606155395508
# IOU   loss: 0.2638563811779022
# Epoch    0: i =    20 ,       9.1461 ms elapsed
# Train loss =     4.88686 (min =     4.81175)     AP@0.5 = 0.30565 (max = 0.34722)
#
# Train: [168/5441 (3%)]
# Coord loss: 0.04816107451915741
# Obj   loss: 1.3470308780670166
# NoObj loss: 1.4029251337051392
# Class loss: 2.1803524494171143
# IOU   loss: 0.3197293281555176
# Epoch    0: i =    21 ,       8.9871 ms elapsed
# Train loss =     4.88910 (min =     4.81175)     AP@0.5 = 0.30363 (max = 0.34722)
#
# Train: [176/5441 (3%)]
# Coord loss: 0.18313971161842346
# Obj   loss: 1.225969672203064
# NoObj loss: 1.4003849029541016
# Class loss: 1.2907644510269165
# IOU   loss: 0.5131714940071106
# Epoch    0: i =    22 ,       8.9460 ms elapsed
# Train loss =     4.88761 (min =     4.81175)     AP@0.5 = 0.30699 (max = 0.34722)
#
# Train: [184/5441 (3%)]
# Coord loss: 0.2627771198749542
# Obj   loss: 1.3741990327835083
# NoObj loss: 1.3993589878082275
# Class loss: 1.3215926885604858
# IOU   loss: 0.8319275975227356
# Epoch    0: i =    23 ,       8.8630 ms elapsed
# Train loss =     4.88923 (min =     4.81175)     AP@0.5 = 0.30007 (max = 0.34722)
#
# Train: [192/5441 (4%)]
# Coord loss: 0.06316979974508286
# Obj   loss: 1.3321861028671265
# NoObj loss: 1.4049314260482788
# Class loss: 1.4347988367080688
# IOU   loss: 0.42264968156814575
# Epoch    0: i =    24 ,       8.7986 ms elapsed
# Train loss =     4.88800 (min =     4.81175)     AP@0.5 = 0.30473 (max = 0.34722)
#
# Train: [200/5441 (4%)]
# Coord loss: 0.08938663452863693
# Obj   loss: 1.2052345275878906
# NoObj loss: 1.4033864736557007
# Class loss: 1.391695261001587
# IOU   loss: 0.47527170181274414
# Epoch    0: i =    25 ,       8.8081 ms elapsed
# Train loss =     4.88628 (min =     4.81175)     AP@0.5 = 0.30769 (max = 0.34722)
#
# Train: [208/5441 (4%)]
# Coord loss: 0.15987859666347504
# Obj   loss: 1.357600450515747
# NoObj loss: 1.4086506366729736
# Class loss: 1.4841740131378174
# IOU   loss: 0.7018235921859741
# Epoch    0: i =    26 ,       8.8100 ms elapsed
# Train loss =     4.88747 (min =     4.81175)     AP@0.5 = 0.30371 (max = 0.34722)
#
# Train: [216/5441 (4%)]
# Coord loss: 0.07836098968982697
# Obj   loss: 1.2954460382461548
# NoObj loss: 1.403351902961731
# Class loss: 1.0301374197006226
# IOU   loss: 0.4996456801891327
# Epoch    0: i =    27 ,       8.8243 ms elapsed
# Train loss =     4.88442 (min =     4.81175)     AP@0.5 = 0.31297 (max = 0.34722)
#
# Train: [224/5441 (4%)]
# Coord loss: 0.02936546504497528
# Obj   loss: 1.1520895957946777
# NoObj loss: 1.4031612873077393
# Class loss: 1.5154672861099243
# IOU   loss: 0.29476362466812134
# Epoch    0: i =    28 ,       8.8245 ms elapsed
# Train loss =     4.88185 (min =     4.81175)     AP@0.5 = 0.32300 (max = 0.34722)
#
# Train: [232/5441 (4%)]
# Coord loss: 0.10993720591068268
# Obj   loss: 1.2956290245056152
# NoObj loss: 1.3955682516098022
# Class loss: 0.8593058586120605
# IOU   loss: 0.5084637403488159
# Epoch    0: i =    29 ,       8.7502 ms elapsed
# Train loss =     4.87814 (min =     4.81175)     AP@0.5 = 0.32093 (max = 0.34722)
#
# Train: [240/5441 (4%)]
# Coord loss: 0.08616030216217041
# Obj   loss: 1.2840429544448853
# NoObj loss: 1.4016836881637573
# Class loss: 1.4176199436187744
# IOU   loss: 0.5048230290412903
# Epoch    0: i =    30 ,       8.8106 ms elapsed
# Train loss =     4.87719 (min =     4.81175)     AP@0.5 = 0.32167 (max = 0.34722)
#
# Train: [248/5441 (5%)]
# Coord loss: 0.26541703939437866
# Obj   loss: 1.3168028593063354
# NoObj loss: 1.4053053855895996
# Class loss: 1.9526236057281494
# IOU   loss: 0.9143863320350647
# Epoch    0: i =    31 ,       8.7529 ms elapsed
# Train loss =     4.88223 (min =     4.81175)     AP@0.5 = 0.31486 (max = 0.34722)
#
# Train: [256/5441 (5%)]
# Coord loss: 0.11985278129577637
# Obj   loss: 1.3100024461746216
# NoObj loss: 1.3941535949707031
# Class loss: 2.308717727661133
# IOU   loss: 0.603482723236084
# Epoch    0: i =    32 ,       8.8133 ms elapsed
# Train loss =     4.88661 (min =     4.81175)     AP@0.5 = 0.31506 (max = 0.34722)
#
# Train: [264/5441 (5%)]
# Coord loss: 0.06519420444965363
# Obj   loss: 1.3528066873550415
# NoObj loss: 1.4009113311767578
# Class loss: 1.1065505743026733
# IOU   loss: 0.452933669090271
# Epoch    0: i =    33 ,       8.8053 ms elapsed
# Train loss =     4.88401 (min =     4.81175)     AP@0.5 = 0.31112 (max = 0.34722)
#
# Train: [272/5441 (5%)]
# Coord loss: 0.1107497438788414
# Obj   loss: 1.3314801454544067
# NoObj loss: 1.405896782875061
# Class loss: 0.9984275102615356
# IOU   loss: 0.5667325854301453
# Epoch    0: i =    34 ,       8.8209 ms elapsed
# Train loss =     4.88162 (min =     4.81175)     AP@0.5 = 0.31313 (max = 0.34722)
#
# Train: [280/5441 (5%)]
# Coord loss: 0.11801640689373016
# Obj   loss: 1.2996762990951538
# NoObj loss: 1.404589295387268
# Class loss: 0.8814693093299866
# IOU   loss: 0.535938560962677
# Epoch    0: i =    35 ,       8.7577 ms elapsed
# Train loss =     4.87838 (min =     4.81175)     AP@0.5 = 0.31168 (max = 0.34722)
#
# Train: [288/5441 (5%)]
# Coord loss: 0.16086865961551666
# Obj   loss: 1.3308292627334595
# NoObj loss: 1.396945834159851
# Class loss: 1.1453889608383179
# IOU   loss: 0.6865843534469604
# Epoch    0: i =    36 ,       8.7675 ms elapsed
# Train loss =     4.87759 (min =     4.81175)     AP@0.5 = 0.31357 (max = 0.34722)
#
# Train: [296/5441 (5%)]
# Coord loss: 0.08343867212533951
# Obj   loss: 1.29019033908844
# NoObj loss: 1.4048670530319214
# Class loss: 1.726746916770935
# IOU   loss: 0.45741310715675354
# Epoch    0: i =    37 ,       8.8284 ms elapsed
# Train loss =     4.87801 (min =     4.81175)     AP@0.5 = 0.31218 (max = 0.34722)
#
# Train: [304/5441 (6%)]
# Coord loss: 0.08109617233276367
# Obj   loss: 1.202762484550476
# NoObj loss: 1.4055757522583008
# Class loss: 1.1103441715240479
# IOU   loss: 0.5193911790847778
# Epoch    0: i =    38 ,       8.8269 ms elapsed
# Train loss =     4.87523 (min =     4.81175)     AP@0.5 = 0.31706 (max = 0.34722)
#
# Train: [312/5441 (6%)]
# Coord loss: 0.07072223722934723
# Obj   loss: 1.3254653215408325
# NoObj loss: 1.398618459701538
# Class loss: 0.956680178642273
# IOU   loss: 0.4060255289077759
# Epoch    0: i =    39 ,       8.8498 ms elapsed
# Train loss =     4.87168 (min =     4.81175)     AP@0.5 = 0.31790 (max = 0.34722)
#
# Train: [320/5441 (6%)]
# Coord loss: 0.13914819061756134
# Obj   loss: 1.3658090829849243
# NoObj loss: 1.4135910272598267
# Class loss: 1.7870814800262451
# IOU   loss: 0.675848662853241
# Epoch    0: i =    40 ,       8.8020 ms elapsed
# Train loss =     4.87419 (min =     4.81175)     AP@0.5 = 0.31561 (max = 0.34722)
#
# Train: [328/5441 (6%)]
# Coord loss: 0.17339226603507996
# Obj   loss: 1.3228076696395874
# NoObj loss: 1.4052037000656128
# Class loss: 1.1760011911392212
# IOU   loss: 0.7056191563606262
# Epoch    0: i =    41 ,       8.7694 ms elapsed
# Train loss =     4.87374 (min =     4.81175)     AP@0.5 = 0.31629 (max = 0.34722)
#
# Train: [336/5441 (6%)]
# Coord loss: 0.13854755461215973
# Obj   loss: 1.2471225261688232
# NoObj loss: 1.3988920450210571
# Class loss: 1.602198839187622
# IOU   loss: 0.5994170904159546
# Epoch    0: i =    42 ,       8.7381 ms elapsed
# Train loss =     4.87429 (min =     4.81175)     AP@0.5 = 0.31781 (max = 0.34722)
#
# Train: [344/5441 (6%)]
# Coord loss: 0.07846412062644958
# Obj   loss: 1.3160914182662964
# NoObj loss: 1.3969128131866455
# Class loss: 1.8123310804367065
# IOU   loss: 0.48479193449020386
# Epoch    0: i =    43 ,       8.7944 ms elapsed
# Train loss =     4.87533 (min =     4.81175)     AP@0.5 = 0.31788 (max = 0.34722)
#
# Train: [352/5441 (6%)]
# Coord loss: 0.045712221413850784
# Obj   loss: 1.2355724573135376
# NoObj loss: 1.399057388305664
# Class loss: 2.1659159660339355
# IOU   loss: 0.40229031443595886
# Epoch    0: i =    44 ,       8.7677 ms elapsed
# Train loss =     4.87714 (min =     4.81175)     AP@0.5 = 0.31930 (max = 0.34722)
#
# Train: [360/5441 (7%)]
# Coord loss: 0.11330832540988922
# Obj   loss: 1.376352071762085
# NoObj loss: 1.4128588438034058
# Class loss: 1.5676981210708618
# IOU   loss: 0.6717771291732788
# Epoch    0: i =    45 ,       8.7429 ms elapsed
# Train loss =     4.87841 (min =     4.81175)     AP@0.5 = 0.31281 (max = 0.34722)
#
# Train: [368/5441 (7%)]
# Coord loss: 0.11593750864267349
# Obj   loss: 1.2483710050582886
# NoObj loss: 1.4095971584320068
# Class loss: 1.1988928318023682
# IOU   loss: 0.475373238325119
# Epoch    0: i =    46 ,       8.7428 ms elapsed
# Train loss =     4.87635 (min =     4.81175)     AP@0.5 = 0.31427 (max = 0.34722)
#
# Train: [376/5441 (7%)]
# Coord loss: 0.08987166732549667
# Obj   loss: 1.3014965057373047
# NoObj loss: 1.4091975688934326
# Class loss: 1.2895376682281494
# IOU   loss: 0.45949724316596985
# Epoch    0: i =    47 ,       8.7702 ms elapsed
# Train loss =     4.87479 (min =     4.81175)     AP@0.5 = 0.31567 (max = 0.34722)
#
# Train: [384/5441 (7%)]
# Coord loss: 0.1437317579984665
# Obj   loss: 1.3386682271957397
# NoObj loss: 1.396835446357727
# Class loss: 1.7724010944366455
# IOU   loss: 0.6418203711509705
# Epoch    0: i =    48 ,       8.7564 ms elapsed
# Train loss =     4.87678 (min =     4.81175)     AP@0.5 = 0.31761 (max = 0.34722)
#
# Train: [392/5441 (7%)]
# Coord loss: 0.042288508266210556
# Obj   loss: 1.1963635683059692
# NoObj loss: 1.401872992515564
# Class loss: 1.2054295539855957
# IOU   loss: 0.28117406368255615
# Epoch    0: i =    49 ,       8.7171 ms elapsed
# Train loss =     4.87324 (min =     4.81175)     AP@0.5 = 0.31769 (max = 0.34722)
#
# Train: [400/5441 (7%)]
# Coord loss: 0.10268881171941757
# Obj   loss: 1.3403687477111816
# NoObj loss: 1.3987149000167847
# Class loss: 0.8913488388061523
# IOU   loss: 0.5443743467330933
# Epoch    0: i =    50 ,       8.7512 ms elapsed
# Train loss =     4.87045 (min =     4.81175)     AP@0.5 = 0.31894 (max = 0.34722)
#
# Train: [408/5441 (7%)]
# Coord loss: 0.185817688703537
# Obj   loss: 1.2415432929992676
# NoObj loss: 1.399011254310608
# Class loss: 1.5258198976516724
# IOU   loss: 0.7316600680351257
# Epoch    0: i =    51 ,       8.7334 ms elapsed
# Train loss =     4.87144 (min =     4.81175)     AP@0.5 = 0.32015 (max = 0.34722)
#
# Train: [416/5441 (8%)]
# Coord loss: 0.19840247929096222
# Obj   loss: 1.3375779390335083
# NoObj loss: 1.4076080322265625
# Class loss: 0.830207109451294
# IOU   loss: 0.8045554757118225
# Epoch    0: i =    52 ,       8.7340 ms elapsed
# Train loss =     4.87008 (min =     4.81175)     AP@0.5 = 0.31903 (max = 0.34722)
#
# Train: [424/5441 (8%)]
# Coord loss: 0.058624256402254105
# Obj   loss: 1.2628412246704102
# NoObj loss: 1.4097450971603394
# Class loss: 1.3020124435424805
# IOU   loss: 0.30365419387817383
# Epoch    0: i =    53 ,       8.7119 ms elapsed
# Train loss =     4.86761 (min =     4.81175)     AP@0.5 = 0.32801 (max = 0.34722)
#
# Train: [432/5441 (8%)]
# Coord loss: 0.07456099987030029
# Obj   loss: 1.1784439086914062
# NoObj loss: 1.4059911966323853
# Class loss: 0.8824830651283264
# IOU   loss: 0.3722400963306427
# Epoch    0: i =    54 ,       8.6713 ms elapsed
# Train loss =     4.86322 (min =     4.81175)     AP@0.5 = 0.32829 (max = 0.34722)
#
# Train: [440/5441 (8%)]
# Coord loss: 0.039146993309259415
# Obj   loss: 1.2367174625396729
# NoObj loss: 1.4017918109893799
# Class loss: 1.024773359298706
# IOU   loss: 0.23641973733901978
# Epoch    0: i =    55 ,       8.6550 ms elapsed
# Train loss =     4.85898 (min =     4.81175)     AP@0.5 = 0.33316 (max = 0.34722)
#
# Train: [448/5441 (8%)]
# Coord loss: 0.10212421417236328
# Obj   loss: 1.3117536306381226
# NoObj loss: 1.397642970085144
# Class loss: 1.284135341644287
# IOU   loss: 0.578942060470581
# Epoch    0: i =    56 ,       8.6859 ms elapsed
# Train loss =     4.85813 (min =     4.81175)     AP@0.5 = 0.33614 (max = 0.34722)
#
# Train: [456/5441 (8%)]
# Coord loss: 0.14806930720806122
# Obj   loss: 1.3494316339492798
# NoObj loss: 1.4073468446731567
# Class loss: 1.1692448854446411
# IOU   loss: 0.7251200079917908
# Epoch    0: i =    57 ,       8.6751 ms elapsed
# Train loss =     4.85787 (min =     4.81175)     AP@0.5 = 0.33484 (max = 0.34722)
#
# Train: [464/5441 (9%)]
# Coord loss: 0.17022180557250977
# Obj   loss: 1.2309978008270264
# NoObj loss: 1.4018821716308594
# Class loss: 0.9889147877693176
# IOU   loss: 0.5082694292068481
# Epoch    0: i =    58 ,       8.6482 ms elapsed
# Train loss =     4.85534 (min =     4.81175)     AP@0.5 = 0.33666 (max = 0.34722)
#
# Train: [472/5441 (9%)]
# Coord loss: 0.089503213763237
# Obj   loss: 1.3148999214172363
# NoObj loss: 1.4078716039657593
# Class loss: 1.959756851196289
# IOU   loss: 0.49525660276412964
# Epoch    0: i =    59 ,       8.6067 ms elapsed
# Train loss =     4.85720 (min =     4.81175)     AP@0.5 = 0.33742 (max = 0.34722)
#
# Train: [480/5441 (9%)]
# Coord loss: 0.2611219882965088
# Obj   loss: 1.3174772262573242
# NoObj loss: 1.4001771211624146
# Class loss: 3.0324501991271973
# IOU   loss: 0.8266898393630981
# Epoch    0: i =    60 ,       8.6493 ms elapsed
# Train loss =     4.86608 (min =     4.81175)     AP@0.5 = 0.33815 (max = 0.34722)
#
# Train: [488/5441 (9%)]
# Coord loss: 0.07266803830862045
# Obj   loss: 1.3706194162368774
# NoObj loss: 1.4014737606048584
# Class loss: 1.689971685409546
# IOU   loss: 0.5543177723884583
# Epoch    0: i =    61 ,       8.5990 ms elapsed
# Train loss =     4.86708 (min =     4.81175)     AP@0.5 = 0.33691 (max = 0.34722)
#
# Train: [496/5441 (9%)]
# Coord loss: 0.09598872065544128
# Obj   loss: 1.2873061895370483
# NoObj loss: 1.404950499534607
# Class loss: 1.3984875679016113
# IOU   loss: 0.4159151613712311
# Epoch    0: i =    62 ,       8.5807 ms elapsed
# Train loss =     4.86590 (min =     4.81175)     AP@0.5 = 0.33955 (max = 0.34722)
#
# Train: [504/5441 (9%)]
# Coord loss: 0.10023045539855957
# Obj   loss: 1.2546236515045166
# NoObj loss: 1.408626675605774
# Class loss: 1.456629991531372
# IOU   loss: 0.5074198246002197
# Epoch    0: i =    63 ,       8.5636 ms elapsed
# Train loss =     4.86529 (min =     4.81175)     AP@0.5 = 0.34116 (max = 0.34722)
#
# Train: [512/5441 (9%)]
# Coord loss: 0.13965891301631927
# Obj   loss: 1.32350492477417
# NoObj loss: 1.401756763458252
# Class loss: 1.129643440246582
# IOU   loss: 0.5672502517700195
# Epoch    0: i =    64 ,       8.5501 ms elapsed
# Train loss =     4.86395 (min =     4.81175)     AP@0.5 = 0.33807 (max = 0.34722)
#
# Train: [520/5441 (10%)]
# Coord loss: 0.08923119306564331
# Obj   loss: 1.2924100160598755
# NoObj loss: 1.4049547910690308
# Class loss: 1.8781380653381348
# IOU   loss: 0.4227496087551117
# Epoch    0: i =    65 ,       8.5458 ms elapsed
# Train loss =     4.86493 (min =     4.81175)     AP@0.5 = 0.33813 (max = 0.34722)
#
# Train: [528/5441 (10%)]
# Coord loss: 0.08769187331199646
# Obj   loss: 1.2072622776031494
# NoObj loss: 1.4040040969848633
# Class loss: 0.8565512299537659
# IOU   loss: 0.5541919469833374
# Epoch    0: i =    66 ,       8.5433 ms elapsed
# Train loss =     4.86163 (min =     4.81175)     AP@0.5 = 0.34059 (max = 0.34722)
#
# Train: [536/5441 (10%)]
# Coord loss: 0.09638067334890366
# Obj   loss: 1.322200059890747
# NoObj loss: 1.4056485891342163
# Class loss: 1.592900037765503
# IOU   loss: 0.6086810231208801
# Epoch    0: i =    67 ,       8.5413 ms elapsed
# Train loss =     4.86235 (min =     4.81175)     AP@0.5 = 0.33986 (max = 0.34722)
#
# Train: [544/5441 (10%)]
# Coord loss: 0.06700039654970169
# Obj   loss: 1.2997413873672485
# NoObj loss: 1.4037519693374634
# Class loss: 1.0470730066299438
# IOU   loss: 0.4838988780975342
# Epoch    0: i =    68 ,       8.5585 ms elapsed
# Train loss =     4.85992 (min =     4.81175)     AP@0.5 = 0.33872 (max = 0.34722)
#
# Train: [552/5441 (10%)]
# Coord loss: 0.12865519523620605
# Obj   loss: 1.3259212970733643
# NoObj loss: 1.400597095489502
# Class loss: 1.5554254055023193
# IOU   loss: 0.7053873538970947
# Epoch    0: i =    69 ,       8.5221 ms elapsed
# Train loss =     4.86102 (min =     4.81175)     AP@0.5 = 0.33588 (max = 0.34722)
#
# Train: [560/5441 (10%)]
# Coord loss: 0.1869126409292221
# Obj   loss: 1.2424747943878174
# NoObj loss: 1.3960820436477661
# Class loss: 0.8673286437988281
# IOU   loss: 0.6055704951286316
# Epoch    0: i =    70 ,       8.5216 ms elapsed
# Train loss =     4.85861 (min =     4.81175)     AP@0.5 = 0.34079 (max = 0.34722)
#
# Train: [568/5441 (10%)]
# Coord loss: 0.07779357582330704
# Obj   loss: 1.3446273803710938
# NoObj loss: 1.4028087854385376
# Class loss: 2.0077271461486816
# IOU   loss: 0.6065455079078674
# Epoch    0: i =    71 ,       8.5534 ms elapsed
# Train loss =     4.86109 (min =     4.81175)     AP@0.5 = 0.33800 (max = 0.34722)
#
# Train: [576/5441 (11%)]
# Coord loss: 0.08357150107622147
# Obj   loss: 1.2777122259140015
# NoObj loss: 1.3984020948410034
# Class loss: 1.0170787572860718
# IOU   loss: 0.44621023535728455
# Epoch    0: i =    72 ,       8.5418 ms elapsed
# Train loss =     4.85838 (min =     4.81175)     AP@0.5 = 0.33641 (max = 0.34722)
#
# Train: [584/5441 (11%)]
# Coord loss: 0.11243019253015518
# Obj   loss: 1.3009247779846191
# NoObj loss: 1.3963000774383545
# Class loss: 2.338430881500244
# IOU   loss: 0.564866840839386
# Epoch    0: i =    73 ,       8.5244 ms elapsed
# Train loss =     4.86200 (min =     4.81175)     AP@0.5 = 0.33866 (max = 0.34722)
#
# Train: [592/5441 (11%)]
# Coord loss: 0.08982861787080765
# Obj   loss: 1.3268846273422241
# NoObj loss: 1.401328206062317
# Class loss: 0.8031632900238037
# IOU   loss: 0.5279017686843872
# Epoch    0: i =    74 ,       8.4776 ms elapsed
# Train loss =     4.85899 (min =     4.81175)     AP@0.5 = 0.33762 (max = 0.34722)
#
# Train: [600/5441 (11%)]
# Coord loss: 0.13625262677669525
# Obj   loss: 1.3111435174942017
# NoObj loss: 1.4013488292694092
# Class loss: 1.0198001861572266
# IOU   loss: 0.7484338879585266
# Epoch    0: i =    75 ,       8.4819 ms elapsed
# Train loss =     4.85797 (min =     4.81175)     AP@0.5 = 0.33741 (max = 0.34722)
#
# Train: [608/5441 (11%)]
# Coord loss: 0.09382151812314987
# Obj   loss: 1.3422092199325562
# NoObj loss: 1.4052437543869019
# Class loss: 1.105912685394287
# IOU   loss: 0.6782241463661194
# Epoch    0: i =    76 ,       8.4752 ms elapsed
# Train loss =     4.85700 (min =     4.81175)     AP@0.5 = 0.33957 (max = 0.34722)
#
# Train: [616/5441 (11%)]
# Coord loss: 0.1064009964466095
# Obj   loss: 1.291023850440979
# NoObj loss: 1.4017784595489502
# Class loss: 1.5885179042816162
# IOU   loss: 0.5246273875236511
# Epoch    0: i =    77 ,       8.4711 ms elapsed
# Train loss =     4.85723 (min =     4.81175)     AP@0.5 = 0.34011 (max = 0.34722)
#
# Train: [624/5441 (11%)]
# Coord loss: 0.17193476855754852
# Obj   loss: 1.3199326992034912
# NoObj loss: 1.4003044366836548
# Class loss: 1.4124281406402588
# IOU   loss: 0.6856858730316162
# Epoch    0: i =    78 ,       8.4501 ms elapsed
# Train loss =     4.85778 (min =     4.81175)     AP@0.5 = 0.33682 (max = 0.34722)
#
# Train: [632/5441 (12%)]
# Coord loss: 0.16301289200782776
# Obj   loss: 1.3358633518218994
# NoObj loss: 1.3993171453475952
# Class loss: 2.3527393341064453
# IOU   loss: 0.7592257261276245
# Epoch    0: i =    79 ,       8.4476 ms elapsed
# Train loss =     4.86254 (min =     4.81175)     AP@0.5 = 0.33437 (max = 0.34722)
#
# Train: [640/5441 (12%)]
# Coord loss: 0.2176581174135208
# Obj   loss: 1.318873643875122
# NoObj loss: 1.4035744667053223
# Class loss: 0.8002148866653442
# IOU   loss: 0.6967042088508606
# Epoch    0: i =    80 ,       8.4477 ms elapsed
# Train loss =     4.86079 (min =     4.81175)     AP@0.5 = 0.33496 (max = 0.34722)
#
# Train: [648/5441 (12%)]
# Coord loss: 0.05930553749203682
# Obj   loss: 1.261831521987915
# NoObj loss: 1.3976106643676758
# Class loss: 1.232164740562439
# IOU   loss: 0.43079811334609985
# Epoch    0: i =    81 ,       8.4430 ms elapsed
# Train loss =     4.85883 (min =     4.81175)     AP@0.5 = 0.33358 (max = 0.34722)
#
# Train: [656/5441 (12%)]
# Coord loss: 0.0738757774233818
# Obj   loss: 1.2826945781707764
# NoObj loss: 1.3967691659927368
# Class loss: 1.3821302652359009
# IOU   loss: 0.4297456741333008
# Epoch    0: i =    82 ,       8.4254 ms elapsed
# Train loss =     4.85763 (min =     4.81175)     AP@0.5 = 0.33452 (max = 0.34722)
#
# Train: [664/5441 (12%)]
# Coord loss: 0.16557714343070984
# Obj   loss: 1.3923211097717285
# NoObj loss: 1.4055167436599731
# Class loss: 1.270536184310913
# IOU   loss: 0.8547317385673523
# Epoch    0: i =    83 ,       8.4033 ms elapsed
# Train loss =     4.85857 (min =     4.81175)     AP@0.5 = 0.33221 (max = 0.34722)
#
# Train: [672/5441 (12%)]
# Coord loss: 0.08136807382106781
# Obj   loss: 1.3191817998886108
# NoObj loss: 1.4003652334213257
# Class loss: 1.987247109413147
# IOU   loss: 0.44210267066955566
# Epoch    0: i =    84 ,       8.4122 ms elapsed
# Train loss =     4.86007 (min =     4.81175)     AP@0.5 = 0.33163 (max = 0.34722)
#
# Train: [680/5441 (12%)]
# Coord loss: 0.12130346149206161
# Obj   loss: 1.2612336874008179
# NoObj loss: 1.399818778038025
# Class loss: 1.2126741409301758
# IOU   loss: 0.507396399974823
# Epoch    0: i =    85 ,       8.3969 ms elapsed
# Train loss =     4.85863 (min =     4.81175)     AP@0.5 = 0.33431 (max = 0.34722)
#
# Train: [688/5441 (13%)]
# Coord loss: 0.0941476970911026
# Obj   loss: 1.2563658952713013
# NoObj loss: 1.4018000364303589
# Class loss: 0.9884993433952332
# IOU   loss: 0.5955386161804199
# Epoch    0: i =    86 ,       8.3827 ms elapsed
# Train loss =     4.85654 (min =     4.81175)     AP@0.5 = 0.33416 (max = 0.34722)
#
# Train: [696/5441 (13%)]
# Coord loss: 0.0720217227935791
# Obj   loss: 1.2996535301208496
# NoObj loss: 1.4051402807235718
# Class loss: 1.1875622272491455
# IOU   loss: 0.553803026676178
# Epoch    0: i =    87 ,       8.4074 ms elapsed
# Train loss =     4.85518 (min =     4.81175)     AP@0.5 = 0.33607 (max = 0.34722)
#
# Train: [704/5441 (13%)]
# Coord loss: 0.09276127070188522
# Obj   loss: 1.3149956464767456
# NoObj loss: 1.4096742868423462
# Class loss: 1.1451222896575928
# IOU   loss: 0.479763925075531
# Epoch    0: i =    88 ,       8.3792 ms elapsed
# Train loss =     4.85354 (min =     4.81175)     AP@0.5 = 0.33659 (max = 0.34722)
#
# Train: [712/5441 (13%)]
# Coord loss: 0.10428006947040558
# Obj   loss: 1.2806470394134521
# NoObj loss: 1.4044594764709473
# Class loss: 1.742483139038086
# IOU   loss: 0.5499486327171326
# Epoch    0: i =    89 ,       8.3771 ms elapsed
# Train loss =     4.85444 (min =     4.81175)     AP@0.5 = 0.33643 (max = 0.34722)
#
# Train: [720/5441 (13%)]
# Coord loss: 0.28148138523101807
# Obj   loss: 1.2213817834854126
# NoObj loss: 1.4036986827850342
# Class loss: 0.9086061716079712
# IOU   loss: 0.7158899903297424
# Epoch    0: i =    90 ,       8.3822 ms elapsed
# Train loss =     4.85316 (min =     4.81175)     AP@0.5 = 0.33825 (max = 0.34722)
#
# Train: [728/5441 (13%)]
# Coord loss: 0.16264179348945618
# Obj   loss: 1.360153079032898
# NoObj loss: 1.4008153676986694
# Class loss: 1.9793847799301147
# IOU   loss: 0.6802763938903809
# Epoch    0: i =    91 ,       8.3942 ms elapsed
# Train loss =     4.85604 (min =     4.81175)     AP@0.5 = 0.33873 (max = 0.34722)
#
# Train: [736/5441 (14%)]
# Coord loss: 0.06852008402347565
# Obj   loss: 1.247344970703125
# NoObj loss: 1.4049123525619507
# Class loss: 0.8569411635398865
# IOU   loss: 0.3495502471923828
# Epoch    0: i =    92 ,       8.4262 ms elapsed
# Train loss =     4.85240 (min =     4.81175)     AP@0.5 = 0.34049 (max = 0.34722)
#
# Train: [744/5441 (14%)]
# Coord loss: 0.1315613090991974
# Obj   loss: 1.2653040885925293
# NoObj loss: 1.3949863910675049
# Class loss: 1.303075909614563
# IOU   loss: 0.5973538160324097
# Epoch    0: i =    93 ,       8.4351 ms elapsed
# Train loss =     4.85177 (min =     4.81175)     AP@0.5 = 0.33965 (max = 0.34722)
#
# Train: [752/5441 (14%)]
# Coord loss: 0.14931142330169678
# Obj   loss: 1.3605520725250244
# NoObj loss: 1.4007577896118164
# Class loss: 1.9855883121490479
# IOU   loss: 0.7592119574546814
# Epoch    0: i =    94 ,       8.4274 ms elapsed
# Train loss =     4.85490 (min =     4.81175)     AP@0.5 = 0.33862 (max = 0.34722)
#
# Train: [760/5441 (14%)]
# Coord loss: 0.17222793400287628
# Obj   loss: 1.3070720434188843
# NoObj loss: 1.4075043201446533
# Class loss: 1.3433332443237305
# IOU   loss: 0.713069498538971
# Epoch    0: i =    95 ,       8.4377 ms elapsed
# Train loss =     4.85524 (min =     4.81175)     AP@0.5 = 0.33865 (max = 0.34722)
#
# Train: [768/5441 (14%)]
# Coord loss: 0.07874350994825363
# Obj   loss: 1.2568062543869019
# NoObj loss: 1.402472734451294
# Class loss: 1.5990796089172363
# IOU   loss: 0.4161917269229889
# Epoch    0: i =    96 ,       8.4350 ms elapsed
# Train loss =     4.85485 (min =     4.81175)     AP@0.5 = 0.33910 (max = 0.34722)
#
# Train: [776/5441 (14%)]
# Coord loss: 0.06970489770174026
# Obj   loss: 1.2627105712890625
# NoObj loss: 1.4040480852127075
# Class loss: 0.9185304641723633
# IOU   loss: 0.4776766002178192
# Epoch    0: i =    97 ,       8.4110 ms elapsed
# Train loss =     4.85207 (min =     4.81175)     AP@0.5 = 0.33953 (max = 0.34722)
#
# Train: [784/5441 (14%)]
# Coord loss: 0.11036548018455505
# Obj   loss: 1.3550142049789429
# NoObj loss: 1.4024759531021118
# Class loss: 1.6896708011627197
# IOU   loss: 0.5618427395820618
# Epoch    0: i =    98 ,       8.4027 ms elapsed
# Train loss =     4.85309 (min =     4.81175)     AP@0.5 = 0.33713 (max = 0.34722)
#
# Train: [792/5441 (15%)]
# Coord loss: 0.09220446646213531
# Obj   loss: 1.2416903972625732
# NoObj loss: 1.403458595275879
# Class loss: 2.148766040802002
# IOU   loss: 0.5792786478996277
# Epoch    0: i =    99 ,       8.4147 ms elapsed
# Train loss =     4.85543 (min =     4.81175)     AP@0.5 = 0.33878 (max = 0.34722)
#
# Train: [800/5441 (15%)]
# Coord loss: 0.13007265329360962
# Obj   loss: 1.305473804473877
# NoObj loss: 1.4001729488372803
# Class loss: 1.072819709777832
# IOU   loss: 0.5729135870933533
# Epoch    0: i =   100 ,       8.4114 ms elapsed
# Train loss =     4.85401 (min =     4.81175)     AP@0.5 = 0.33802 (max = 0.34722)
#
# Train: [808/5441 (15%)]
# Coord loss: 0.09805144369602203
# Obj   loss: 1.2812846899032593
# NoObj loss: 1.4019381999969482
# Class loss: 1.826508641242981
# IOU   loss: 0.5108596086502075
# Epoch    0: i =   101 ,       8.4293 ms elapsed
# Train loss =     4.85501 (min =     4.81175)     AP@0.5 = 0.33766 (max = 0.34722)
#
# Train: [816/5441 (15%)]
# Coord loss: 0.10853660106658936
# Obj   loss: 1.3955755233764648
# NoObj loss: 1.4049034118652344
# Class loss: 0.8880839943885803
# IOU   loss: 0.5355268120765686
# Epoch    0: i =   102 ,       8.4122 ms elapsed
# Train loss =     4.85304 (min =     4.81175)     AP@0.5 = 0.33575 (max = 0.34722)
#
# Train: [824/5441 (15%)]
# Coord loss: 0.06470401585102081
# Obj   loss: 1.265733003616333
# NoObj loss: 1.4036636352539062
# Class loss: 1.269789218902588
# IOU   loss: 0.4021325707435608
# Epoch    0: i =   103 ,       8.4216 ms elapsed
# Train loss =     4.85136 (min =     4.81175)     AP@0.5 = 0.33659 (max = 0.34722)
#
# Train: [832/5441 (15%)]
# Coord loss: 0.07862794399261475
# Obj   loss: 1.2879003286361694
# NoObj loss: 1.4082638025283813
# Class loss: 2.097764730453491
# IOU   loss: 0.46794864535331726
# Epoch    0: i =   104 ,       8.4357 ms elapsed
# Train loss =     4.85319 (min =     4.81175)     AP@0.5 = 0.33664 (max = 0.34722)
#
# Train: [840/5441 (15%)]
# Coord loss: 0.08103501051664352
# Obj   loss: 1.1844518184661865
# NoObj loss: 1.400235652923584
# Class loss: 1.0977234840393066
# IOU   loss: 0.4477417767047882
# Epoch    0: i =   105 ,       8.4327 ms elapsed
# Train loss =     4.85080 (min =     4.81175)     AP@0.5 = 0.33934 (max = 0.34722)
#
# Train: [848/5441 (16%)]
# Coord loss: 0.10454434156417847
# Obj   loss: 1.3265745639801025
# NoObj loss: 1.4023700952529907
# Class loss: 1.5758728981018066
# IOU   loss: 0.5158824324607849
# Epoch    0: i =   106 ,       8.4211 ms elapsed
# Train loss =     4.85107 (min =     4.81175)     AP@0.5 = 0.33973 (max = 0.34722)
#
# Train: [856/5441 (16%)]
# Coord loss: 0.07393151521682739
# Obj   loss: 1.3023959398269653
# NoObj loss: 1.4043289422988892
# Class loss: 0.9324772357940674
# IOU   loss: 0.3686067461967468
# Epoch    0: i =   107 ,       8.4014 ms elapsed
# Train loss =     4.84822 (min =     4.81175)     AP@0.5 = 0.33901 (max = 0.34722)
#
# Train: [864/5441 (16%)]
# Coord loss: 0.18595056235790253
# Obj   loss: 1.3154891729354858
# NoObj loss: 1.3990925550460815
# Class loss: 1.6771137714385986
# IOU   loss: 0.5951950550079346
# Epoch    0: i =   108 ,       8.3973 ms elapsed
# Train loss =     4.84942 (min =     4.81175)     AP@0.5 = 0.33931 (max = 0.34722)
#
# Train: [872/5441 (16%)]
# Coord loss: 0.05993127077817917
# Obj   loss: 1.3067352771759033
# NoObj loss: 1.397330403327942
# Class loss: 1.665187120437622
# IOU   loss: 0.4045247435569763
# Epoch    0: i =   109 ,       8.3906 ms elapsed
# Train loss =     4.84936 (min =     4.81175)     AP@0.5 = 0.34151 (max = 0.34722)
#
# Train: [880/5441 (16%)]
# Coord loss: 0.08842479437589645
# Obj   loss: 1.2977133989334106
# NoObj loss: 1.4011584520339966
# Class loss: 1.1364202499389648
# IOU   loss: 0.5036881566047668
# Epoch    0: i =   110 ,       8.3786 ms elapsed
# Train loss =     4.84782 (min =     4.81175)     AP@0.5 = 0.34332 (max = 0.34722)
#
# Train: [888/5441 (16%)]
# Coord loss: 0.08328835666179657
# Obj   loss: 1.2874391078948975
# NoObj loss: 1.400328278541565
# Class loss: 1.3720141649246216
# IOU   loss: 0.5332527160644531
# Epoch    0: i =   111 ,       8.3577 ms elapsed
# Train loss =     4.84719 (min =     4.81175)     AP@0.5 = 0.34259 (max = 0.34722)
#
# Train: [896/5441 (16%)]
# Coord loss: 0.1007358655333519
# Obj   loss: 1.243912696838379
# NoObj loss: 1.4019711017608643
# Class loss: 1.002926230430603
# IOU   loss: 0.46602535247802734
# Epoch    0: i =   112 ,       8.3539 ms elapsed
# Train loss =     4.84489 (min =     4.81175)     AP@0.5 = 0.34613 (max = 0.34722)
#
# Train: [904/5441 (17%)]
# Coord loss: 0.07780160009860992
# Obj   loss: 1.325243592262268
# NoObj loss: 1.4002383947372437
# Class loss: 1.9994399547576904
# IOU   loss: 0.5598750114440918
# Epoch    0: i =   113 ,       8.3472 ms elapsed
# Train loss =     4.84677 (min =     4.81175)     AP@0.5 = 0.34644 (max = 0.34722)
#
# Train: [912/5441 (17%)]
# Coord loss: 0.07263629138469696
# Obj   loss: 1.3394572734832764
# NoObj loss: 1.406507134437561
# Class loss: 1.243009328842163
# IOU   loss: 0.44436386227607727
# Epoch    0: i =   114 ,       8.3547 ms elapsed
# Train loss =     4.84554 (min =     4.81175)     AP@0.5 = 0.34466 (max = 0.34722)
#
# Train: [920/5441 (17%)]
# Coord loss: 0.06617038697004318
# Obj   loss: 1.3160480260849
# NoObj loss: 1.404405951499939
# Class loss: 1.853200912475586
# IOU   loss: 0.5100167393684387
# Epoch    0: i =   115 ,       8.3381 ms elapsed
# Train loss =     4.84663 (min =     4.81175)     AP@0.5 = 0.34602 (max = 0.34722)
#
# Train: [928/5441 (17%)]
# Coord loss: 0.02862412855029106
# Obj   loss: 1.108791470527649
# NoObj loss: 1.3982688188552856
# Class loss: 1.055612325668335
# IOU   loss: 0.23177707195281982
# Epoch    0: i =   116 ,       8.3425 ms elapsed
# Train loss =     4.84297 (min =     4.81175)     AP@0.5 = 0.34838 (max = 0.34722)
#
# Train: [936/5441 (17%)]
# Coord loss: 0.1714768409729004
# Obj   loss: 1.3417398929595947
# NoObj loss: 1.408560037612915
# Class loss: 1.7083886861801147
# IOU   loss: 0.8153566122055054
# Epoch    0: i =   117 ,       8.3229 ms elapsed
# Train loss =     4.84512 (min =     4.81175)     AP@0.5 = 0.34730 (max = 0.34722)
#
# Train: [944/5441 (17%)]
# Coord loss: 0.07679519802331924
# Obj   loss: 1.183653473854065
# NoObj loss: 1.3955570459365845
# Class loss: 0.8058338165283203
# IOU   loss: 0.3450281023979187
# Epoch    0: i =   118 ,       8.3229 ms elapsed
# Train loss =     4.84142 (min =     4.81175)     AP@0.5 = 0.35062 (max = 0.34722)
#
# Train: [952/5441 (17%)]
# Coord loss: 0.08817102015018463
# Obj   loss: 1.2430990934371948
# NoObj loss: 1.4066044092178345
# Class loss: 1.210487961769104
# IOU   loss: 0.461161345243454
# Epoch    0: i =   119 ,       8.3349 ms elapsed
# Train loss =     4.83989 (min =     4.81175)     AP@0.5 = 0.35238 (max = 0.34722)
#
# Train: [960/5441 (18%)]
# Coord loss: 0.13566790521144867
# Obj   loss: 1.1772257089614868
# NoObj loss: 1.4000630378723145
# Class loss: 0.8106823563575745
# IOU   loss: 0.42217758297920227
# Epoch    0: i =   120 ,       8.3568 ms elapsed
# Train loss =     4.83673 (min =     4.81175)     AP@0.5 = 0.35485 (max = 0.34722)
#
# Train: [968/5441 (18%)]
# Coord loss: 0.08509782701730728
# Obj   loss: 1.2575808763504028
# NoObj loss: 1.402182698249817
# Class loss: 0.8711947202682495
# IOU   loss: 0.5376227498054504
# Epoch    0: i =   121 ,       8.3549 ms elapsed
# Train loss =     4.83433 (min =     4.81175)     AP@0.5 = 0.35606 (max = 0.34722)
#
# Train: [976/5441 (18%)]
# Coord loss: 0.0717305988073349
# Obj   loss: 1.2360279560089111
# NoObj loss: 1.4015589952468872
# Class loss: 1.9660437107086182
# IOU   loss: 0.4491352140903473
# Epoch    0: i =   122 ,       8.3508 ms elapsed
# Train loss =     4.83535 (min =     4.81175)     AP@0.5 = 0.35627 (max = 0.34722)
#
# Train: [984/5441 (18%)]
# Coord loss: 0.24744105339050293
# Obj   loss: 1.3537660837173462
# NoObj loss: 1.4069545269012451
# Class loss: 1.1946964263916016
# IOU   loss: 0.7907953262329102
# Epoch    0: i =   123 ,       8.3389 ms elapsed
# Train loss =     4.83590 (min =     4.81175)     AP@0.5 = 0.35551 (max = 0.34722)
#
# Train: [992/5441 (18%)]
# Coord loss: 0.08754131197929382
# Obj   loss: 1.2662861347198486
# NoObj loss: 1.4021263122558594
# Class loss: 1.9169169664382935
# IOU   loss: 0.4068642258644104
# Epoch    0: i =   124 ,       8.3473 ms elapsed
# Train loss =     4.83675 (min =     4.81175)     AP@0.5 = 0.35669 (max = 0.34722)
#
# Train: [1000/5441 (18%)]
# Coord loss: 0.08447075635194778
# Obj   loss: 1.2867132425308228
# NoObj loss: 1.39749014377594
# Class loss: 2.273482322692871
# IOU   loss: 0.451536625623703
# Epoch    0: i =   125 ,       8.3358 ms elapsed
# Train loss =     4.83903 (min =     4.81175)     AP@0.5 = 0.35593 (max = 0.34722)
#
# Train: [1008/5441 (19%)]
# Coord loss: 0.07045409083366394
# Obj   loss: 1.3391374349594116
# NoObj loss: 1.4069706201553345
# Class loss: 1.1372132301330566
# IOU   loss: 0.5016007423400879
# Epoch    0: i =   126 ,       8.3292 ms elapsed
# Train loss =     4.83770 (min =     4.81175)     AP@0.5 = 0.35472 (max = 0.34722)
#
# Train: [1016/5441 (19%)]
# Coord loss: 0.10526697337627411
# Obj   loss: 1.1361626386642456
# NoObj loss: 1.4045469760894775
# Class loss: 1.0412025451660156
# IOU   loss: 0.5229375958442688
# Epoch    0: i =   127 ,       8.3447 ms elapsed
# Train loss =     4.83554 (min =     4.81175)     AP@0.5 = 0.35681 (max = 0.34722)
#
# Train: [1024/5441 (19%)]
# Coord loss: 0.148175910115242
# Obj   loss: 1.310850977897644
# NoObj loss: 1.3986358642578125
# Class loss: 1.303700566291809
# IOU   loss: 0.5767742395401001
# Epoch    0: i =   128 ,       8.3310 ms elapsed
# Train loss =     4.83520 (min =     4.81175)     AP@0.5 = 0.35668 (max = 0.34722)
#
# Train: [1032/5441 (19%)]
# Coord loss: 0.22983206808567047
# Obj   loss: 1.2696342468261719
# NoObj loss: 1.4028886556625366
# Class loss: 1.5692850351333618
# IOU   loss: 0.757635235786438
# Epoch    0: i =   129 ,       8.3259 ms elapsed
# Train loss =     4.83655 (min =     4.81175)     AP@0.5 = 0.35596 (max = 0.34722)
#
# Train: [1040/5441 (19%)]
# Coord loss: 0.048613280057907104
# Obj   loss: 1.2788188457489014
# NoObj loss: 1.4037586450576782
# Class loss: 0.8695328235626221
# IOU   loss: 0.4331282079219818
# Epoch    0: i =   130 ,       8.3352 ms elapsed
# Train loss =     4.83381 (min =     4.81175)     AP@0.5 = 0.35616 (max = 0.34722)
#
# Train: [1048/5441 (19%)]
# Coord loss: 0.0936356782913208
# Obj   loss: 1.2815237045288086
# NoObj loss: 1.404571294784546
# Class loss: 1.8208061456680298
# IOU   loss: 0.48702821135520935
# Epoch    0: i =   131 ,       8.3369 ms elapsed
# Train loss =     4.83468 (min =     4.81175)     AP@0.5 = 0.35681 (max = 0.34722)
#
# Train: [1056/5441 (19%)]
# Coord loss: 0.15860886871814728
# Obj   loss: 1.2565271854400635
# NoObj loss: 1.4019029140472412
# Class loss: 0.8401630520820618
# IOU   loss: 0.639080286026001
# Epoch    0: i =   132 ,       8.3252 ms elapsed
# Train loss =     4.83285 (min =     4.81175)     AP@0.5 = 0.35600 (max = 0.34722)
#
# Train: [1064/5441 (20%)]
# Coord loss: 0.1229310929775238
# Obj   loss: 1.296709656715393
# NoObj loss: 1.4106758832931519
# Class loss: 1.5381789207458496
# IOU   loss: 0.566787600517273
# Epoch    0: i =   133 ,       8.3235 ms elapsed
# Train loss =     4.83320 (min =     4.81175)     AP@0.5 = 0.35589 (max = 0.34722)
#
# Train: [1072/5441 (20%)]
# Coord loss: 0.05333547666668892
# Obj   loss: 1.3067638874053955
# NoObj loss: 1.3974895477294922
# Class loss: 1.4862477779388428
# IOU   loss: 0.3679247498512268
# Epoch    0: i =   134 ,       8.3168 ms elapsed
# Train loss =     4.83245 (min =     4.81175)     AP@0.5 = 0.35666 (max = 0.34722)
#
# Train: [1080/5441 (20%)]
# Coord loss: 0.15983691811561584
# Obj   loss: 1.3596580028533936
# NoObj loss: 1.409220576286316
# Class loss: 1.1451971530914307
# IOU   loss: 0.7214317321777344
# Epoch    0: i =   135 ,       8.3284 ms elapsed
# Train loss =     4.83233 (min =     4.81175)     AP@0.5 = 0.35596 (max = 0.34722)
#
# Train: [1088/5441 (20%)]
# Coord loss: 0.13847576081752777
# Obj   loss: 1.3056014776229858
# NoObj loss: 1.4048105478286743
# Class loss: 1.5554414987564087
# IOU   loss: 0.6335728168487549
# Epoch    0: i =   136 ,       8.3355 ms elapsed
# Train loss =     4.83301 (min =     4.81175)     AP@0.5 = 0.35637 (max = 0.34722)
#
# Train: [1096/5441 (20%)]
# Coord loss: 0.08815053850412369
# Obj   loss: 1.3231874704360962
# NoObj loss: 1.4025071859359741
# Class loss: 2.7156600952148438
# IOU   loss: 0.5169588923454285
# Epoch    0: i =   137 ,       8.3322 ms elapsed
# Train loss =     4.83706 (min =     4.81175)     AP@0.5 = 0.35742 (max = 0.34722)
#
# Train: [1104/5441 (20%)]
# Coord loss: 0.06309603154659271
# Obj   loss: 1.324466347694397
# NoObj loss: 1.4064157009124756
# Class loss: 2.356191635131836
# IOU   loss: 0.5243607759475708
# Epoch    0: i =   138 ,       8.3245 ms elapsed
# Train loss =     4.83984 (min =     4.81175)     AP@0.5 = 0.35631 (max = 0.34722)
#
# Train: [1112/5441 (20%)]
# Coord loss: 0.06576728075742722
# Obj   loss: 1.2837411165237427
# NoObj loss: 1.4050747156143188
# Class loss: 1.6370728015899658
# IOU   loss: 0.3935616910457611
# Epoch    0: i =   139 ,       8.3230 ms elapsed
# Train loss =     4.83966 (min =     4.81175)     AP@0.5 = 0.35649 (max = 0.34722)
#
# Train: [1120/5441 (21%)]
# Coord loss: 0.09434022754430771
# Obj   loss: 1.3389548063278198
# NoObj loss: 1.4025534391403198
# Class loss: 1.5941351652145386
# IOU   loss: 0.5174453854560852
# Epoch    0: i =   140 ,       8.3077 ms elapsed
# Train loss =     4.84002 (min =     4.81175)     AP@0.5 = 0.35455 (max = 0.34722)
#
# Train: [1128/5441 (21%)]
# Coord loss: 0.13161276280879974
# Obj   loss: 1.3752760887145996
# NoObj loss: 1.4065345525741577
# Class loss: 1.332909107208252
# IOU   loss: 0.7055289149284363
# Epoch    0: i =   141 ,       8.2939 ms elapsed
# Train loss =     4.84038 (min =     4.81175)     AP@0.5 = 0.35221 (max = 0.34722)
#
# Train: [1136/5441 (21%)]
# Coord loss: 0.10080642253160477
# Obj   loss: 1.2652326822280884
# NoObj loss: 1.399832010269165
# Class loss: 1.5524258613586426
# IOU   loss: 0.5151281356811523
# Epoch    0: i =   142 ,       8.2876 ms elapsed
# Train loss =     4.84036 (min =     4.81175)     AP@0.5 = 0.35241 (max = 0.34722)
#
# Train: [1144/5441 (21%)]
# Coord loss: 0.2260598987340927
# Obj   loss: 1.3058545589447021
# NoObj loss: 1.4091511964797974
# Class loss: 1.5817146301269531
# IOU   loss: 0.7298484444618225
# Epoch    0: i =   143 ,       8.2891 ms elapsed
# Train loss =     4.84171 (min =     4.81175)     AP@0.5 = 0.35288 (max = 0.34722)
#
# Train: [1152/5441 (21%)]
# Coord loss: 0.08958408981561661
# Obj   loss: 1.2981948852539062
# NoObj loss: 1.3980655670166016
# Class loss: 1.0345170497894287
# IOU   loss: 0.44015762209892273
# Epoch    0: i =   144 ,       8.3002 ms elapsed
# Train loss =     4.83982 (min =     4.81175)     AP@0.5 = 0.35308 (max = 0.34722)
#
# Train: [1160/5441 (21%)]
# Coord loss: 0.08951231837272644
# Obj   loss: 1.2617923021316528
# NoObj loss: 1.4077221155166626
# Class loss: 1.048283576965332
# IOU   loss: 0.6692286133766174
# Epoch    0: i =   145 ,       8.2963 ms elapsed
# Train loss =     4.83864 (min =     4.81175)     AP@0.5 = 0.35410 (max = 0.34722)
#
# Train: [1168/5441 (21%)]
# Coord loss: 0.09004233032464981
# Obj   loss: 1.2717983722686768
# NoObj loss: 1.4048480987548828
# Class loss: 1.4061572551727295
# IOU   loss: 0.5423937439918518
# Epoch    0: i =   146 ,       8.2813 ms elapsed
# Train loss =     4.83824 (min =     4.81175)     AP@0.5 = 0.35510 (max = 0.34722)
#
# Train: [1176/5441 (22%)]
# Coord loss: 0.10388769954442978
# Obj   loss: 1.368054986000061
# NoObj loss: 1.4111543893814087
# Class loss: 0.9552671313285828
# IOU   loss: 0.7246749997138977
# Epoch    0: i =   147 ,       8.2938 ms elapsed
# Train loss =     4.83735 (min =     4.81175)     AP@0.5 = 0.35380 (max = 0.34722)
#
# Train: [1184/5441 (22%)]
# Coord loss: 0.12768828868865967
# Obj   loss: 1.355832815170288
# NoObj loss: 1.400734782218933
# Class loss: 1.527494192123413
# IOU   loss: 0.4808652997016907
# Epoch    0: i =   148 ,       8.2931 ms elapsed
# Train loss =     4.83753 (min =     4.81175)     AP@0.5 = 0.35560 (max = 0.34722)
#
# Train: [1192/5441 (22%)]
# Coord loss: 0.03821206092834473
# Obj   loss: 1.2641584873199463
# NoObj loss: 1.4053919315338135
# Class loss: 1.5119531154632568
# IOU   loss: 0.34893545508384705
# Epoch    0: i =   149 ,       8.2876 ms elapsed
# Train loss =     4.83667 (min =     4.81175)     AP@0.5 = 0.35629 (max = 0.34722)
#
# Train: [1200/5441 (22%)]
# Coord loss: 0.07246559858322144
# Obj   loss: 1.2342928647994995
# NoObj loss: 1.3996256589889526
# Class loss: 3.2110595703125
# IOU   loss: 0.5582713484764099
# ...
# IOU   loss: 0.5342307090759277
# Epoch    0: i =   300 ,       8.3787 ms elapsed
# Train loss =     4.82265 (min =     4.81175)     AP@0.5 = 0.35222 (max = 0.34722)
#
# Train: [2408/5441 (44%)]
# Coord loss: 0.04485543817281723
# Obj   loss: 1.2905323505401611
# NoObj loss: 1.4033061265945435
# Class loss: 1.2978448867797852
# IOU   loss: 0.24868625402450562
# Epoch    0: i =   301 ,       8.3787 ms elapsed
# Train loss =     4.82149 (min =     4.81175)     AP@0.5 = 0.35311 (max = 0.34722)
#
# Train: [2416/5441 (44%)]
# Coord loss: 0.06076715514063835
# Obj   loss: 1.3145766258239746
# NoObj loss: 1.4002386331558228
# Class loss: 2.6699910163879395
# IOU   loss: 0.5231326818466187
# Epoch    0: i =   302 ,       8.3740 ms elapsed
# Train loss =     4.82395 (min =     4.81175)     AP@0.5 = 0.35314 (max = 0.34722)
#
# Train: [2424/5441 (45%)]
# Coord loss: 0.1572938859462738
# Obj   loss: 1.3160712718963623
# NoObj loss: 1.4058222770690918
# Class loss: 1.0655274391174316
# IOU   loss: 0.5644201636314392
# Epoch    0: i =   303 ,       8.3814 ms elapsed
# Train loss =     4.82328 (min =     4.81175)     AP@0.5 = 0.35284 (max = 0.34722)
#
# Train: [2432/5441 (45%)]
# Coord loss: 0.10053448379039764
# Obj   loss: 1.2602289915084839
# NoObj loss: 1.4001977443695068
# Class loss: 0.8201956152915955
# IOU   loss: 0.4648742377758026
# Epoch    0: i =   304 ,       8.3793 ms elapsed
# Train loss =     4.82161 (min =     4.81175)     AP@0.5 = 0.35313 (max = 0.34722)
#
# Train: [2440/5441 (45%)]
# Coord loss: 0.2855294942855835
# Obj   loss: 1.3638020753860474
# NoObj loss: 1.4041162729263306
# Class loss: 1.997066617012024
# IOU   loss: 0.9542053937911987
# Epoch    0: i =   305 ,       8.3856 ms elapsed
# Train loss =     4.82414 (min =     4.81175)     AP@0.5 = 0.35283 (max = 0.34722)
#
# Train: [2448/5441 (45%)]
# Coord loss: 0.06502066552639008
# Obj   loss: 1.3360933065414429
# NoObj loss: 1.4076392650604248
# Class loss: 1.4913889169692993
# IOU   loss: 0.4535692632198334
# Epoch    0: i =   306 ,       8.3870 ms elapsed
# Train loss =     4.82399 (min =     4.81175)     AP@0.5 = 0.35267 (max = 0.34722)
#
# Train: [2456/5441 (45%)]
# Coord loss: 0.05321201682090759
# Obj   loss: 1.301666259765625
# NoObj loss: 1.3978513479232788
# Class loss: 2.09334135055542
# IOU   loss: 0.3328888416290283
# Epoch    0: i =   307 ,       8.3822 ms elapsed
# Train loss =     4.82475 (min =     4.81175)     AP@0.5 = 0.35296 (max = 0.34722)
#
# Train: [2464/5441 (45%)]
# Coord loss: 0.08861646056175232
# Obj   loss: 1.3417028188705444
# NoObj loss: 1.411676287651062
# Class loss: 1.257030963897705
# IOU   loss: 0.5922274589538574
# Epoch    0: i =   308 ,       8.3780 ms elapsed
# Train loss =     4.82446 (min =     4.81175)     AP@0.5 = 0.35228 (max = 0.34722)
#
# Train: [2472/5441 (45%)]
# Coord loss: 0.15406998991966248
# Obj   loss: 1.25197434425354
# NoObj loss: 1.3977580070495605
# Class loss: 1.266258955001831
# IOU   loss: 0.7139032483100891
# Epoch    0: i =   309 ,       8.3732 ms elapsed
# Train loss =     4.82438 (min =     4.81175)     AP@0.5 = 0.35218 (max = 0.34722)
#
# Train: [2480/5441 (46%)]
# Coord loss: 0.23219609260559082
# Obj   loss: 1.294191837310791
# NoObj loss: 1.4063010215759277
# Class loss: 1.0016206502914429
# IOU   loss: 0.8729962110519409
# Epoch    0: i =   310 ,       8.3670 ms elapsed
# Train loss =     4.82434 (min =     4.81175)     AP@0.5 = 0.35189 (max = 0.34722)
#
# Train: [2488/5441 (46%)]
# Coord loss: 0.10454896837472916
# Obj   loss: 1.200075626373291
# NoObj loss: 1.4083831310272217
# Class loss: 1.6939363479614258
# IOU   loss: 0.3872223198413849
# Epoch    0: i =   311 ,       8.3748 ms elapsed
# Train loss =     4.82428 (min =     4.81175)     AP@0.5 = 0.35295 (max = 0.34722)
#
# Train: [2496/5441 (46%)]
# Coord loss: 0.1049794927239418
# Obj   loss: 1.3424733877182007
# NoObj loss: 1.4099384546279907
# Class loss: 1.896242618560791
# IOU   loss: 0.5242499709129333
# Epoch    0: i =   312 ,       8.3697 ms elapsed
# Train loss =     4.82523 (min =     4.81175)     AP@0.5 = 0.35247 (max = 0.34722)
#
# Train: [2504/5441 (46%)]
# Coord loss: 0.08180711418390274
# Obj   loss: 1.2751963138580322
# NoObj loss: 1.410144329071045
# Class loss: 1.0319864749908447
# IOU   loss: 0.49647489190101624
# Epoch    0: i =   313 ,       8.3637 ms elapsed
# Train loss =     4.82412 (min =     4.81175)     AP@0.5 = 0.35218 (max = 0.34722)
#
# Train: [2512/5441 (46%)]
# Coord loss: 0.14897577464580536
# Obj   loss: 1.3362276554107666
# NoObj loss: 1.4134714603424072
# Class loss: 2.3441576957702637
# IOU   loss: 0.6645300388336182
# Epoch    0: i =   314 ,       8.3657 ms elapsed
# Train loss =     4.82639 (min =     4.81175)     AP@0.5 = 0.35252 (max = 0.34722)
#
# Train: [2520/5441 (46%)]
# Coord loss: 0.10862401127815247
# Obj   loss: 1.248115062713623
# NoObj loss: 1.4116928577423096
# Class loss: 1.5086941719055176
# IOU   loss: 0.6018384695053101
# Epoch    0: i =   315 ,       8.3669 ms elapsed
# Train loss =     4.82650 (min =     4.81175)     AP@0.5 = 0.35299 (max = 0.34722)
#
# Train: [2528/5441 (46%)]
# Coord loss: 0.11276780068874359
# Obj   loss: 1.2848056554794312
# NoObj loss: 1.4039496183395386
# Class loss: 1.631110668182373
# IOU   loss: 0.659559965133667
# Epoch    0: i =   316 ,       8.3631 ms elapsed
# Train loss =     4.82706 (min =     4.81175)     AP@0.5 = 0.35252 (max = 0.34722)
#
# Train: [2536/5441 (47%)]
# Coord loss: 0.21397630870342255
# Obj   loss: 1.3015925884246826
# NoObj loss: 1.4165087938308716
# Class loss: 1.1882688999176025
# IOU   loss: 0.6590345501899719
# Epoch    0: i =   317 ,       8.3632 ms elapsed
# Train loss =     4.82696 (min =     4.81175)     AP@0.5 = 0.35193 (max = 0.34722)
#
# Train: [2544/5441 (47%)]
# Coord loss: 0.09639280289411545
# Obj   loss: 1.273086428642273
# NoObj loss: 1.4063533544540405
# Class loss: 1.658156156539917
# IOU   loss: 0.5074240565299988
# Epoch    0: i =   318 ,       8.3656 ms elapsed
# Train loss =     4.82719 (min =     4.81175)     AP@0.5 = 0.35203 (max = 0.34722)
#
# Train: [2552/5441 (47%)]
# Coord loss: 0.19629225134849548
# Obj   loss: 1.2841213941574097
# NoObj loss: 1.4145070314407349
# Class loss: 1.2536957263946533
# IOU   loss: 0.7517426609992981
# Epoch    0: i =   319 ,       8.3601 ms elapsed
# Train loss =     4.82735 (min =     4.81175)     AP@0.5 = 0.35156 (max = 0.34722)
#
# Train: [2560/5441 (47%)]
# Coord loss: 0.12089507281780243
# Obj   loss: 1.2462972402572632
# NoObj loss: 1.4134726524353027
# Class loss: 0.7992810010910034
# IOU   loss: 0.4699879586696625
# Epoch    0: i =   320 ,       8.3639 ms elapsed
# Train loss =     4.82574 (min =     4.81175)     AP@0.5 = 0.35247 (max = 0.34722)
#
# Train: [2568/5441 (47%)]
# Coord loss: 0.09449808299541473
# Obj   loss: 1.298317313194275
# NoObj loss: 1.409651756286621
# Class loss: 1.9482800960540771
# IOU   loss: 0.5187176465988159
# Epoch    0: i =   321 ,       8.3753 ms elapsed
# Train loss =     4.82665 (min =     4.81175)     AP@0.5 = 0.35219 (max = 0.34722)
#
# Train: [2576/5441 (47%)]
# Coord loss: 0.0508526973426342
# Obj   loss: 1.2657999992370605
# NoObj loss: 1.4032936096191406
# Class loss: 1.1841673851013184
# IOU   loss: 0.3477288782596588
# Epoch    0: i =   322 ,       8.3850 ms elapsed
# Train loss =     4.82547 (min =     4.81175)     AP@0.5 = 0.35265 (max = 0.34722)
#
# Train: [2584/5441 (47%)]
# Coord loss: 0.09615568071603775
# Obj   loss: 1.272615671157837
# NoObj loss: 1.4100241661071777
# Class loss: 1.4693012237548828
# IOU   loss: 0.45974794030189514
# Epoch    0: i =   323 ,       8.3820 ms elapsed
# Train loss =     4.82523 (min =     4.81175)     AP@0.5 = 0.35293 (max = 0.34722)
#
# Train: [2592/5441 (48%)]
# Coord loss: 0.20337732136249542
# Obj   loss: 1.3529114723205566
# NoObj loss: 1.4034616947174072
# Class loss: 2.5431418418884277
# IOU   loss: 0.7537954449653625
# Epoch    0: i =   324 ,       8.3811 ms elapsed
# Train loss =     4.82817 (min =     4.81175)     AP@0.5 = 0.35302 (max = 0.34722)
#
# Train: [2600/5441 (48%)]
# Coord loss: 0.08730849623680115
# Obj   loss: 1.3180923461914062
# NoObj loss: 1.4011207818984985
# Class loss: 1.2363158464431763
# IOU   loss: 0.5785268545150757
# Epoch    0: i =   325 ,       8.3876 ms elapsed
# Train loss =     4.82774 (min =     4.81175)     AP@0.5 = 0.35274 (max = 0.34722)
#
# Train: [2608/5441 (48%)]
# Coord loss: 0.08270154148340225
# Obj   loss: 1.2088543176651
# NoObj loss: 1.3971086740493774
# Class loss: 0.8110741376876831
# IOU   loss: 0.46923187375068665
# Epoch    0: i =   326 ,       8.3923 ms elapsed
# Train loss =     4.82599 (min =     4.81175)     AP@0.5 = 0.35362 (max = 0.34722)
#
# Train: [2616/5441 (48%)]
# Coord loss: 0.07431456446647644
# Obj   loss: 1.1606086492538452
# NoObj loss: 1.4058278799057007
# Class loss: 1.0283398628234863
# IOU   loss: 0.4162599742412567
# Epoch    0: i =   327 ,       8.3941 ms elapsed
# Train loss =     4.82447 (min =     4.81175)     AP@0.5 = 0.35425 (max = 0.34722)
#
# Train: [2624/5441 (48%)]
# Coord loss: 0.23207402229309082
# Obj   loss: 1.3853271007537842
# NoObj loss: 1.4088037014007568
# Class loss: 3.205195665359497
# IOU   loss: 1.1005288362503052
# Epoch    0: i =   328 ,       8.3920 ms elapsed
# Train loss =     4.82958 (min =     4.81175)     AP@0.5 = 0.35325 (max = 0.34722)
#
# Train: [2632/5441 (48%)]
# Coord loss: 0.11801633983850479
# Obj   loss: 1.3271355628967285
# NoObj loss: 1.4128327369689941
# Class loss: 1.9145286083221436
# IOU   loss: 0.7163416147232056
# Epoch    0: i =   329 ,       8.3905 ms elapsed
# Train loss =     4.83092 (min =     4.81175)     AP@0.5 = 0.35297 (max = 0.34722)
#
# Train: [2640/5441 (49%)]
# Coord loss: 0.1926296204328537
# Obj   loss: 1.2990398406982422
# NoObj loss: 1.4053928852081299
# Class loss: 2.121208667755127
# IOU   loss: 0.6309643983840942
# Epoch    0: i =   330 ,       8.3909 ms elapsed
# Train loss =     4.83258 (min =     4.81175)     AP@0.5 = 0.35329 (max = 0.34722)
#
# Train: [2648/5441 (49%)]
# Coord loss: 0.046535518020391464
# Obj   loss: 1.3024044036865234
# NoObj loss: 1.4008480310440063
# Class loss: 1.1554622650146484
# IOU   loss: 0.386238157749176
# Epoch    0: i =   331 ,       8.3957 ms elapsed
# Train loss =     4.83149 (min =     4.81175)     AP@0.5 = 0.35338 (max = 0.34722)
#
# Train: [2656/5441 (49%)]
# Coord loss: 0.16018176078796387
# Obj   loss: 1.3283137083053589
# NoObj loss: 1.408826470375061
# Class loss: 1.0718494653701782
# IOU   loss: 0.7370409369468689
# Epoch    0: i =   332 ,       8.3953 ms elapsed
# Train loss =     4.83123 (min =     4.81175)     AP@0.5 = 0.35293 (max = 0.34722)
#
# Train: [2664/5441 (49%)]
# Coord loss: 0.11038055270910263
# Obj   loss: 1.3028775453567505
# NoObj loss: 1.3991575241088867
# Class loss: 1.022629737854004
# IOU   loss: 0.46630677580833435
# Epoch    0: i =   333 ,       8.3953 ms elapsed
# Train loss =     4.83016 (min =     4.81175)     AP@0.5 = 0.35284 (max = 0.34722)
#
# Train: [2672/5441 (49%)]
# Coord loss: 0.1405070722103119
# Obj   loss: 1.2992117404937744
# NoObj loss: 1.4066543579101562
# Class loss: 1.4607770442962646
# IOU   loss: 0.5319358110427856
# Epoch    0: i =   334 ,       8.3946 ms elapsed
# Train loss =     4.83018 (min =     4.81175)     AP@0.5 = 0.35257 (max = 0.34722)
#
# Train: [2680/5441 (49%)]
# Coord loss: 0.046226922422647476
# Obj   loss: 1.308659315109253
# NoObj loss: 1.4074543714523315
# Class loss: 1.1853996515274048
# IOU   loss: 0.3442065715789795
# Epoch    0: i =   335 ,       8.3971 ms elapsed
# Train loss =     4.82910 (min =     4.81175)     AP@0.5 = 0.35194 (max = 0.34722)
#
# Train: [2688/5441 (49%)]
# Coord loss: 0.11916646361351013
# Obj   loss: 1.3827317953109741
# NoObj loss: 1.409654140472412
# Class loss: 1.8143260478973389
# IOU   loss: 0.7246004343032837
# Epoch    0: i =   336 ,       8.4043 ms elapsed
# Train loss =     4.83035 (min =     4.81175)     AP@0.5 = 0.35168 (max = 0.34722)
#
# Train: [2696/5441 (50%)]
# Coord loss: 0.126083105802536
# Obj   loss: 1.3244656324386597
# NoObj loss: 1.4085371494293213
# Class loss: 0.8298189043998718
# IOU   loss: 0.6226751804351807
# Epoch    0: i =   337 ,       8.4025 ms elapsed
# Train loss =     4.82931 (min =     4.81175)     AP@0.5 = 0.35141 (max = 0.34722)
#
# Train: [2704/5441 (50%)]
# Coord loss: 0.059305377304553986
# Obj   loss: 1.1894460916519165
# NoObj loss: 1.4024913311004639
# Class loss: 1.0242187976837158
# IOU   loss: 0.3289642930030823
# Epoch    0: i =   338 ,       8.3985 ms elapsed
# Train loss =     4.82766 (min =     4.81175)     AP@0.5 = 0.35208 (max = 0.34722)
#
# Train: [2712/5441 (50%)]
# Coord loss: 0.12204381078481674
# Obj   loss: 1.3355584144592285
# NoObj loss: 1.411808729171753
# Class loss: 2.0807178020477295
# IOU   loss: 0.6105065941810608
# Epoch    0: i =   339 ,       8.3950 ms elapsed
# Train loss =     4.82912 (min =     4.81175)     AP@0.5 = 0.35170 (max = 0.34722)
#
# Train: [2720/5441 (50%)]
# Coord loss: 0.05090605840086937
# Obj   loss: 1.3300584554672241
# NoObj loss: 1.4057692289352417
# Class loss: 1.1145620346069336
# IOU   loss: 0.3341871201992035
# Epoch    0: i =   340 ,       8.3885 ms elapsed
# Train loss =     4.82794 (min =     4.81175)     AP@0.5 = 0.35132 (max = 0.34722)
#
# Train: [2728/5441 (50%)]
# Coord loss: 0.08122257143259048
# Obj   loss: 1.28357994556427
# NoObj loss: 1.398622989654541
# Class loss: 1.1588349342346191
# IOU   loss: 0.48400864005088806
# Epoch    0: i =   341 ,       8.3904 ms elapsed
# Train loss =     4.82711 (min =     4.81175)     AP@0.5 = 0.35170 (max = 0.34722)
#
# Train: [2736/5441 (50%)]
# Coord loss: 0.07325437664985657
# Obj   loss: 1.3529903888702393
# NoObj loss: 1.4131770133972168
# Class loss: 2.139961004257202
# IOU   loss: 0.43982481956481934
# Epoch    0: i =   342 ,       8.3940 ms elapsed
# Train loss =     4.82828 (min =     4.81175)     AP@0.5 = 0.35151 (max = 0.34722)
#
# Train: [2744/5441 (50%)]
# Coord loss: 0.10832203924655914
# Obj   loss: 1.2372688055038452
# NoObj loss: 1.4054983854293823
# Class loss: 0.812195360660553
# IOU   loss: 0.496192067861557
# Epoch    0: i =   343 ,       8.3953 ms elapsed
# Train loss =     4.82676 (min =     4.81175)     AP@0.5 = 0.35194 (max = 0.34722)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 38
#      36 clip_val = 1.0
#      37 optimizer.zero_grad()
# ---> 38 loss.backward()
#      39 validate_gradients(qat_model) #net.validate_gradients()
#      40 torch.nn.utils.clip_grad_norm_(qat_model.parameters(), clip_val)
#
# File ~/miniconda3/envs/udaya_tf/lib/python3.9/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/miniconda3/envs/udaya_tf/lib/python3.9/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/miniconda3/envs/udaya_tf/lib/python3.9/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import torch
state_dict = torch.load("/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/simple_model_checkpoints/checkpoints/epoch_562_0.32524436072447455.pt")
# Out:
# /tmp/ipykernel_22092/175184666.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load("/home/udayanga/Udaya_Research_stuff/2024_GAP8_work/yolov3_ann_head1_model/simple_model_checkpoints/checkpoints/epoch_562_0.32524436072447455.pt")

# %%
for key in state_dict["model_state_dict"].keys():
    print(key)
    print(state_dict["model_state_dict"][key].shape)
# Out:
# anchors
# torch.Size([1, 3, 2])
# backend_blocks.0.weight
# torch.Size([16, 2, 3, 3])
# backend_blocks.1.weight
# torch.Size([16])
# backend_blocks.1.bias
# torch.Size([16])
# backend_blocks.1.running_mean
# torch.Size([16])
# backend_blocks.1.running_var
# torch.Size([16])
# backend_blocks.1.num_batches_tracked
# torch.Size([])
# backend_blocks.3.weight
# torch.Size([32, 16, 3, 3])
# backend_blocks.4.weight
# torch.Size([32])
# backend_blocks.4.bias
# torch.Size([32])
# backend_blocks.4.running_mean
# torch.Size([32])
# backend_blocks.4.running_var
# torch.Size([32])
# backend_blocks.4.num_batches_tracked
# torch.Size([])
# backend_blocks.7.weight
# torch.Size([32, 32, 3, 3])
# backend_blocks.8.weight
# torch.Size([32])
# backend_blocks.8.bias
# torch.Size([32])
# backend_blocks.8.running_mean
# torch.Size([32])
# backend_blocks.8.running_var
# torch.Size([32])
# backend_blocks.8.num_batches_tracked
# torch.Size([])
# backend_blocks.10.weight
# torch.Size([64, 32, 3, 3])
# backend_blocks.11.weight
# torch.Size([64])
# backend_blocks.11.bias
# torch.Size([64])
# backend_blocks.11.running_mean
# torch.Size([64])
# backend_blocks.11.running_var
# torch.Size([64])
# backend_blocks.11.num_batches_tracked
# torch.Size([])
# backend_blocks.14.weight
# torch.Size([64, 64, 3, 3])
# backend_blocks.15.weight
# torch.Size([64])
# backend_blocks.15.bias
# torch.Size([64])
# backend_blocks.15.running_mean
# torch.Size([64])
# backend_blocks.15.running_var
# torch.Size([64])
# backend_blocks.15.num_batches_tracked
# torch.Size([])
# head1_backend.0.weight
# torch.Size([64, 64, 3, 3])
# head1_backend.1.weight
# torch.Size([64])
# head1_backend.1.bias
# torch.Size([64])
# head1_backend.1.running_mean
# torch.Size([64])
# head1_backend.1.running_var
# torch.Size([64])
# head1_backend.1.num_batches_tracked
# torch.Size([])
# head1_backend.3.weight
# torch.Size([128, 64, 3, 3])
# head1_backend.4.weight
# torch.Size([128])
# head1_backend.4.bias
# torch.Size([128])
# head1_backend.4.running_mean
# torch.Size([128])
# head1_backend.4.running_var
# torch.Size([128])
# head1_backend.4.num_batches_tracked
# torch.Size([])
# head1_blocks.0.weight
# torch.Size([128, 128, 3, 3])
# head1_blocks.1.weight
# torch.Size([128])
# head1_blocks.1.bias
# torch.Size([128])
# head1_blocks.1.running_mean
# torch.Size([128])
# head1_blocks.1.running_var
# torch.Size([128])
# head1_blocks.1.num_batches_tracked
# torch.Size([])
# head1_blocks.3.weight
# torch.Size([21, 128, 1, 1])
# head1_blocks.4.weight
# torch.Size([21])
# head1_blocks.4.bias
# torch.Size([21])
# head1_blocks.4.running_mean
# torch.Size([21])
# head1_blocks.4.running_var
# torch.Size([21])
# head1_blocks.4.num_batches_tracked
# torch.Size([])
